# %%
import sys
sys.path.insert(0,'..')

import numpy as np

import gym
import stable_baselines
from stable_baselines import A2C, ACER, ACKTR, DQN, DDPG, SAC, PPO1, PPO2, TD3, TRPO
from stable_baselines.common.env_checker import check_env
from stable_baselines.common.policies import MlpPolicy

from fakegym.fakegym import FakeGym
import importlib
# Out:
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.

# %%
class MyObservation():
    def __init__(self, env):
        self.env = env
        self.gps_actual = None
        self.gps_target = None
        self.distance = None
        self.touching = None

    def _update(self):
        self.gps_actual = self.env.state_object.gps_actual
        self.gps_target = self.env.state_object.gps_target
        self.distance = self.env.state_object.distance
        self.touching = self.env.state_object.touching

    def shape(self):
        """Make sure length is correct here.In this example:
        gps_actual: 2
        gps_target: 2
        distance:   4
        touching:   1
        =================
                   (9, )
        
        """
        return (9, )

    def get(self, env):
        """Get observation as numpy array."""
        self._update()
        
        arr = np.empty(0)
        arr = np.hstack((arr, np.array(self.gps_actual)))
        arr = np.hstack((arr, np.array(self.gps_target)))
        arr = np.hstack((arr, np.array(self.distance)))
        arr = np.hstack((arr, np.array(self.touching)))
        
        return arr
    

class MyEnv(FakeGym):
    def __init__(self, seed=None, N=10, num_of_sensors=4, obs_len=1, obstacles_each=4,
                 step_range=(1, 1), action_type="discrete",
                 discrete_action_shaping="flatten", obs=MyObservation):
        super(MyEnv, self).__init__(seed, N, num_of_sensors, obstacles_each, step_range, action_type, discrete_action_shaping, obs, obs_len=1)
        

    def calc_reward(self):
        """Calculate reward function.

        Idea(Mats):
        - negative reward for normal move so that james moves faster to goal
        - still lower negative reward if james gets closer to goal
        - high positive award for reaching it
        - high negative award to hitting a wall
        - epsilon only to divide never by 0

        """
        if self.gps_actual == self.gps_target:
            reward = 1000
        else:
            epsilon = 10**-5
            cost_step = 1
            distance = self.get_target_distance()+epsilon
            cost_distance = (distance**0.4)/(distance)
            reward_factor = -1
            reward = reward_factor * (cost_step * cost_distance)
            if self.state_object:
                reward = reward - 10
        return reward
        
        
    def check_done(self):
        if self.com.time_steps == 1000:
            return True
        if self.gps_actual == self.gps_target:
            return True
        return False


env = MyEnv()
check_env(env)
# Out:
# /home/pj/anaconda3/envs/spinningup/lib/python3.6/site-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))

# %%
time_steps = 2*10**5
model_name = "PPO1_fake_200k"
model = PPO1("MlpPolicy", env, verbose=1)
model.learn(total_timesteps=time_steps, log_interval=10000)
model.save("../models/keep/{}".format(model_name))
del model
# Out:
# WARNING:tensorflow:From /home/pj/anaconda3/envs/spinningup/lib/python3.6/site-packages/stable_baselines/common/tf_util.py:191: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /home/pj/anaconda3/envs/spinningup/lib/python3.6/site-packages/stable_baselines/common/tf_util.py:200: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# WARNING:tensorflow:From /home/pj/anaconda3/envs/spinningup/lib/python3.6/site-packages/stable_baselines/common/policies.py:116: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# WARNING:tensorflow:From /home/pj/anaconda3/envs/spinningup/lib/python3.6/site-packages/stable_baselines/common/input.py:25: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /home/pj/anaconda3/envs/spinningup/lib/python3.6/site-packages/stable_baselines/common/policies.py:561: flatten (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.flatten instead.
# WARNING:tensorflow:From /home/pj/anaconda3/envs/spinningup/lib/python3.6/site-packages/tensorflow_core/python/layers/core.py:332: Layer.apply (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.__call__` method instead.
# WARNING:tensorflow:From /home/pj/anaconda3/envs/spinningup/lib/python3.6/site-packages/stable_baselines/common/tf_layers.py:123: The name tf.get_variable is deprecated. Please use tf.compat.v1.get_variable instead.
#
# WARNING:tensorflow:From /home/pj/anaconda3/envs/spinningup/lib/python3.6/site-packages/stable_baselines/common/distributions.py:326: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /home/pj/anaconda3/envs/spinningup/lib/python3.6/site-packages/stable_baselines/common/distributions.py:327: The name tf.log is deprecated. Please use tf.math.log instead.
#
# WARNING:tensorflow:From /home/pj/anaconda3/envs/spinningup/lib/python3.6/site-packages/stable_baselines/ppo1/pposgd_simple.py:153: The name tf.summary.scalar is deprecated. Please use tf.compat.v1.summary.scalar instead.
#
# WARNING:tensorflow:From /home/pj/anaconda3/envs/spinningup/lib/python3.6/site-packages/stable_baselines/common/tf_util.py:449: The name tf.get_collection is deprecated. Please use tf.compat.v1.get_collection instead.
#
# WARNING:tensorflow:From /home/pj/anaconda3/envs/spinningup/lib/python3.6/site-packages/stable_baselines/common/tf_util.py:449: The name tf.GraphKeys is deprecated. Please use tf.compat.v1.GraphKeys instead.
#
# WARNING:tensorflow:From /home/pj/anaconda3/envs/spinningup/lib/python3.6/site-packages/stable_baselines/ppo1/pposgd_simple.py:163: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# WARNING:tensorflow:From /home/pj/anaconda3/envs/spinningup/lib/python3.6/site-packages/stable_baselines/common/tf_util.py:241: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From /home/pj/anaconda3/envs/spinningup/lib/python3.6/site-packages/stable_baselines/common/tf_util.py:242: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
#
# WARNING:tensorflow:From /home/pj/anaconda3/envs/spinningup/lib/python3.6/site-packages/stable_baselines/ppo1/pposgd_simple.py:191: The name tf.summary.merge_all is deprecated. Please use tf.compat.v1.summary.merge_all instead.
#
# WARNING:tensorflow:From /home/pj/anaconda3/envs/spinningup/lib/python3.6/site-packages/tensorflow_core/python/ops/math_grad.py:1424: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# ********** Iteration 0 ************
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#      -0.00070 |      -0.01386 |      5.79e+04 |       0.00020 |       1.38613
#      -0.01138 |      -0.01385 |      5.77e+04 |       0.00175 |       1.38466
#      -0.02054 |      -0.01381 |      5.75e+04 |       0.00571 |       1.38082
#      -0.02121 |      -0.01375 |      5.73e+04 |       0.01146 |       1.37521
# Evaluating losses...
#      -0.02088 |      -0.01373 |      5.71e+04 |       0.01363 |       1.37313
# ----------------------------------
# | EpLenMean       | 251          |
# | EpRewMean       | -2.04e+03    |
# | EpThisIter      | 1            |
# | EpisodesSoFar   | 1            |
# | TimeElapsed     | 1.33         |
# | TimestepsSoFar  | 256          |
# | ev_tdlam_before | -0.000362    |
# | loss_ent        | 1.37313      |
# | loss_kl         | 0.013634689  |
# | loss_pol_entpen | -0.013731299 |
# | loss_pol_surr   | -0.020876758 |
# | loss_vf_loss    | 57144.52     |
# ----------------------------------
# ********** Iteration 1 ************
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#      8.83e-05 |      -0.01374 |      5.94e+04 |      4.42e-05 |       1.37423
#      -0.00378 |      -0.01375 |      5.92e+04 |       0.00059 |       1.37513
#      -0.00999 |      -0.01377 |      5.90e+04 |       0.00245 |       1.37697
#      -0.01468 |      -0.01377 |      5.88e+04 |       0.00600 |       1.37717
# Evaluating losses...
#      -0.01636 |      -0.01377 |      5.87e+04 |       0.00871 |       1.37670
# ----------------------------------
# | EpLenMean       | 113          |
# | EpRewMean       | -378         |
# | EpThisIter      | 2            |
# | EpisodesSoFar   | 3            |
# | TimeElapsed     | 2.15         |
# | TimestepsSoFar  | 512          |
# | ev_tdlam_before | -0.00114     |
# | loss_ent        | 1.3767002    |
# | loss_kl         | 0.008711378  |
# | loss_pol_entpen | -0.013767001 |
# | loss_pol_surr   | -0.016358394 |
# | loss_vf_loss    | 58741.168    |
# ----------------------------------
# ********** Iteration 2 ************
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#      -0.00126 |      -0.01376 |      7.16e+04 |       0.00012 |       1.37649
#      -0.00793 |      -0.01376 |      7.16e+04 |       0.00156 |       1.37600
#      -0.01795 |      -0.01373 |      7.15e+04 |       0.00591 |       1.37336
#      -0.02357 |      -0.01367 |      7.15e+04 |       0.01268 |       1.36698
# Evaluating losses...
#      -0.02466 |      -0.01363 |      7.15e+04 |       0.01598 |       1.36272
# ----------------------------------
# | EpLenMean       | 143          |
# | EpRewMean       | -761         |
# | EpThisIter      | 2            |
# | EpisodesSoFar   | 5            |
# | TimeElapsed     | 2.89         |
# | TimestepsSoFar  | 768          |
# | ev_tdlam_before | -0.000314    |
# | loss_ent        | 1.3627167    |
# | loss_kl         | 0.01597546   |
# | loss_pol_entpen | -0.013627168 |
# | loss_pol_surr   | -0.024663206 |
# | loss_vf_loss    | 71503.42     |
# ----------------------------------
# ********** Iteration 3 ************
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#      -0.00038 |      -0.01377 |      3.38e+04 |       0.00017 |       1.37671
#      -0.00800 |      -0.01373 |      3.36e+04 |       0.00181 |       1.37303
#      -0.01680 |      -0.01365 |      3.34e+04 |       0.00715 |       1.36529
#      -0.02132 |      -0.01357 |      3.32e+04 |       0.01466 |       1.35697
# Evaluating losses...
#      -0.02338 |      -0.01354 |      3.31e+04 |       0.01871 |       1.35447
# ----------------------------------
# | EpLenMean       | 143          |
# | EpRewMean       | -761         |
# | EpThisIter      | 0            |
# | EpisodesSoFar   | 5            |
# | TimeElapsed     | 3.69         |
# | TimestepsSoFar  | 1024         |
# | ev_tdlam_before | -0.00109     |
# | loss_ent        | 1.3544657    |
# | loss_kl         | 0.018713258  |
# | loss_pol_entpen | -0.013544658 |
# | loss_pol_surr   | -0.023375928 |
# | loss_vf_loss    | 33074.332    |
# ----------------------------------
# ********** Iteration 4 ************
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#      -0.00112 |      -0.01345 |      5.21e+04 |       0.00038 |       1.34531
#      -0.01035 |      -0.01354 |      5.20e+04 |       0.00323 |       1.35446
#      -0.02395 |      -0.01364 |      5.19e+04 |       0.01155 |       1.36371
#      -0.02367 |      -0.01368 |      5.18e+04 |       0.02159 |       1.36787
# Evaluating losses...
#      -0.02492 |      -0.01370 |      5.17e+04 |       0.02335 |       1.37036
# ----------------------------------
# | EpLenMean       | 195          |
# | EpRewMean       | -1.35e+03    |
# | EpThisIter      | 1            |
# | EpisodesSoFar   | 6            |
# | TimeElapsed     | 4.45         |
# | TimestepsSoFar  | 1280         |
# | ev_tdlam_before | -0.000291    |
# | loss_ent        | 1.3703628    |
# | loss_kl         | 0.023353169  |
# | loss_pol_entpen | -0.013703627 |
# | loss_pol_surr   | -0.024916152 |
# | loss_vf_loss    | 51745.363    |
# ----------------------------------
# ********** Iteration 5 ************
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#       0.00199 |      -0.01372 |      3.55e+04 |       0.00013 |       1.37192
#      -0.00499 |      -0.01374 |      3.54e+04 |       0.00075 |       1.37389
#      -0.01071 |      -0.01374 |      3.53e+04 |       0.00348 |       1.37392
#      -0.02456 |      -0.01372 |      3.51e+04 |       0.00885 |       1.37177
# Evaluating losses...
#      -0.02616 |      -0.01370 |      3.50e+04 |       0.01248 |       1.37027
# ----------------------------------
# | EpLenMean       | 195          |
# | EpRewMean       | -1.35e+03    |
# | EpThisIter      | 0            |
# | EpisodesSoFar   | 6            |
# | TimeElapsed     | 5.32         |
# | TimestepsSoFar  | 1536         |
# | ev_tdlam_before | -0.000911    |
# | loss_ent        | 1.3702738    |
# | loss_kl         | 0.012481863  |
# | loss_pol_entpen | -0.013702738 |
# | loss_pol_surr   | -0.026162218 |
# | loss_vf_loss    | 35031.39     |
# ----------------------------------
# ********** Iteration 6 ************
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#       0.00127 |      -0.01364 |      3.71e+04 |      6.85e-05 |       1.36444
#      -0.00098 |      -0.01363 |      3.70e+04 |       0.00031 |       1.36297
#      -0.00820 |      -0.01363 |      3.68e+04 |       0.00076 |       1.36308
#      -0.01440 |      -0.01364 |      3.67e+04 |       0.00280 |       1.36396
# Evaluating losses...
#      -0.02275 |      -0.01364 |      3.66e+04 |       0.00589 |       1.36357
# ----------------------------------
# | EpLenMean       | 195          |
# | EpRewMean       | -1.35e+03    |
# | EpThisIter      | 0            |
# | EpisodesSoFar   | 6            |
# | TimeElapsed     | 6.06         |
# | TimestepsSoFar  | 1792         |
# | ev_tdlam_before | 0.000306     |
# | loss_ent        | 1.3635699    |
# | loss_kl         | 0.005886391  |
# | loss_pol_entpen | -0.013635699 |
# | loss_pol_surr   | -0.022745892 |
# | loss_vf_loss    | 36603.625    |
# ----------------------------------
# ********** Iteration 7 ************
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#      -0.00195 |      -0.01364 |      3.61e+04 |       0.00039 |       1.36373
#      -0.01198 |      -0.01361 |      3.59e+04 |       0.00468 |       1.36097
#      -0.01880 |      -0.01355 |      3.58e+04 |       0.01424 |       1.35457
#      -0.02032 |      -0.01348 |      3.57e+04 |       0.02328 |       1.34836
# Evaluating losses...
#      -0.02217 |      -0.01347 |      3.56e+04 |       0.02558 |       1.34656
# ----------------------------------
# | EpLenMean       | 195          |
# | EpRewMean       | -1.35e+03    |
# | EpThisIter      | 0            |
# | EpisodesSoFar   | 6            |
# | TimeElapsed     | 6.79         |
# | TimestepsSoFar  | 2048         |
# | ev_tdlam_before | -0.000526    |
# | loss_ent        | 1.3465571    |
# | loss_kl         | 0.02558384   |
# | loss_pol_entpen | -0.013465572 |
# | loss_pol_surr   | -0.022165667 |
# | loss_vf_loss    | 35581.875    |
# ----------------------------------
# ********** Iteration 8 ************
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#      -0.00070 |      -0.01356 |      1.32e+05 |       0.00013 |       1.35633
#      -0.01039 |      -0.01356 |      1.32e+05 |       0.00154 |       1.35559
#      -0.02190 |      -0.01353 |      1.32e+05 |       0.00669 |       1.35329
#      -0.03154 |      -0.01349 |      1.32e+05 |       0.01505 |       1.34863
# Evaluating losses...
#      -0.03268 |      -0.01346 |      1.32e+05 |       0.01949 |       1.34611
# ----------------------------------
# | EpLenMean       | 190          |
# | EpRewMean       | -1.29e+03    |
# | EpThisIter      | 6            |
# | EpisodesSoFar   | 12           |
# | TimeElapsed     | 7.53         |
# | TimestepsSoFar  | 2304         |
# | ev_tdlam_before | -6.79e-06    |
# | loss_ent        | 1.3461099    |
# | loss_kl         | 0.019489314  |
# | loss_pol_entpen | -0.013461099 |
# | loss_pol_surr   | -0.03267688  |
# | loss_vf_loss    | 132063.42    |
# ----------------------------------
# ********** Iteration 9 ************
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#       0.00032 |      -0.01346 |      7.07e+04 |       0.00031 |       1.34563
#      -0.00823 |      -0.01340 |      7.07e+04 |       0.00234 |       1.34008
#      -0.01380 |      -0.01331 |      7.07e+04 |       0.00859 |       1.33075
#      -0.01671 |      -0.01325 |      7.07e+04 |       0.01333 |       1.32464
# Evaluating losses...
#      -0.02050 |      -0.01326 |      7.07e+04 |       0.01285 |       1.32604
# ----------------------------------
# | EpLenMean       | 176          |
# | EpRewMean       | -1.11e+03    |
# | EpThisIter      | 2            |
# | EpisodesSoFar   | 14           |
# | TimeElapsed     | 8.25         |
# | TimestepsSoFar  | 2560         |
# | ev_tdlam_before | -2.75e-05    |
# | loss_ent        | 1.3260401    |
# | loss_kl         | 0.012849712  |
# | loss_pol_entpen | -0.013260402 |
# | loss_pol_surr   | -0.020501181 |
# | loss_vf_loss    | 70675.875    |
# ----------------------------------
# ********** Iteration 10 ************
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#      -0.00086 |      -0.01337 |      5.16e+04 |       0.00045 |       1.33683
#      -0.01257 |      -0.01344 |      5.16e+04 |       0.00437 |       1.34431
#      -0.01334 |      -0.01349 |      5.16e+04 |       0.01187 |       1.34854
#      -0.01814 |      -0.01349 |      5.15e+04 |       0.01450 |       1.34927
# Evaluating losses...
#      -0.02221 |      -0.01348 |      5.15e+04 |       0.01323 |       1.34845
# ----------------------------------
# | EpLenMean       | 181          |
# | EpRewMean       | -1.17e+03    |
# | EpThisIter      | 1            |
# | EpisodesSoFar   | 15           |
# | TimeElapsed     | 9.05         |
# | TimestepsSoFar  | 2816         |
# | ev_tdlam_before | -2.97e-05    |
# | loss_ent        | 1.3484517    |
# | loss_kl         | 0.013233153  |
# | loss_pol_entpen | -0.013484517 |
# | loss_pol_surr   | -0.02220663  |
# | loss_vf_loss    | 51496.863    |
# ----------------------------------
# ********** Iteration 11 ************
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#      -0.00272 |      -0.01367 |      3.60e+04 |       0.00019 |       1.36722
#      -0.01443 |      -0.01374 |      3.59e+04 |       0.00319 |       1.37421
#      -0.01917 |      -0.01380 |      3.58e+04 |       0.00744 |       1.37962
#      -0.02818 |      -0.01381 |      3.57e+04 |       0.00756 |       1.38136
# Evaluating losses...
#      -0.03526 |      -0.01380 |      3.56e+04 |       0.00768 |       1.38037
# ----------------------------------
# | EpLenMean       | 181          |
# | EpRewMean       | -1.17e+03    |
# | EpThisIter      | 0            |
# | EpisodesSoFar   | 15           |
# | TimeElapsed     | 9.74         |
# | TimestepsSoFar  | 3072         |
# | ev_tdlam_before | 0.000183     |
# | loss_ent        | 1.3803732    |
# | loss_kl         | 0.0076777413 |
# | loss_pol_entpen | -0.013803732 |
# | loss_pol_surr   | -0.035264686 |
# | loss_vf_loss    | 35586.6      |
# ----------------------------------
# ********** Iteration 12 ************
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#       0.00053 |      -0.01376 |      3.41e+04 |       0.00033 |       1.37601
#      -0.00147 |      -0.01375 |      3.40e+04 |       0.00190 |       1.37525
#      -0.00153 |      -0.01373 |      3.39e+04 |       0.00411 |       1.37343
#      -0.00382 |      -0.01372 |      3.37e+04 |       0.00654 |       1.37212
# Evaluating losses...
#      -0.00544 |      -0.01372 |      3.37e+04 |       0.00789 |       1.37172
# -----------------------------------
# | EpLenMean       | 181           |
# | EpRewMean       | -1.17e+03     |
# | EpThisIter      | 0             |
# | EpisodesSoFar   | 15            |
# | TimeElapsed     | 10.4          |
# | TimestepsSoFar  | 3328          |
# | ev_tdlam_before | -4.07e-05     |
# | loss_ent        | 1.3717239     |
# | loss_kl         | 0.007886733   |
# | loss_pol_entpen | -0.013717239  |
# | loss_pol_surr   | -0.0054381546 |
# | loss_vf_loss    | 33665.77      |
# -----------------------------------
# ********** Iteration 13 ************
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#      -0.00085 |      -0.01371 |      3.27e+04 |       0.00017 |       1.37057
#      -0.01407 |      -0.01368 |      3.26e+04 |       0.00252 |       1.36847
#      -0.03288 |      -0.01358 |      3.25e+04 |       0.01319 |       1.35822
#      -0.03357 |      -0.01343 |      3.24e+04 |       0.02859 |       1.34345
# Evaluating losses...
#      -0.03118 |      -0.01338 |      3.23e+04 |       0.03379 |       1.33814
# ----------------------------------
# | EpLenMean       | 181          |
# | EpRewMean       | -1.17e+03    |
# | EpThisIter      | 0            |
# | EpisodesSoFar   | 15           |
# | TimeElapsed     | 11.1         |
# | TimestepsSoFar  | 3584         |
# | ev_tdlam_before | 0.000214     |
# | loss_ent        | 1.3381417    |
# | loss_kl         | 0.033792153  |
# | loss_pol_entpen | -0.013381418 |
# | loss_pol_surr   | -0.031177497 |
# | loss_vf_loss    | 32317.451    |
# ----------------------------------
# ********** Iteration 14 ************
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#      -0.00052 |      -0.01347 |      8.99e+04 |      3.50e-05 |       1.34709
#      -0.00831 |      -0.01347 |      8.99e+04 |       0.00074 |       1.34742
#      -0.01740 |      -0.01349 |      8.99e+04 |       0.00438 |       1.34898
#      -0.01946 |      -0.01349 |      8.99e+04 |       0.01032 |       1.34867
# Evaluating losses...
#      -0.02186 |      -0.01349 |      8.99e+04 |       0.01280 |       1.34852
# ----------------------------------
# | EpLenMean       | 201          |
# | EpRewMean       | -1.46e+03    |
# | EpThisIter      | 4            |
# | EpisodesSoFar   | 19           |
# | TimeElapsed     | 11.8         |
# | TimestepsSoFar  | 3840         |
# | ev_tdlam_before | 3.14e-05     |
# | loss_ent        | 1.3485186    |
# | loss_kl         | 0.012798293  |
# | loss_pol_entpen | -0.013485186 |
# | loss_pol_surr   | -0.021855224 |
# | loss_vf_loss    | 89905.56     |
# ----------------------------------
# ********** Iteration 15 ************
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#      2.52e-05 |      -0.01347 |      3.43e+04 |      2.89e-05 |       1.34733
#      -0.00584 |      -0.01345 |      3.42e+04 |       0.00099 |       1.34548
#      -0.01810 |      -0.01341 |      3.41e+04 |       0.00570 |       1.34143
#      -0.01946 |      -0.01336 |      3.40e+04 |       0.01405 |       1.33559
# Evaluating losses...
#      -0.01971 |      -0.01334 |      3.40e+04 |       0.01721 |       1.33373
# ----------------------------------
# | EpLenMean       | 201          |
# | EpRewMean       | -1.46e+03    |
# | EpThisIter      | 0            |
# | EpisodesSoFar   | 19           |
# | TimeElapsed     | 12.5         |
# | TimestepsSoFar  | 4096         |
# | ev_tdlam_before | -0.000875    |
# | loss_ent        | 1.3337343    |
# | loss_kl         | 0.017212689  |
# | loss_pol_entpen | -0.013337341 |
# | loss_pol_surr   | -0.019707156 |
# | loss_vf_loss    | 33970.016    |
# ----------------------------------
# ********** Iteration 16 ************
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#       0.00031 |      -0.01338 |      3.27e+04 |      4.43e-05 |       1.33825
#      -0.00119 |      -0.01343 |      3.26e+04 |       0.00035 |       1.34284
#      -0.00275 |      -0.01352 |      3.25e+04 |       0.00223 |       1.35226
#      -0.00834 |      -0.01360 |      3.24e+04 |       0.00571 |       1.36025
# Evaluating losses...
#      -0.00962 |      -0.01363 |      3.23e+04 |       0.00810 |       1.36334
# -----------------------------------
# | EpLenMean       | 201           |
# | EpRewMean       | -1.46e+03     |
# | EpThisIter      | 0             |
# | EpisodesSoFar   | 19            |
# | TimeElapsed     | 13.2          |
# | TimestepsSoFar  | 4352          |
# | ev_tdlam_before | 0.000161      |
# | loss_ent        | 1.3633437     |
# | loss_kl         | 0.0080966065  |
# | loss_pol_entpen | -0.0136334365 |
# | loss_pol_surr   | -0.00961649   |
# | loss_vf_loss    | 32289.219     |
# -----------------------------------
# ********** Iteration 17 ************
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#      -0.00144 |      -0.01354 |      5.32e+04 |       0.00022 |       1.35368
#      -0.01311 |      -0.01362 |      5.32e+04 |       0.00226 |       1.36209
#      -0.01540 |      -0.01369 |      5.31e+04 |       0.00714 |       1.36876
#      -0.01427 |      -0.01371 |      5.31e+04 |       0.01139 |       1.37103
# Evaluating losses...
#      -0.01722 |      -0.01371 |      5.31e+04 |       0.01244 |       1.37105
# ----------------------------------
# | EpLenMean       | 222          |
# | EpRewMean       | -1.7e+03     |
# | EpThisIter      | 1            |
# | EpisodesSoFar   | 20           |
# | TimeElapsed     | 13.8         |
# | TimestepsSoFar  | 4608         |
# | ev_tdlam_before | 9.54e-06     |
# | loss_ent        | 1.3710475    |
# | loss_kl         | 0.012443828  |
# | loss_pol_entpen | -0.013710474 |
# | loss_pol_surr   | -0.017218202 |
# | loss_vf_loss    | 53067.906    |
# ----------------------------------
# ********** Iteration 18 ************
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#      -0.00090 |      -0.01366 |      5.79e+04 |      2.45e-05 |       1.36625
#      -0.00486 |      -0.01365 |      5.79e+04 |       0.00045 |       1.36537
#      -0.01212 |      -0.01364 |      5.78e+04 |       0.00210 |       1.36441
#      -0.01918 |      -0.01362 |      5.78e+04 |       0.00585 |       1.36199
# Evaluating losses...
#      -0.02330 |      -0.01359 |      5.77e+04 |       0.00915 |       1.35884
# ----------------------------------
# | EpLenMean       | 220          |
# | EpRewMean       | -1.67e+03    |
# | EpThisIter      | 1            |
# | EpisodesSoFar   | 21           |
# | TimeElapsed     | 14.5         |
# | TimestepsSoFar  | 4864         |
# | ev_tdlam_before | -4.29e-06    |
# | loss_ent        | 1.3588433    |
# | loss_kl         | 0.009146582  |
# | loss_pol_entpen | -0.013588433 |
# | loss_pol_surr   | -0.02330228  |
# | loss_vf_loss    | 57730.47     |
# ----------------------------------
# ********** Iteration 19 ************
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#       0.00040 |      -0.01349 |      3.33e+04 |       0.00019 |       1.34892
#      -0.00187 |      -0.01350 |      3.32e+04 |       0.00185 |       1.34987
#      -0.00452 |      -0.01350 |      3.31e+04 |       0.00572 |       1.35035
#      -0.00615 |      -0.01346 |      3.30e+04 |       0.00576 |       1.34582
# Evaluating losses...
#      -0.01040 |      -0.01341 |      3.30e+04 |       0.00643 |       1.34134
# ----------------------------------
# | EpLenMean       | 220          |
# | EpRewMean       | -1.67e+03    |
# | EpThisIter      | 0            |
# | EpisodesSoFar   | 21           |
# | TimeElapsed     | 15.1         |
# | TimestepsSoFar  | 5120         |
# | ev_tdlam_before | -2.47e-05    |
# | loss_ent        | 1.3413386    |
# | loss_kl         | 0.0064287046 |
# | loss_pol_entpen | -0.013413386 |
# | loss_pol_surr   | -0.010400446 |
# | loss_vf_loss    | 32954.92     |
# ----------------------------------
# ********** Iteration 20 ************
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#      9.95e-05 |      -0.01347 |      3.39e+04 |       0.00016 |       1.34711
#      -0.00352 |      -0.01345 |      3.38e+04 |       0.00154 |       1.34464
#      -0.00822 |      -0.01340 |      3.37e+04 |       0.00489 |       1.34011
#      -0.00926 |      -0.01332 |      3.36e+04 |       0.00882 |       1.33190
# Evaluating losses...
#      -0.01158 |      -0.01326 |      3.35e+04 |       0.01028 |       1.32609
# ----------------------------------
# | EpLenMean       | 220          |
# | EpRewMean       | -1.67e+03    |
# | EpThisIter      | 0            |
# | EpisodesSoFar   | 21           |
# | TimeElapsed     | 15.7         |
# | TimestepsSoFar  | 5376         |
# | ev_tdlam_before | -9.92e-05    |
# | loss_ent        | 1.3260901    |
# | loss_kl         | 0.010278178  |
# | loss_pol_entpen | -0.013260901 |
# | loss_pol_surr   | -0.011582978 |
# | loss_vf_loss    | 33497.766    |
# ----------------------------------
# ********** Iteration 21 ************
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#       0.00066 |      -0.01309 |      3.20e+04 |       0.00026 |       1.30887
#      -0.00751 |      -0.01291 |      3.19e+04 |       0.00239 |       1.29133
#      -0.01644 |      -0.01274 |      3.18e+04 |       0.00860 |       1.27399
#      -0.02162 |      -0.01262 |      3.17e+04 |       0.01794 |       1.26226
# Evaluating losses...
#      -0.02072 |      -0.01260 |      3.17e+04 |       0.02331 |       1.26038
# -----------------------------------
# | EpLenMean       | 256           |
# | EpRewMean       | -2.13e+03     |
# | EpThisIter      | 1             |
# | EpisodesSoFar   | 22            |
# | TimeElapsed     | 16.4          |
# | TimestepsSoFar  | 5632          |
# | ev_tdlam_before | -1.34e-05     |
# | loss_ent        | 1.2603817     |
# | loss_kl         | 0.023307871   |
# | loss_pol_entpen | -0.0126038175 |
# | loss_pol_surr   | -0.020722527  |
# | loss_vf_loss    | 31650.352     |
# -----------------------------------
# ********** Iteration 22 ************
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#       0.00235 |      -0.01287 |      5.45e+04 |       0.00011 |       1.28667
#       0.00016 |      -0.01281 |      5.44e+04 |       0.00035 |       1.28116
#      -0.00854 |      -0.01275 |      5.44e+04 |       0.00065 |       1.27480
#      -0.01725 |      -0.01269 |      5.43e+04 |       0.00332 |       1.26861
# Evaluating losses...
#      -0.02391 |      -0.01260 |      5.43e+04 |       0.00733 |       1.26015
# ----------------------------------
# | EpLenMean       | 247          |
# | EpRewMean       | -2.03e+03    |
# | EpThisIter      | 1            |
# | EpisodesSoFar   | 23           |
# | TimeElapsed     | 17           |
# | TimestepsSoFar  | 5888         |
# | ev_tdlam_before | 2.94e-05     |
# | loss_ent        | 1.2601478    |
# | loss_kl         | 0.007328624  |
# | loss_pol_entpen | -0.012601477 |
# | loss_pol_surr   | -0.02391203  |
# | loss_vf_loss    | 54293.867    |
# ----------------------------------
# ********** Iteration 23 ************
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#      -0.00138 |      -0.01241 |      3.56e+04 |       0.00055 |       1.24116
#      -0.00753 |      -0.01214 |      3.55e+04 |       0.00419 |       1.21371
#      -0.00598 |      -0.01173 |      3.54e+04 |       0.01353 |       1.17258
#      -0.00859 |      -0.01141 |      3.53e+04 |       0.02187 |       1.14136
# Evaluating losses...
#      -0.00929 |      -0.01140 |      3.52e+04 |       0.02201 |       1.13996
# ----------------------------------
# | EpLenMean       | 247          |
# | EpRewMean       | -2.03e+03    |
# | EpThisIter      | 0            |
# | EpisodesSoFar   | 23           |
# | TimeElapsed     | 17.7         |
# | TimestepsSoFar  | 6144         |
# | ev_tdlam_before | -4.65e-06    |
# | loss_ent        | 1.1399643    |
# | loss_kl         | 0.022011025  |
# | loss_pol_entpen | -0.011399643 |
# | loss_pol_surr   | -0.009290818 |
# | loss_vf_loss    | 35213.88     |
# ----------------------------------
# ********** Iteration 24 ************
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#      -0.00218 |      -0.01142 |      3.48e+04 |       0.00046 |       1.14242
#      -0.01375 |      -0.01183 |      3.47e+04 |       0.00472 |       1.18301
#      -0.01112 |      -0.01212 |      3.46e+04 |       0.01216 |       1.21165
#      -0.01292 |      -0.01197 |      3.45e+04 |       0.01280 |       1.19719
# Evaluating losses...
#      -0.01821 |      -0.01172 |      3.44e+04 |       0.01090 |       1.17180
# ----------------------------------
# | EpLenMean       | 247          |
# | EpRewMean       | -2.03e+03    |
# | EpThisIter      | 0            |
# | EpisodesSoFar   | 23           |
# | TimeElapsed     | 18.3         |
# | TimestepsSoFar  | 6400         |
# | ev_tdlam_before | -1.07e-06    |
# | loss_ent        | 1.1718044    |
# | loss_kl         | 0.010902595  |
# | loss_pol_entpen | -0.011718044 |
# | loss_pol_surr   | -0.018210527 |
# | loss_vf_loss    | 34427.23     |
# ----------------------------------
# ********** Iteration 25 ************
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#       0.00021 |      -0.01166 |      3.41e+04 |       0.00049 |       1.16561
#      -0.00254 |      -0.01130 |      3.39e+04 |       0.00348 |       1.12991
#      -0.00749 |      -0.01106 |      3.38e+04 |       0.00761 |       1.10598
#      -0.01068 |      -0.01101 |      3.37e+04 |       0.01041 |       1.10093
# Evaluating losses...
#      -0.01278 |      -0.01109 |      3.37e+04 |       0.01103 |       1.10902
# ----------------------------------
# | EpLenMean       | 247          |
# | EpRewMean       | -2.03e+03    |
# | EpThisIter      | 0            |
# | EpisodesSoFar   | 23           |
# | TimeElapsed     | 19           |
# | TimestepsSoFar  | 6656         |
# | ev_tdlam_before | 2.47e-05     |
# | loss_ent        | 1.1090151    |
# | loss_kl         | 0.011026891  |
# | loss_pol_entpen | -0.011090151 |
# | loss_pol_surr   | -0.012776017 |
# | loss_vf_loss    | 33660.062    |
# ----------------------------------
# ********** Iteration 26 ************
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#       0.00030 |      -0.01170 |      3.54e+04 |       0.00015 |       1.16981
#      -0.00550 |      -0.01141 |      3.53e+04 |       0.00213 |       1.14064
#      -0.01322 |      -0.01088 |      3.52e+04 |       0.01087 |       1.08800
#      -0.01602 |      -0.01068 |      3.51e+04 |       0.01541 |       1.06829
# Evaluating losses...
#      -0.01969 |      -0.01092 |      3.50e+04 |       0.01024 |       1.09192
# ----------------------------------
# | EpLenMean       | 279          |
# | EpRewMean       | -2.44e+03    |
# | EpThisIter      | 1            |
# | EpisodesSoFar   | 24           |
# | TimeElapsed     | 19.6         |
# | TimestepsSoFar  | 6912         |
# | ev_tdlam_before | -0.000142    |
# | loss_ent        | 1.0919192    |
# | loss_kl         | 0.010241151  |
# | loss_pol_entpen | -0.010919191 |
# | loss_pol_surr   | -0.019688569 |
# | loss_vf_loss    | 34986.863    |
# ----------------------------------
# ********** Iteration 27 ************
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#       0.00085 |      -0.01119 |      3.98e+04 |       0.00088 |       1.11882
#      -0.00380 |      -0.01172 |      3.97e+04 |       0.00680 |       1.17165
#      -0.00636 |      -0.01190 |      3.95e+04 |       0.01065 |       1.18996
#      -0.00984 |      -0.01165 |      3.94e+04 |       0.00701 |       1.16500
# Evaluating losses...
#      -0.01489 |      -0.01143 |      3.94e+04 |       0.00519 |       1.14324
# -----------------------------------
# | EpLenMean       | 279           |
# | EpRewMean       | -2.44e+03     |
# | EpThisIter      | 0             |
# | EpisodesSoFar   | 24            |
# | TimeElapsed     | 20.2          |
# | TimestepsSoFar  | 7168          |
# | ev_tdlam_before | -1.14e-05     |
# | loss_ent        | 1.1432412     |
# | loss_kl         | 0.005191159   |
# | loss_pol_entpen | -0.011432411  |
# | loss_pol_surr   | -0.0148934405 |
# | loss_vf_loss    | 39351.023     |
# -----------------------------------
# ********** Iteration 28 ************
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#      -0.00293 |      -0.01150 |      4.04e+04 |       0.00030 |       1.14975
#      -0.01974 |      -0.01091 |      4.03e+04 |       0.00625 |       1.09072
#      -0.02261 |      -0.01013 |      4.01e+04 |       0.02391 |       1.01312
#      -0.01987 |      -0.01007 |      4.00e+04 |       0.02748 |       1.00736
# Evaluating losses...
#      -0.02234 |      -0.01038 |      3.99e+04 |       0.02083 |       1.03776
# ----------------------------------
# | EpLenMean       | 279          |
# | EpRewMean       | -2.44e+03    |
# | EpThisIter      | 0            |
# | EpisodesSoFar   | 24           |
# | TimeElapsed     | 20.9         |
# | TimestepsSoFar  | 7424         |
# | ev_tdlam_before | 7.59e-05     |
# | loss_ent        | 1.0377593    |
# | loss_kl         | 0.020829896  |
# | loss_pol_entpen | -0.010377593 |
# | loss_pol_surr   | -0.022335004 |
# | loss_vf_loss    | 39933.17     |
# ----------------------------------
# ********** Iteration 29 ************
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#      -0.00071 |      -0.01047 |      3.98e+04 |       0.00073 |       1.04743
#      -0.00488 |      -0.01095 |      3.97e+04 |       0.00525 |       1.09519
#      -0.00299 |      -0.01111 |      3.95e+04 |       0.00909 |       1.11088
#      -0.00769 |      -0.01089 |      3.94e+04 |       0.00662 |       1.08877
# Evaluating losses...
#      -0.00923 |      -0.01066 |      3.93e+04 |       0.00452 |       1.06640
# ----------------------------------
# | EpLenMean       | 279          |
# | EpRewMean       | -2.44e+03    |
# | EpThisIter      | 0            |
# | EpisodesSoFar   | 24           |
# | TimeElapsed     | 21.5         |
# | TimestepsSoFar  | 7680         |
# | ev_tdlam_before | -2.5e-05     |
# | loss_ent        | 1.0663986    |
# | loss_kl         | 0.004522648  |
# | loss_pol_entpen | -0.010663986 |
# | loss_pol_surr   | -0.009226295 |
# | loss_vf_loss    | 39331.85     |
# ----------------------------------
# ********** Iteration 30 ************
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#      8.05e-05 |      -0.01094 |      3.05e+04 |      6.31e-05 |       1.09358
#      -0.00619 |      -0.01101 |      3.04e+04 |       0.00070 |       1.10102
#      -0.01816 |      -0.01138 |      3.03e+04 |       0.00504 |       1.13791
#      -0.01849 |      -0.01152 |      3.02e+04 |       0.00965 |       1.15219
# Evaluating losses...
#      -0.02029 |      -0.01144 |      3.01e+04 |       0.01000 |       1.14370
# ----------------------------------
# | EpLenMean       | 308          |
# | EpRewMean       | -2.86e+03    |
# | EpThisIter      | 1            |
# | EpisodesSoFar   | 25           |
# | TimeElapsed     | 22.2         |
# | TimestepsSoFar  | 7936         |
# | ev_tdlam_before | -0.000399    |
# | loss_ent        | 1.1436993    |
# | loss_kl         | 0.009995796  |
# | loss_pol_entpen | -0.011436992 |
# | loss_pol_surr   | -0.02029134  |
# | loss_vf_loss    | 30110.516    |
# ----------------------------------
# ********** Iteration 31 ************
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#       0.00029 |      -0.01086 |      3.13e+04 |       0.00011 |       1.08580
#      -0.00303 |      -0.01096 |      3.12e+04 |       0.00092 |       1.09618
#      -0.00232 |      -0.01141 |      3.11e+04 |       0.00773 |       1.14085
#      -0.00058 |      -0.01174 |      3.10e+04 |       0.01650 |       1.17377
# Evaluating losses...
#      -0.00348 |      -0.01166 |      3.10e+04 |       0.01424 |       1.16563
# -----------------------------------
# | EpLenMean       | 308           |
# | EpRewMean       | -2.86e+03     |
# | EpThisIter      | 0             |
# | EpisodesSoFar   | 25            |
# | TimeElapsed     | 22.8          |
# | TimestepsSoFar  | 8192          |
# | ev_tdlam_before | 2.94e-05      |
# | loss_ent        | 1.1656286     |
# | loss_kl         | 0.014241743   |
# | loss_pol_entpen | -0.011656285  |
# | loss_pol_surr   | -0.0034783892 |
# | loss_vf_loss    | 30959.844     |
# -----------------------------------
# ********** Iteration 32 ************
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#       0.00059 |      -0.01183 |      3.14e+04 |       0.00031 |       1.18308
#      -0.00177 |      -0.01162 |      3.13e+04 |       0.00198 |       1.16219
#      -0.00807 |      -0.01160 |      3.12e+04 |       0.00390 |       1.15958
#      -0.01171 |      -0.01163 |      3.11e+04 |       0.00861 |       1.16336
# Evaluating losses...
#      -0.01037 |      -0.01166 |      3.10e+04 |       0.01210 |       1.16557
# ----------------------------------
# | EpLenMean       | 308          |
# | EpRewMean       | -2.86e+03    |
# | EpThisIter      | 0            |
# | EpisodesSoFar   | 25           |
# | TimeElapsed     | 23.4         |
# | TimestepsSoFar  | 8448         |
# | ev_tdlam_before | 0.000267     |
# | loss_ent        | 1.1655693    |
# | loss_kl         | 0.012099373  |
# | loss_pol_entpen | -0.011655694 |
# | loss_pol_surr   | -0.010366328 |
# | loss_vf_loss    | 31038.217    |
# ----------------------------------
# ********** Iteration 33 ************
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#       0.00086 |      -0.01121 |      2.92e+04 |       0.00014 |       1.12100
#      -0.00937 |      -0.01076 |      2.91e+04 |       0.00375 |       1.07634
#      -0.01525 |      -0.01005 |      2.90e+04 |       0.01913 |       1.00480
#      -0.01683 |      -0.00994 |      2.89e+04 |       0.02377 |       0.99397
# Evaluating losses...
#      -0.02152 |      -0.01025 |      2.89e+04 |       0.01622 |       1.02486
# ----------------------------------
# | EpLenMean       | 334          |
# | EpRewMean       | -3.19e+03    |
# | EpThisIter      | 1            |
# | EpisodesSoFar   | 26           |
# | TimeElapsed     | 24.1         |
# | TimestepsSoFar  | 8704         |
# | ev_tdlam_before | 8.11e-06     |
# | loss_ent        | 1.0248568    |
# | loss_kl         | 0.016216304  |
# | loss_pol_entpen | -0.010248567 |
# | loss_pol_surr   | -0.021517858 |
# | loss_vf_loss    | 28883.979    |
# ----------------------------------
# ********** Iteration 34 ************
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#      -0.00402 |      -0.01058 |      3.33e+04 |       0.00096 |       1.05804
#      -0.00864 |      -0.01125 |      3.32e+04 |       0.01152 |       1.12546
#      -0.00395 |      -0.01148 |      3.31e+04 |       0.01854 |       1.14784
#      -0.01010 |      -0.01118 |      3.30e+04 |       0.01013 |       1.11800
# Evaluating losses...
#      -0.01243 |      -0.01102 |      3.29e+04 |       0.00724 |       1.10245
# ----------------------------------
# | EpLenMean       | 334          |
# | EpRewMean       | -3.19e+03    |
# | EpThisIter      | 0            |
# | EpisodesSoFar   | 26           |
# | TimeElapsed     | 24.7         |
# | TimestepsSoFar  | 8960         |
# | ev_tdlam_before | -5.96e-06    |
# | loss_ent        | 1.1024518    |
# | loss_kl         | 0.0072441986 |
# | loss_pol_entpen | -0.011024517 |
# | loss_pol_surr   | -0.012434324 |
# | loss_vf_loss    | 32907.258    |
# ----------------------------------
# ********** Iteration 35 ************
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#      -0.00058 |      -0.01062 |      3.31e+04 |       0.00012 |       1.06215
#      -0.00317 |      -0.01057 |      3.30e+04 |       0.00070 |       1.05728
#      -0.00548 |      -0.01066 |      3.29e+04 |       0.00328 |       1.06628
#      -0.00407 |      -0.01074 |      3.28e+04 |       0.00783 |       1.07399
# Evaluating losses...
#      -0.00535 |      -0.01063 |      3.27e+04 |       0.00761 |       1.06279
# ----------------------------------
# | EpLenMean       | 334          |
# | EpRewMean       | -3.19e+03    |
# | EpThisIter      | 0            |
# | EpisodesSoFar   | 26           |
# | TimeElapsed     | 25.4         |
# | TimestepsSoFar  | 9216         |
# | ev_tdlam_before | 8.52e-06     |
# | loss_ent        | 1.0627942    |
# | loss_kl         | 0.0076055345 |
# | loss_pol_entpen | -0.010627942 |
# | loss_pol_surr   | -0.005345566 |
# | loss_vf_loss    | 32712.582    |
# ----------------------------------
# ********** Iteration 36 ************
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#       0.00150 |      -0.01053 |      3.29e+04 |       0.00017 |       1.05340
#      -0.00139 |      -0.01063 |      3.28e+04 |       0.00066 |       1.06348
#      -0.00729 |      -0.01097 |      3.27e+04 |       0.00437 |       1.09726
#      -0.00289 |      -0.01149 |      3.26e+04 |       0.01775 |       1.14858
# Evaluating losses...
#      -0.00169 |      -0.01161 |      3.26e+04 |       0.02161 |       1.16092
# -----------------------------------
# | EpLenMean       | 334           |
# | EpRewMean       | -3.19e+03     |
# | EpThisIter      | 0             |
# | EpisodesSoFar   | 26            |
# | TimeElapsed     | 26.1          |
# | TimestepsSoFar  | 9472          |
# | ev_tdlam_before | -9.3e-06      |
# | loss_ent        | 1.1609204     |
# | loss_kl         | 0.02161032    |
# | loss_pol_entpen | -0.011609204  |
# | loss_pol_surr   | -0.0016914713 |
# | loss_vf_loss    | 32577.594     |
# -----------------------------------
# ********** Iteration 37 ************
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#       0.00100 |      -0.01163 |      2.99e+04 |       0.00014 |       1.16290
#      -0.00127 |      -0.01166 |      2.98e+04 |       0.00033 |       1.16610
#      -0.00659 |      -0.01176 |      2.97e+04 |       0.00058 |       1.17582
#      -0.01176 |      -0.01189 |      2.96e+04 |       0.00141 |       1.18917
# Evaluating losses...
#      -0.01262 |      -0.01195 |      2.95e+04 |       0.00226 |       1.19520
# ----------------------------------
# | EpLenMean       | 359          |
# | EpRewMean       | -3.51e+03    |
# | EpThisIter      | 1            |
# | EpisodesSoFar   | 27           |
# | TimeElapsed     | 26.7         |
# | TimestepsSoFar  | 9728         |
# | ev_tdlam_before | -1.3e-05     |
# | loss_ent        | 1.1951988    |
# | loss_kl         | 0.0022567788 |
# | loss_pol_entpen | -0.011951987 |
# | loss_pol_surr   | -0.012624206 |
# | loss_vf_loss    | 29548.973    |
# ----------------------------------
# ********** Iteration 38 ************
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#      -0.00204 |      -0.01169 |      3.32e+04 |       0.00031 |       1.16919
#      -0.00921 |      -0.01208 |      3.31e+04 |       0.00785 |       1.20753
#      -0.00802 |      -0.01236 |      3.30e+04 |       0.02422 |       1.23615
#      -0.01048 |      -0.01239 |      3.29e+04 |       0.01917 |       1.23867
# Evaluating losses...
#      -0.01302 |      -0.01232 |      3.29e+04 |       0.01176 |       1.23163
# ----------------------------------
# | EpLenMean       | 359          |
# | EpRewMean       | -3.51e+03    |
# | EpThisIter      | 0            |
# | EpisodesSoFar   | 27           |
# | TimeElapsed     | 27.4         |
# | TimestepsSoFar  | 9984         |
# | ev_tdlam_before | -1.43e-06    |
# | loss_ent        | 1.2316346    |
# | loss_kl         | 0.011761101  |
# | loss_pol_entpen | -0.012316346 |
# | loss_pol_surr   | -0.013023006 |
# | loss_vf_loss    | 32872.22     |
# ----------------------------------
# ********** Iteration 39 ************
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#      -0.00078 |      -0.01220 |      3.34e+04 |       0.00052 |       1.22026
#      -0.00399 |      -0.01200 |      3.33e+04 |       0.00448 |       1.19994
#      -0.00693 |      -0.01181 |      3.32e+04 |       0.01145 |       1.18113
#      -0.00824 |      -0.01181 |      3.31e+04 |       0.01116 |       1.18148
# Evaluating losses...
#      -0.00936 |      -0.01186 |      3.31e+04 |       0.00938 |       1.18606
# ----------------------------------
# | EpLenMean       | 359          |
# | EpRewMean       | -3.51e+03    |
# | EpThisIter      | 0            |
# | EpisodesSoFar   | 27           |
# | TimeElapsed     | 28           |
# | TimestepsSoFar  | 10240        |
# | ev_tdlam_before | -1.43e-06    |
# | loss_ent        | 1.1860586    |
# | loss_kl         | 0.009375606  |
# | loss_pol_entpen | -0.011860587 |
# | loss_pol_surr   | -0.009361438 |
# | loss_vf_loss    | 33076.984    |
# ----------------------------------
# ********** Iteration 40 ************
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#       0.00015 |      -0.01190 |      3.32e+04 |      3.66e-05 |       1.18983
#      -0.00076 |      -0.01194 |      3.31e+04 |       0.00047 |       1.19351
#      -0.00204 |      -0.01201 |      3.30e+04 |       0.00161 |       1.20077
#      -0.00284 |      -0.01205 |      3.29e+04 |       0.00359 |       1.20535
# Evaluating losses...
#      -0.00466 |      -0.01207 |      3.28e+04 |       0.00503 |       1.20698
# -----------------------------------
# | EpLenMean       | 359           |
# | EpRewMean       | -3.51e+03     |
# | EpThisIter      | 0             |
# | EpisodesSoFar   | 27            |
# | TimeElapsed     | 28.7          |
# | TimestepsSoFar  | 10496         |
# | ev_tdlam_before | -3.34e-06     |
# | loss_ent        | 1.206982      |
# | loss_kl         | 0.005029502   |
# | loss_pol_entpen | -0.0120698195 |
# | loss_pol_surr   | -0.00466381   |
# | loss_vf_loss    | 32817.56      |
# -----------------------------------
# ********** Iteration 41 ************
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#       0.00059 |      -0.01219 |      5.45e+04 |      5.72e-05 |       1.21940
#      -0.00139 |      -0.01226 |      5.44e+04 |       0.00045 |       1.22606
#      -0.00396 |      -0.01234 |      5.44e+04 |       0.00162 |       1.23378
#      -0.00845 |      -0.01242 |      5.44e+04 |       0.00399 |       1.24220
# Evaluating losses...
#      -0.00988 |      -0.01246 |      5.43e+04 |       0.00581 |       1.24646
# ----------------------------------
# | EpLenMean       | 370          |
# | EpRewMean       | -3.65e+03    |
# | EpThisIter      | 2            |
# | EpisodesSoFar   | 29           |
# | TimeElapsed     | 29.3         |
# | TimestepsSoFar  | 10752        |
# | ev_tdlam_before | 3.19e-05     |
# | loss_ent        | 1.246464     |
# | loss_kl         | 0.0058076615 |
# | loss_pol_entpen | -0.01246464  |
# | loss_pol_surr   | -0.009876745 |
# | loss_vf_loss    | 54336.426    |
# ----------------------------------
# ********** Iteration 42 ************
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#       0.00053 |      -0.01266 |      3.78e+04 |       0.00027 |       1.26569
#      -0.01041 |      -0.01275 |      3.77e+04 |       0.00253 |       1.27498
#      -0.01944 |      -0.01280 |      3.76e+04 |       0.00811 |       1.27976
#      -0.02569 |      -0.01277 |      3.75e+04 |       0.01457 |       1.27719
# Evaluating losses...
#      -0.02474 |      -0.01271 |      3.74e+04 |       0.01704 |       1.27147
# ----------------------------------
# | EpLenMean       | 370          |
# | EpRewMean       | -3.65e+03    |
# | EpThisIter      | 0            |
# ...
# | loss_kl         | 3.3402314e-06  |
# | loss_pol_entpen | -0.006441546   |
# | loss_pol_surr   | -0.00012076832 |
# | loss_vf_loss    | 44816.508      |
# ------------------------------------
# ********** Iteration 767 ************
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#       0.00020 |      -0.00653 |      5.36e+04 |      4.73e-06 |       0.65313
#       0.00021 |      -0.00654 |      5.21e+04 |      6.74e-06 |       0.65383
#      3.91e-05 |      -0.00651 |      5.07e+04 |      2.54e-06 |       0.65095
#     -6.20e-05 |      -0.00653 |      4.94e+04 |      4.20e-06 |       0.65303
# Evaluating losses...
#     -6.88e-05 |      -0.00655 |      4.86e+04 |      9.39e-06 |       0.65499
# -----------------------------------
# | EpLenMean       | 6.83          |
# | EpRewMean       | 922           |
# | EpThisIter      | 0             |
# | EpisodesSoFar   | 5987          |
# | TimeElapsed     | 360           |
# | TimestepsSoFar  | 196608        |
# | ev_tdlam_before | -7.07         |
# | loss_ent        | 0.65499073    |
# | loss_kl         | 9.393594e-06  |
# | loss_pol_entpen | -0.006549907  |
# | loss_pol_surr   | -6.882846e-05 |
# | loss_vf_loss    | 48589.55      |
# -----------------------------------
# ********** Iteration 768 ************
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#      2.55e-05 |      -0.00627 |      2.09e+05 |      2.40e-07 |       0.62746
#     -6.32e-05 |      -0.00628 |      2.09e+05 |      7.16e-07 |       0.62768
#      -0.00019 |      -0.00627 |      2.09e+05 |      6.25e-07 |       0.62735
#      -0.00028 |      -0.00627 |      2.09e+05 |      1.75e-06 |       0.62699
# Evaluating losses...
#      -0.00038 |      -0.00627 |      2.09e+05 |      2.06e-06 |       0.62702
# -----------------------------------
# | EpLenMean       | 14            |
# | EpRewMean       | 829           |
# | EpThisIter      | 12            |
# | EpisodesSoFar   | 5999          |
# | TimeElapsed     | 360           |
# | TimestepsSoFar  | 196864        |
# | ev_tdlam_before | 0.00567       |
# | loss_ent        | 0.62701654    |
# | loss_kl         | 2.0636694e-06 |
# | loss_pol_entpen | -0.006270165  |
# | loss_pol_surr   | -0.0003849985 |
# | loss_vf_loss    | 209055.97     |
# -----------------------------------
# ********** Iteration 769 ************
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#      9.49e-06 |      -0.00940 |      1.42e+05 |      1.08e-07 |       0.94007
#      -0.00025 |      -0.00940 |      1.42e+05 |      1.66e-06 |       0.94016
#      -0.00025 |      -0.00940 |      1.42e+05 |      4.65e-06 |       0.94001
#      -0.00036 |      -0.00940 |      1.42e+05 |      3.23e-06 |       0.93969
# Evaluating losses...
#      -0.00040 |      -0.00940 |      1.42e+05 |      3.23e-06 |       0.93961
# -----------------------------------
# | EpLenMean       | 15            |
# | EpRewMean       | 816           |
# | EpThisIter      | 5             |
# | EpisodesSoFar   | 6004          |
# | TimeElapsed     | 361           |
# | TimestepsSoFar  | 197120        |
# | ev_tdlam_before | 0.0494        |
# | loss_ent        | 0.9396148     |
# | loss_kl         | 3.2327894e-06 |
# | loss_pol_entpen | -0.009396147  |
# | loss_pol_surr   | -0.0004029125 |
# | loss_vf_loss    | 142225.31     |
# -----------------------------------
# ********** Iteration 770 ************
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#     -8.05e-05 |      -0.01066 |      8.40e+04 |      5.90e-07 |       1.06603
#     -7.74e-05 |      -0.01066 |      8.39e+04 |      5.75e-06 |       1.06629
#      -0.00016 |      -0.01066 |      8.38e+04 |      3.21e-06 |       1.06611
#     -8.12e-05 |      -0.01066 |      8.37e+04 |      1.51e-06 |       1.06599
# Evaluating losses...
#      -0.00028 |      -0.01066 |      8.37e+04 |      2.38e-06 |       1.06622
# ------------------------------------
# | EpLenMean       | 15             |
# | EpRewMean       | 816            |
# | EpThisIter      | 0              |
# | EpisodesSoFar   | 6004           |
# | TimeElapsed     | 361            |
# | TimestepsSoFar  | 197376         |
# | ev_tdlam_before | -5.73          |
# | loss_ent        | 1.0662198      |
# | loss_kl         | 2.375931e-06   |
# | loss_pol_entpen | -0.010662196   |
# | loss_pol_surr   | -0.00027736835 |
# | loss_vf_loss    | 83663.38       |
# ------------------------------------
# ********** Iteration 771 ************
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#     -5.60e-07 |      -0.01020 |      9.91e+04 |      1.01e-06 |       1.02011
#     -1.50e-05 |      -0.01020 |      9.90e+04 |      4.50e-06 |       1.02044
#     -1.95e-05 |      -0.01020 |      9.88e+04 |      1.87e-06 |       1.02009
#      -0.00013 |      -0.01020 |      9.87e+04 |      1.26e-06 |       1.01996
# Evaluating losses...
#      -0.00014 |      -0.01020 |      9.86e+04 |      1.74e-06 |       1.02020
# ------------------------------------
# | EpLenMean       | 15             |
# | EpRewMean       | 816            |
# | EpThisIter      | 0              |
# | EpisodesSoFar   | 6004           |
# | TimeElapsed     | 362            |
# | TimestepsSoFar  | 197632         |
# | ev_tdlam_before | -26.5          |
# | loss_ent        | 1.0201957      |
# | loss_kl         | 1.7387487e-06  |
# | loss_pol_entpen | -0.010201958   |
# | loss_pol_surr   | -0.00014350377 |
# | loss_vf_loss    | 98559.94       |
# ------------------------------------
# ********** Iteration 772 ************
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#      3.84e-05 |      -0.01064 |      9.18e+04 |      6.26e-07 |       1.06362
#     -3.49e-05 |      -0.01064 |      9.16e+04 |      2.80e-06 |       1.06393
#      -0.00014 |      -0.01064 |      9.15e+04 |      1.24e-06 |       1.06380
#      -0.00014 |      -0.01064 |      9.14e+04 |      1.36e-06 |       1.06356
# Evaluating losses...
#      -0.00016 |      -0.01064 |      9.13e+04 |      2.07e-06 |       1.06358
# ------------------------------------
# | EpLenMean       | 15             |
# | EpRewMean       | 816            |
# | EpThisIter      | 0              |
# | EpisodesSoFar   | 6004           |
# | TimeElapsed     | 362            |
# | TimestepsSoFar  | 197888         |
# | ev_tdlam_before | -49.1          |
# | loss_ent        | 1.0635765      |
# | loss_kl         | 2.0743669e-06  |
# | loss_pol_entpen | -0.010635765   |
# | loss_pol_surr   | -0.00016317703 |
# | loss_vf_loss    | 91270.336      |
# ------------------------------------
# ********** Iteration 773 ************
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#     -1.03e-05 |      -0.00763 |      2.14e+05 |      2.08e-07 |       0.76285
#      -0.00018 |      -0.00763 |      2.14e+05 |      1.14e-06 |       0.76297
#      -0.00022 |      -0.00763 |      2.14e+05 |      2.03e-06 |       0.76306
#      -0.00023 |      -0.00763 |      2.14e+05 |      1.99e-06 |       0.76310
# Evaluating losses...
#      -0.00029 |      -0.00763 |      2.14e+05 |      1.96e-06 |       0.76316
# ------------------------------------
# | EpLenMean       | 25.6           |
# | EpRewMean       | 663            |
# | EpThisIter      | 16             |
# | EpisodesSoFar   | 6020           |
# | TimeElapsed     | 363            |
# | TimestepsSoFar  | 198144         |
# | ev_tdlam_before | 0.211          |
# | loss_ent        | 0.763157       |
# | loss_kl         | 1.957355e-06   |
# | loss_pol_entpen | -0.0076315696  |
# | loss_pol_surr   | -0.00029246975 |
# | loss_vf_loss    | 214088.34      |
# ------------------------------------
# ********** Iteration 774 ************
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#      1.27e-06 |      -0.00554 |      3.45e+05 |      2.17e-08 |       0.55439
#     -6.35e-05 |      -0.00554 |      3.44e+05 |      2.53e-07 |       0.55439
#     -9.24e-05 |      -0.00554 |      3.44e+05 |      8.92e-07 |       0.55434
#      -0.00012 |      -0.00554 |      3.44e+05 |      1.15e-06 |       0.55431
# Evaluating losses...
#      -0.00018 |      -0.00554 |      3.44e+05 |      8.87e-07 |       0.55433
# -----------------------------------
# | EpLenMean       | 26.3          |
# | EpRewMean       | 654           |
# | EpThisIter      | 32            |
# | EpisodesSoFar   | 6052          |
# | TimeElapsed     | 363           |
# | TimestepsSoFar  | 198400        |
# | ev_tdlam_before | -0.0355       |
# | loss_ent        | 0.5543296     |
# | loss_kl         | 8.870244e-07  |
# | loss_pol_entpen | -0.0055432958 |
# | loss_pol_surr   | -0.0001792498 |
# | loss_vf_loss    | 343581.28     |
# -----------------------------------
# ********** Iteration 775 ************
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#     -3.90e-05 |      -0.00790 |      2.74e+05 |      4.23e-08 |       0.78995
#      -0.00014 |      -0.00790 |      2.74e+05 |      5.88e-07 |       0.78987
#      -0.00017 |      -0.00790 |      2.74e+05 |      1.01e-06 |       0.78985
#      -0.00020 |      -0.00790 |      2.74e+05 |      5.85e-07 |       0.78983
# Evaluating losses...
#      -0.00022 |      -0.00790 |      2.74e+05 |      4.53e-07 |       0.78983
# ------------------------------------
# | EpLenMean       | 26.9           |
# | EpRewMean       | 646            |
# | EpThisIter      | 24             |
# | EpisodesSoFar   | 6076           |
# | TimeElapsed     | 363            |
# | TimestepsSoFar  | 198656         |
# | ev_tdlam_before | -0.000347      |
# | loss_ent        | 0.78982806     |
# | loss_kl         | 4.528558e-07   |
# | loss_pol_entpen | -0.00789828    |
# | loss_pol_surr   | -0.00021989085 |
# | loss_vf_loss    | 273864.56      |
# ------------------------------------
# ********** Iteration 776 ************
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#      4.23e-06 |      -0.00516 |      2.57e+05 |     -4.87e-09 |       0.51561
#     -5.35e-05 |      -0.00516 |      2.57e+05 |      7.33e-08 |       0.51566
#      -0.00011 |      -0.00516 |      2.57e+05 |      2.00e-07 |       0.51577
#      -0.00015 |      -0.00516 |      2.57e+05 |      4.57e-07 |       0.51591
# Evaluating losses...
#      -0.00018 |      -0.00516 |      2.57e+05 |      6.48e-07 |       0.51601
# ------------------------------------
# | EpLenMean       | 19.6           |
# | EpRewMean       | 743            |
# | EpThisIter      | 27             |
# | EpisodesSoFar   | 6103           |
# | TimeElapsed     | 364            |
# | TimestepsSoFar  | 198912         |
# | ev_tdlam_before | 0.538          |
# | loss_ent        | 0.5160117      |
# | loss_kl         | 6.481987e-07   |
# | loss_pol_entpen | -0.0051601166  |
# | loss_pol_surr   | -0.00017968565 |
# | loss_vf_loss    | 256528.12      |
# ------------------------------------
# ********** Iteration 777 ************
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#     -1.92e-05 |      -0.00703 |      2.68e+05 |      3.98e-08 |       0.70306
#     -9.20e-05 |      -0.00703 |      2.68e+05 |      2.53e-07 |       0.70313
#     -9.46e-05 |      -0.00703 |      2.68e+05 |      4.44e-07 |       0.70319
#      -0.00012 |      -0.00703 |      2.68e+05 |      4.97e-07 |       0.70324
# Evaluating losses...
#      -0.00015 |      -0.00703 |      2.67e+05 |      4.69e-07 |       0.70324
# ------------------------------------
# | EpLenMean       | 9.5            |
# | EpRewMean       | 889            |
# | EpThisIter      | 24             |
# | EpisodesSoFar   | 6127           |
# | TimeElapsed     | 364            |
# | TimestepsSoFar  | 199168         |
# | ev_tdlam_before | 0.251          |
# | loss_ent        | 0.7032354      |
# | loss_kl         | 4.6853822e-07  |
# | loss_pol_entpen | -0.007032354   |
# | loss_pol_surr   | -0.00014662743 |
# | loss_vf_loss    | 267491.94      |
# ------------------------------------
# ********** Iteration 778 ************
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#      4.48e-07 |      -0.00587 |      6.59e+04 |     -3.43e-08 |       0.58666
#     -3.32e-05 |      -0.00586 |      6.59e+04 |     -2.54e-10 |       0.58649
#     -5.98e-05 |      -0.00587 |      6.58e+04 |      2.43e-08 |       0.58667
#     -6.00e-05 |      -0.00587 |      6.58e+04 |      8.85e-08 |       0.58708
# Evaluating losses...
#     -6.20e-05 |      -0.00587 |      6.58e+04 |      1.59e-07 |       0.58720
# -----------------------------------
# | EpLenMean       | 9.94          |
# | EpRewMean       | 883           |
# | EpThisIter      | 3             |
# | EpisodesSoFar   | 6130          |
# | TimeElapsed     | 365           |
# | TimestepsSoFar  | 199424        |
# | ev_tdlam_before | 0.553         |
# | loss_ent        | 0.5872029     |
# | loss_kl         | 1.593206e-07  |
# | loss_pol_entpen | -0.0058720293 |
# | loss_pol_surr   | -6.19567e-05  |
# | loss_vf_loss    | 65831.09      |
# -----------------------------------
# ********** Iteration 779 ************
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#      1.63e-06 |      -0.00573 |      2.25e+04 |      2.11e-08 |       0.57260
#      8.64e-06 |      -0.00573 |      2.25e+04 |      5.16e-08 |       0.57278
#     -5.94e-06 |      -0.00573 |      2.25e+04 |      3.29e-08 |       0.57264
#     -2.09e-06 |      -0.00572 |      2.25e+04 |      5.18e-08 |       0.57238
# Evaluating losses...
#     -3.65e-06 |      -0.00572 |      2.25e+04 |      8.29e-08 |       0.57232
# ------------------------------------
# | EpLenMean       | 9.94           |
# | EpRewMean       | 883            |
# | EpThisIter      | 0              |
# | EpisodesSoFar   | 6130           |
# | TimeElapsed     | 365            |
# | TimestepsSoFar  | 199680         |
# | ev_tdlam_before | -0.325         |
# | loss_ent        | 0.5723187      |
# | loss_kl         | 8.287233e-08   |
# | loss_pol_entpen | -0.005723187   |
# | loss_pol_surr   | -3.6451966e-06 |
# | loss_vf_loss    | 22507.043      |
# ------------------------------------
# ********** Iteration 780 ************
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#      5.16e-06 |      -0.00572 |      2.25e+04 |     -5.57e-08 |       0.57232
#     -7.63e-06 |      -0.00572 |      2.25e+04 |     -1.55e-08 |       0.57234
#     -9.37e-06 |      -0.00572 |      2.25e+04 |      9.33e-10 |       0.57235
#     -8.47e-06 |      -0.00572 |      2.25e+04 |     -4.03e-08 |       0.57225
# Evaluating losses...
#     -8.54e-06 |      -0.00572 |      2.25e+04 |      5.61e-09 |       0.57218
# -----------------------------------
# | EpLenMean       | 9.94          |
# | EpRewMean       | 883           |
# | EpThisIter      | 0             |
# | EpisodesSoFar   | 6130          |
# | TimeElapsed     | 366           |
# | TimestepsSoFar  | 199936        |
# | ev_tdlam_before | -0.324        |
# | loss_ent        | 0.5721835     |
# | loss_kl         | 5.60928e-09   |
# | loss_pol_entpen | -0.0057218345 |
# | loss_pol_surr   | -8.538365e-06 |
# | loss_vf_loss    | 22538.338     |
# -----------------------------------
# ********** Iteration 781 ************
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#      6.18e-07 |      -0.00572 |      2.23e+04 |      7.55e-10 |       0.57221
#      9.28e-07 |      -0.00572 |      2.23e+04 |      3.21e-09 |       0.57219
#      2.30e-07 |      -0.00572 |      2.23e+04 |     -5.26e-09 |       0.57218
#      2.98e-08 |      -0.00572 |      2.23e+04 |      9.24e-11 |       0.57221
# Evaluating losses...
#      8.92e-07 |      -0.00572 |      2.23e+04 |     -2.53e-08 |       0.57223
# ------------------------------------
# | EpLenMean       | 9.94           |
# | EpRewMean       | 883            |
# | EpThisIter      | 0              |
# | EpisodesSoFar   | 6130           |
# | TimeElapsed     | 366            |
# | TimestepsSoFar  | 200192         |
# | ev_tdlam_before | 0              |
# | loss_ent        | 0.57222843     |
# | loss_kl         | -2.5257052e-08 |
# | loss_pol_entpen | -0.0057222843  |
# | loss_pol_surr   | 8.92207e-07    |
# | loss_vf_loss    | 22266.316      |
# ------------------------------------

# %%
model = PPO1.load("../models/keep/{}".format(model_name))

env = MyEnv(N=10)
obs = env.reset()
for _ in range(200):
    action, _states = model.predict(obs)
    obs, rewards, done, info = env.step(action)
    env.render()
    if done is True:
        break
# Out:
# Loading a model without an environment, this model cannot be trained until it has a valid environment.
# /home/pj/anaconda3/envs/spinningup/lib/python3.6/site-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))

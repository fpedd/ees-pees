# %%
import webotsgym as wg

from webotsgym.config import WebotConfig
from webotsgym.environment import WebotsEnv
from webotsgym.evaluate import Evaluate, EvaluateMats, EvaluatePJ0
from webotsgym.action import DiscreteAction, ContinuousAction
from webotsgym.observation import Observation

import numpy as np
import matplotlib.pyplot as plt

import gym
import stable_baselines
from stable_baselines import A2C, ACER, ACKTR, DQN, DDPG, SAC, PPO1, PPO2, TD3, TRPO
from stable_baselines.common.env_checker import check_env
from stable_baselines.common.policies import MlpPolicy
# Out:
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.

# %%
def exponential_decay(x, N0=1, lambda_=5):
    return N0*np.exp(-lambda_*x)

class MyObs(Observation):
    def __init__(self, env):
        super(MyObs, self).__init__(env)
        self.env = env

class MyEval(Evaluate):
    def __init__(self, env, config: WebotConfig = WebotConfig()):
        super(MyEval, self).__init__(env, config)
        self.reward_range = (-1000, 1000)

    def calc_reward(self):
        reward = -1
        distance_norm = self.env.get_target_distance()
        distance_abs = self.env.get_target_distance(False)

        if distance_abs < 0.1 and abs(self.env.state.speed) < 0.05 and self.env.state.touching is False:
            return 10000
        else:
            reward += 2500 * exponential_decay(distance_abs, lambda_=40) * exponential_decay(abs(self.env.state.speed), lambda_=10)
        
        if self.env.state.touching:
            reward -= 5
        return reward

    def check_done(self):
        if self.env.total_reward < -10000:
            print("reward boundary")
            return True
        if self.env.get_target_distance(False) < 0.1 and abs(self.env.state.speed) < 0.05 and self.env.state.touching is False:
            print("target reached")
            return True
        return False
    

config = WebotConfig()
config.fast_simulation = True
config.reset_env_after = 200000
config.num_obstacles = 0
config.world_size = 2
config.world_scaling = 0.5

action_class = ContinuousAction(direction_type="steering", relative=False)
env = WebotsEnv(train=True, 
                action_class=action_class, 
                evaluate_class=MyEval,
                observation_class=MyObs,
                config=config)
# Out:
# /home/fabian/.local/lib/python3.6/site-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# Accepting on Port:  10201
# sending: env
# USE FAST MODE

# %%
time_steps = 499999
model_name = "Webots_find_target_small"

model = PPO1("MlpPolicy", env)
# Out:
# WARNING:tensorflow:From /home/fabian/anaconda3/envs/spinningup/lib/python3.6/site-packages/stable_baselines/common/tf_util.py:191: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /home/fabian/anaconda3/envs/spinningup/lib/python3.6/site-packages/stable_baselines/common/tf_util.py:200: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# WARNING:tensorflow:From /home/fabian/anaconda3/envs/spinningup/lib/python3.6/site-packages/stable_baselines/common/policies.py:116: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# WARNING:tensorflow:From /home/fabian/anaconda3/envs/spinningup/lib/python3.6/site-packages/stable_baselines/common/input.py:25: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /home/fabian/anaconda3/envs/spinningup/lib/python3.6/site-packages/stable_baselines/common/policies.py:561: flatten (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.flatten instead.
# WARNING:tensorflow:From /home/fabian/.local/lib/python3.6/site-packages/tensorflow_core/python/layers/core.py:332: Layer.apply (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.__call__` method instead.
# WARNING:tensorflow:From /home/fabian/anaconda3/envs/spinningup/lib/python3.6/site-packages/stable_baselines/common/tf_layers.py:123: The name tf.get_variable is deprecated. Please use tf.compat.v1.get_variable instead.
#
# WARNING:tensorflow:From /home/fabian/anaconda3/envs/spinningup/lib/python3.6/site-packages/stable_baselines/common/distributions.py:418: The name tf.random_normal is deprecated. Please use tf.random.normal instead.
#
# WARNING:tensorflow:From /home/fabian/anaconda3/envs/spinningup/lib/python3.6/site-packages/stable_baselines/ppo1/pposgd_simple.py:153: The name tf.summary.scalar is deprecated. Please use tf.compat.v1.summary.scalar instead.
#
# WARNING:tensorflow:From /home/fabian/anaconda3/envs/spinningup/lib/python3.6/site-packages/stable_baselines/common/tf_util.py:449: The name tf.get_collection is deprecated. Please use tf.compat.v1.get_collection instead.
#
# WARNING:tensorflow:From /home/fabian/anaconda3/envs/spinningup/lib/python3.6/site-packages/stable_baselines/common/tf_util.py:449: The name tf.GraphKeys is deprecated. Please use tf.compat.v1.GraphKeys instead.
#
# WARNING:tensorflow:From /home/fabian/anaconda3/envs/spinningup/lib/python3.6/site-packages/stable_baselines/ppo1/pposgd_simple.py:163: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# WARNING:tensorflow:From /home/fabian/anaconda3/envs/spinningup/lib/python3.6/site-packages/stable_baselines/common/tf_util.py:241: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From /home/fabian/anaconda3/envs/spinningup/lib/python3.6/site-packages/stable_baselines/common/tf_util.py:242: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
#
# WARNING:tensorflow:From /home/fabian/anaconda3/envs/spinningup/lib/python3.6/site-packages/stable_baselines/ppo1/pposgd_simple.py:191: The name tf.summary.merge_all is deprecated. Please use tf.compat.v1.summary.merge_all instead.
#
# WARNING:tensorflow:From /home/fabian/.local/lib/python3.6/site-packages/tensorflow_core/python/ops/math_grad.py:1424: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where

# %%
while True:
    model.learn(total_timesteps=50000, log_interval=10000)
    model.save("models/" + model_name)

# model = PPO1.load("models/{}".format('DQN_WebotFakeMini_TRPO_pj1_nReward2_200000'))
# env = MyEnv()
# obs = env.reset()

# env.render()
# done = False
# max_num_steps = 100
# time = 0
# Out:
# sending: env
# USE FAST MODE
# Reward ( 250 )	 -0.9999999999596332
# Reward ( 500 )	 -0.9966694025518726
# Reward ( 750 )	 -5.997706564370685
# Reward ( 1000 )	 -5.99798258080306
# Reward ( 1250 )	 -5.980571397427766
# Reward ( 1500 )	 -5.976038702904289
# Reward ( 1750 )	 -5.980439497099049
# Reward ( 2000 )	 -5.977194646506338
# Reward ( 2250 )	 -5.949293025894477
# reward boundary
# sending: env
# USE FAST MODE
# sending: env
# USE FAST MODE
# sending: env
# USE FAST MODE
# Reward ( 2500 )	 -0.9999967850039992
# Reward ( 2750 )	 -0.9999890334818876
# Reward ( 3000 )	 -5.9999999943961075
# Reward ( 3250 )	 -5.999999997142746
# Reward ( 3500 )	 -5.9999992765373475
# Reward ( 3750 )	 -5.999999980368584
# Reward ( 4000 )	 -5.99999998130258
# Reward ( 4250 )	 -5.999999982118452
# Reward ( 4500 )	 -5.999999993426602
# reward boundary
# sending: env
# USE FAST MODE
# Reward ( 4750 )	 -0.9999741079750614
# Reward ( 5000 )	 -0.8128900993952102
# Reward ( 5250 )	 -5.56410779442428
# Reward ( 5500 )	 -5.530556168843183
# Reward ( 5750 )	 -5.672839071990747
# Reward ( 6000 )	 -5.506335932564923
# Reward ( 6250 )	 -5.41721879528863
# Reward ( 6500 )	 -5.324133138135771
# Reward ( 6750 )	 -5.64434808814649
# reward boundary
# sending: env
# USE FAST MODE
# Reward ( 7000 )	 -0.9999989383321511
# Reward ( 7250 )	 -5.999999970324424
# Reward ( 7500 )	 -0.9999970705855901
# Reward ( 7750 )	 -0.9999996858594234
# Reward ( 8000 )	 -5.999999879293083
# Reward ( 8250 )	 -5.999999974933777
# Reward ( 8500 )	 -0.9999955210912771
# Reward ( 8750 )	 -0.8479295139147867
# Reward ( 9000 )	 -5.999176895994008
# Reward ( 9250 )	 -5.99911785645219
# reward boundary
# sending: env
# USE FAST MODE
# sending: env
# USE FAST MODE
# Reward ( 9750 )	 -0.999999783659842
# Reward ( 10000 )	 -5.999999999289616
# Reward ( 10250 )	 -5.999999999455624
# Reward ( 10500 )	 -0.9999999843196253
# Reward ( 10750 )	 -5.999999999904166
# Reward ( 11000 )	 -0.9999999420978964
# Reward ( 11250 )	 -5.999999999848523
# Reward ( 11500 )	 -5.999999999816341
# Reward ( 11750 )	 -5.9999999998408065
# reward boundary
# sending: env
# USE FAST MODE
# Reward ( 12000 )	 -5.999999994489504
# Reward ( 12250 )	 -5.999999998724206
# Reward ( 12500 )	 -5.9999999992765005
# Reward ( 12750 )	 -5.999999998128386
# Reward ( 13000 )	 -0.9999998573592356
# Reward ( 13250 )	 -5.9999997022301725
# Reward ( 13500 )	 -0.9999997783699701
# Reward ( 13750 )	 -5.999999998865572
# reward boundary
# sending: env
# USE FAST MODE
# Reward ( 14000 )	 -0.9999930847973245
# Reward ( 14250 )	 -5.999999999507246
# Reward ( 14500 )	 -5.999999999006407
# Reward ( 14750 )	 -5.999999998852676
# Reward ( 15000 )	 -5.999999991250062
# Reward ( 15250 )	 -0.9999998672098288
# Reward ( 15500 )	 -5.999999998913154
# Reward ( 15750 )	 -5.999999997074492
# Reward ( 16000 )	 -5.999999998483043
# reward boundary
# sending: env
# USE FAST MODE
# Reward ( 16250 )	 -0.9999987658511581
# Reward ( 16500 )	 0.8463679628534648
# Reward ( 16750 )	 -5.929838494841706
# Reward ( 17000 )	 -5.926700278672875
# Reward ( 17250 )	 -0.28506228287864843
# target reached
# sending: env
# USE FAST MODE
# sending: env
# USE FAST MODE
# Reward ( 17500 )	 -0.9999775641117659
# Reward ( 17750 )	 -0.9997559133663814
# Reward ( 18000 )	 -0.9999997145376088
# Reward ( 18250 )	 -0.9999999333684596
# Reward ( 18500 )	 -0.9999999998577285
# Reward ( 18750 )	 -5.99999999998944
# Reward ( 19000 )	 -5.999999999969943
# Reward ( 19250 )	 -5.9999999999863
# Reward ( 19500 )	 -5.99999999995533
# Reward ( 19750 )	 -5.999999999973325
# Reward ( 20000 )	 -5.999999999985534
# Reward ( 20250 )	 -0.9999999980301482
# reward boundary
# sending: env
# USE FAST MODE
# sending: env
# USE FAST MODE
# sending: env
# USE FAST MODE
# Reward ( 20500 )	 -0.9999868627086603
# Reward ( 20750 )	 -0.906076781605832
# Reward ( 21000 )	 -0.8229134384245214
# Reward ( 21250 )	 -5.999999963317671
# Reward ( 21500 )	 -5.999999994646504
# Reward ( 21750 )	 -0.9999999354245267
# Reward ( 22000 )	 -0.9999998206014102
# Reward ( 22250 )	 -5.999999994998808
# Reward ( 22500 )	 -0.999999882336305
# Reward ( 22750 )	 -5.999999990530135
# Reward ( 23000 )	 -0.9999999514227041
# Reward ( 23250 )	 -5.999914743255922
# Reward ( 23500 )	 22.32698015108301
# Reward ( 23750 )	 -4.863554633864262
# Reward ( 24000 )	 -5.959083456066353
# reward boundary
# sending: env
# USE FAST MODE
# sending: env
# USE FAST MODE
# Reward ( 24250 )	 -5.999999999965744
# Reward ( 24500 )	 -5.999999999983872
# Reward ( 24750 )	 -0.9999999781806866
# Reward ( 25000 )	 -0.999999775785687
# Reward ( 25250 )	 -0.9999910637688396
# Reward ( 25500 )	 -5.9999997238151135
# Reward ( 25750 )	 -5.999999678228493
# Reward ( 26000 )	 -5.999997043263536
# Reward ( 26250 )	 -5.9948820112237335
# Reward ( 26500 )	 -3.031164181674311
# reward boundary
# sending: env
# USE FAST MODE
# Reward ( 26750 )	 -0.9999999986656439
# Reward ( 27000 )	 -5.999999999992915
# Reward ( 27250 )	 -5.999999999999369
# Reward ( 27500 )	 -5.999999999999105
# Reward ( 27750 )	 -5.999999999999419
# Reward ( 28000 )	 -5.999999999994384
# Reward ( 28250 )	 -5.99999999743044
# Reward ( 28500 )	 -5.99999997571603
# reward boundary
# sending: env
# USE FAST MODE
# sending: env
# USE FAST MODE
# Reward ( 28750 )	 -0.9999990345537767
# Reward ( 29000 )	 -0.9998225449096075
# Reward ( 29250 )	 3.594985178599126
# Reward ( 29500 )	 -0.9847687239843413
# Reward ( 29750 )	 -0.9999988451834754
# Reward ( 30000 )	 -5.999999996457798
# Reward ( 30250 )	 -5.99999999497254
# Reward ( 30500 )	 -0.9999999510934812
# Reward ( 30750 )	 -0.99999984968934
# Reward ( 31000 )	 -0.9897570549615633
# Reward ( 31250 )	 -0.9251673774838385
# target reached
# sending: env
# USE FAST MODE
# Reward ( 31500 )	 -0.9999351895471172
# Reward ( 31750 )	 -5.99988765574428
# Reward ( 32000 )	 -5.999999980037456
# Reward ( 32250 )	 -5.999999969579235
# Reward ( 32500 )	 -5.9999999961940995
# Reward ( 32750 )	 -5.999999997980555
# Reward ( 33000 )	 -0.9999997225984324
# Reward ( 33250 )	 -5.999999786580618
# Reward ( 33500 )	 -5.997832205033213
# reward boundary
# sending: env
# USE FAST MODE
# sending: env
# USE FAST MODE
# Reward ( 33750 )	 -5.999999984434097
# Reward ( 34000 )	 -5.9999999983364525
# Reward ( 34250 )	 -0.9999999725351989
# Reward ( 34500 )	 -0.7227954285616252
# Reward ( 34750 )	 -0.9999992771164795
# Reward ( 35000 )	 -0.9999997376722896
# Reward ( 35250 )	 -0.9999993403967686
# Reward ( 35500 )	 -5.999999998694803
# Reward ( 35750 )	 -5.99999999992992
# Reward ( 36000 )	 -0.8944313965694433
# Reward ( 36250 )	 -5.999999998991517
# Reward ( 36500 )	 -5.999999999989615
# reward boundary
# sending: env
# USE FAST MODE
# sending: env
# USE FAST MODE
# sending: env
# USE FAST MODE
# sending: env
# USE FAST MODE
# Reward ( 36750 )	 -0.9999899961939394
# Reward ( 37000 )	 -0.9999997044800667
# Reward ( 37250 )	 -0.9991546702897216
# Reward ( 37500 )	 -5.999999355352465
# Reward ( 37750 )	 -5.999999976583368
# Reward ( 38000 )	 -5.999999996522139
# Reward ( 38250 )	 -0.9999989019220942
# Reward ( 38500 )	 -5.999999972665512
# Reward ( 38750 )	 -5.999999989323157
# reward boundary
# sending: env
# USE FAST MODE
# Reward ( 39000 )	 -0.999999998220918
# Reward ( 39250 )	 -0.9999999998846161
# Reward ( 39500 )	 -5.999999999999359
# Reward ( 39750 )	 -0.9999999673154822
# Reward ( 40000 )	 -5.999999996024636
# Reward ( 40250 )	 -5.9999999999894085
# Reward ( 40500 )	 -5.9999999884622355
# Reward ( 40750 )	 -5.99718225068617
# Reward ( 41000 )	 -0.9999999997669534
# Reward ( 41250 )	 -5.999999999999359
# reward boundary
# sending: env
# USE FAST MODE
# Reward ( 41500 )	 -0.9999999991240264
# Reward ( 41750 )	 -5.99999999852523
# Reward ( 42000 )	 -5.999999995872335
# Reward ( 42250 )	 -5.999999993686249
# Reward ( 42500 )	 -5.999999992972426
# Reward ( 42750 )	 -5.999999993202594
# Reward ( 43000 )	 -5.999999995326822
# Reward ( 43250 )	 -5.9999999939783075
# reward boundary
# sending: env
# USE FAST MODE
# sending: env
# USE FAST MODE
# sending: env
# USE FAST MODE
# Reward ( 43500 )	 -0.999999988268268
# Reward ( 43750 )	 -5.999999999995755
# Reward ( 44000 )	 -0.9999993282449342
# Reward ( 44250 )	 -5.99999999990347
# Reward ( 44500 )	 -5.999999999936183
# Reward ( 44750 )	 -0.9993736481860739
# Reward ( 45000 )	 -0.9998780761626774
# Reward ( 45250 )	 -5.999999993785353
# Reward ( 45500 )	 -5.999999987380642
# Reward ( 45750 )	 -5.999999999995784
# reward boundary
# sending: env
# USE FAST MODE
# Reward ( 46000 )	 -0.9999956766047058
# Reward ( 46250 )	 -0.9999973444209387
# Reward ( 46500 )	 -0.05040243285772428
# target reached
# sending: env
# USE FAST MODE
# Reward ( 46750 )	 -5.996263797824117
# Reward ( 47000 )	 -5.9999984865732845
# Reward ( 47250 )	 -5.999999963196058
# Reward ( 47500 )	 -0.9997357258553634
# Reward ( 47750 )	 -5.999999826658153
# Reward ( 48000 )	 -5.999992973174768
# Reward ( 48250 )	 -5.9999999648696125
# Reward ( 48500 )	 -5.9999999777850395
# reward boundary
# sending: env
# USE FAST MODE
# sending: env
# USE FAST MODE
# Reward ( 48750 )	 -0.9999993641832158
# target reached
# sending: env
# USE FAST MODE
# sending: env
# USE FAST MODE
# sending: env
# USE FAST MODE
# Reward ( 49000 )	 -0.9999999990588224
# Reward ( 49250 )	 -5.999999998821843
# Reward ( 49500 )	 -5.9999999999770495
# Reward ( 49750 )	 -5.999999994399267
# target reached
# sending: env
# USE FAST MODE
# sending: env
# USE FAST MODE
# Reward ( 50000 )	 -0.9999973454538715
# sending: env
# USE FAST MODE
# Reward ( 50250 )	 -0.9999999971475546
# Reward ( 50500 )	 -0.9999999336945035
# Reward ( 50750 )	 -5.999999999999631
# Reward ( 51000 )	 -5.999999999999333
# Reward ( 51250 )	 -5.999999999424606
# Reward ( 51500 )	 -5.999999997066218
# Reward ( 51750 )	 -0.9995662821194875
# Reward ( 52000 )	 -0.999999998838319
# Reward ( 52250 )	 -5.999999999999244
# Reward ( 52500 )	 -5.999999998725966
# Reward ( 52750 )	 -5.999999993488089
# reward boundary
# sending: env
# USE FAST MODE
# Reward ( 53000 )	 -0.9999996219424832
# Reward ( 53250 )	 -5.999002545754705
# Reward ( 53500 )	 -4.146617111117633
# Reward ( 53750 )	 -5.997356143610025
# Reward ( 54000 )	 -5.999999930815442
# Reward ( 54250 )	 -5.999999991803217
# Reward ( 54500 )	 -0.33688300733580023
# target reached
# sending: env
# USE FAST MODE
# Reward ( 54750 )	 -0.9999989050742804
# Reward ( 55000 )	 -5.999999960146529
# Reward ( 55250 )	 -0.6929963962747705
# target reached
# sending: env
# USE FAST MODE
# Reward ( 55500 )	 -5.999999998256123
# Reward ( 55750 )	 -5.999999992105475
# Reward ( 56000 )	 -5.999999995630178
# Reward ( 56250 )	 -5.999994669237299
# Reward ( 56500 )	 -5.999952013193344
# Reward ( 56750 )	 -5.9999999952198335
# Reward ( 57000 )	 15.884925768546474
# target reached
# sending: env
# USE FAST MODE
# Reward ( 57250 )	 -0.9999994760977318
# Reward ( 57500 )	 -0.9999999819307398
# Reward ( 57750 )	 -5.999999999401941
# Reward ( 58000 )	 -5.999999952584434
# Reward ( 58250 )	 -0.9992138532232671
# Reward ( 58500 )	 -5.999999999076135
# Reward ( 58750 )	 -5.999999999963432
# Reward ( 59000 )	 -0.9986490682046267
# Reward ( 59250 )	 20.116361739162855
# Reward ( 59500 )	 -5.999999989985101
# Reward ( 59750 )	 -0.9999986319218106
# reward boundary
# sending: env
# USE FAST MODE
# sending: env
# USE FAST MODE
# Reward ( 60000 )	 -5.999999996638523
# Reward ( 60250 )	 -5.9999999999984635
# Reward ( 60500 )	 -0.9999999898557593
# Reward ( 60750 )	 -5.999999973408408
# Reward ( 61000 )	 -0.9999999997902222
# target reached
# sending: env
# USE FAST MODE
# Reward ( 61250 )	 -0.9999998988848483
# Reward ( 61500 )	 -0.999906598023735
# Reward ( 61750 )	 -0.9999996239823228
# Reward ( 62000 )	 -5.999999999664703
# Reward ( 62250 )	 -5.999999992413471
# Reward ( 62500 )	 -0.9106370971626051
# Reward ( 62750 )	 -4.731419372503232
# Reward ( 63000 )	 -2.980360650607067
# Reward ( 63250 )	 -5.999999999937481
# Reward ( 63500 )	 -0.9999968455947997
# Reward ( 63750 )	 -5.9999999927005145
# reward boundary
# sending: env
# USE FAST MODE
# sending: env
# USE FAST MODE
# Reward ( 64000 )	 -0.9999991917783605
# Reward ( 64250 )	 -5.999999987955607
# Reward ( 64500 )	 -5.999999953325521
# Reward ( 64750 )	 -5.995684070468232
# Reward ( 65000 )	 -5.9942528226192735
# Reward ( 65250 )	 -3.7873842829092133
# Reward ( 65500 )	 -4.678364160392049
# Reward ( 65750 )	 -4.085241687115671
# Reward ( 66000 )	 -5.999999999996083
# Reward ( 66250 )	 -5.999999999991454
# reward boundary
# sending: env
# USE FAST MODE
# Reward ( 66500 )	 -0.9999963694678083
# Reward ( 66750 )	 -5.999999288384788
# target reached
# sending: env
# USE FAST MODE
# Reward ( 67000 )	 -0.9999999984738301
# Reward ( 67250 )	 -5.999999999486207
# Reward ( 67500 )	 -5.999999999997365
# Reward ( 67750 )	 -0.9999456059694507
# Reward ( 68000 )	 -5.999999974571933
# Reward ( 68250 )	 -5.999999971110273
# Reward ( 68500 )	 -0.9999999984092365
# Reward ( 68750 )	 -5.999999929728098
# target reached
# sending: env
# USE FAST MODE
# sending: env
# USE FAST MODE
# Reward ( 69000 )	 -0.9999999988467885
# Reward ( 69250 )	 -0.999999990827733
# Reward ( 69500 )	 -0.9999314981382369
# Reward ( 69750 )	 -5.999999986491736
# Reward ( 70000 )	 -0.9986189405933693
# Reward ( 70250 )	 -0.9999917100565802
# Reward ( 70500 )	 -5.999999999785098
# Reward ( 70750 )	 -5.999999999652599
# Reward ( 71000 )	 -0.9998438560338292
# Reward ( 71250 )	 -0.9999983106206762
# Reward ( 71500 )	 -0.9999998339628788
# Reward ( 71750 )	 -0.9989870965439233
# target reached
# sending: env
# USE FAST MODE
# sending: env
# USE FAST MODE
# Reward ( 72000 )	 -0.9999983333099042
# Reward ( 72250 )	 -0.7224936977040981
# target reached
# sending: env
# USE FAST MODE
# Reward ( 72500 )	 -0.9998136570298327
# Reward ( 72750 )	 -0.9997265770708935
# Reward ( 73000 )	 -0.999998057555719
# target reached
# sending: env
# USE FAST MODE
# Reward ( 73250 )	 -0.9947778464365754
# Reward ( 73500 )	 -0.9999995538295728
# Reward ( 73750 )	 -0.9999999969853626
# Reward ( 74000 )	 -0.9845189587513911
# target reached
# sending: env
# USE FAST MODE
# Reward ( 74250 )	 -0.99999940247358
# Reward ( 74500 )	 -0.9999999716548588
# Reward ( 74750 )	 -0.9957598954052156
# Reward ( 75000 )	 -0.999999890506799
# Reward ( 75250 )	 -0.9999153159067767
# Reward ( 75500 )	 -0.9999953402195836
# Reward ( 75750 )	 -5.999999970510894
# Reward ( 76000 )	 -0.9999997641419368
# Reward ( 76250 )	 -5.444892658434798
# Reward ( 76500 )	 -0.9999859284592979
# Reward ( 76750 )	 5.174145482480808
# Reward ( 77000 )	 2.5728149597574164
# target reached
# sending: env
# USE FAST MODE
# Reward ( 77250 )	 -0.9999999746142546
# Reward ( 77500 )	 -5.999999980025223
# Reward ( 77750 )	 -0.4032593153168923
# Reward ( 78000 )	 -5.999999985308866
# Reward ( 78250 )	 -5.9999999588461135
# Reward ( 78500 )	 -0.9999999994401215
# Reward ( 78750 )	 -5.999999995943919
# Reward ( 79000 )	 -5.999999992979809
# Reward ( 79250 )	 -0.9999989736361313
# Reward ( 79500 )	 -0.9980452465825363
# reward boundary
# sending: env
# USE FAST MODE
# Reward ( 79750 )	 -0.9999886104081532
# Reward ( 80000 )	 -5.999999978172566
# Reward ( 80250 )	 -5.999999994015425
# Reward ( 80500 )	 -5.999999442101085
# Reward ( 80750 )	 -5.999999738683382
# Reward ( 81000 )	 -0.9967598532733924
# Reward ( 81250 )	 -5.999999958530799
# Reward ( 81500 )	 -0.9998530143770574
# target reached
# sending: env
# USE FAST MODE
# Reward ( 81750 )	 -5.999999999982104
# Reward ( 82000 )	 -5.9999999995096545
# Reward ( 82250 )	 -5.999999999820598
# Reward ( 82500 )	 -0.9999999967498033
# Reward ( 82750 )	 -0.9999903620628754
# Reward ( 83000 )	 -5.999999999479045
# Reward ( 83250 )	 -0.9999932091895823
# Reward ( 83500 )	 -0.997571140784841
# target reached
# sending: env
# USE FAST MODE
# Reward ( 83750 )	 -0.9999926416892503
# Reward ( 84000 )	 -5.999998906366485
# Reward ( 84250 )	 -0.981421980974432
# Reward ( 84500 )	 -5.99999999970945
# Reward ( 84750 )	 -5.9999999970858005
# Reward ( 85000 )	 -4.4174691986266055
# Reward ( 85250 )	 -5.9999380375950855
# Reward ( 85500 )	 -0.9999966795256817
# Reward ( 85750 )	 -5.999999173693082
# target reached
# sending: env
# USE FAST MODE
# Reward ( 86250 )	 -0.9999999997611485
# Reward ( 86500 )	 -0.9999999762172037
# Reward ( 86750 )	 -0.9999999999883964
# Reward ( 87000 )	 -0.999999999547224
# Reward ( 87250 )	 -0.9999990948622453
# Reward ( 87500 )	 -0.9999999964877236
# Reward ( 87750 )	 -5.999999999998687
# Reward ( 88000 )	 -0.9999999276056757
# Reward ( 88250 )	 -0.9999869292044082
# Reward ( 88500 )	 -5.99999999995972
# Reward ( 88750 )	 -5.99999999949264
# Reward ( 89000 )	 -5.999999999994345
# reward boundary
# sending: env
# USE FAST MODE
# Reward ( 89250 )	 -0.9990761359203271
# target reached
# sending: env
# USE FAST MODE
# Reward ( 89500 )	 -5.999893538983363
# Reward ( 89750 )	 -5.999999599146911
# Reward ( 90000 )	 -0.9999983308803511
# Reward ( 90250 )	 -5.999999997091217
# Reward ( 90500 )	 -3.7769305906761734
# target reached
# sending: env
# USE FAST MODE
# sending: env
# USE FAST MODE
# Reward ( 90750 )	 -0.9999950179500955
# Reward ( 91000 )	 -0.45919643200103355
# Reward ( 91250 )	 -5.999587087890633
# Reward ( 91500 )	 -5.929633162448308
# Reward ( 91750 )	 -5.824177399550281
# target reached
# sending: env
# USE FAST MODE
# Reward ( 92000 )	 -0.9999999998742599
# Reward ( 92250 )	 -0.999973366995926
# Reward ( 92500 )	 -5.999876419447853
# target reached
# sending: env
# USE FAST MODE
# Reward ( 92750 )	 -0.9998492657427956
# Reward ( 93000 )	 0.6974577166350495
# Reward ( 93250 )	 -4.51951113351755
# Reward ( 93500 )	 -5.772481384153716
# target reached
# sending: env
# USE FAST MODE
# Reward ( 93750 )	 -0.9999998939083921
# Reward ( 94000 )	 -5.999999943722664
# Reward ( 94250 )	 -5.999999978520267
# Reward ( 94500 )	 -0.9999999967700836
# Reward ( 94750 )	 -0.9134910088927155
# Reward ( 95000 )	 -5.980399801114525
# Reward ( 95250 )	 -5.998476673155156
# Reward ( 95500 )	 -0.8484116843405083
# Reward ( 95750 )	 -5.999999973890789
# Reward ( 96000 )	 1.654394132151467
# target reached
# sending: env
# USE FAST MODE
# sending: env
# USE FAST MODE
# Reward ( 96250 )	 -0.9999999649536893
# Reward ( 96500 )	 -0.9999463275035345
# Reward ( 96750 )	 -0.9999963606935737
# Reward ( 97000 )	 -0.9999999384957287
# Reward ( 97250 )	 -0.9999999967844948
# Reward ( 97500 )	 -0.9996180838864437
# target reached
# sending: env
# USE FAST MODE
# Reward ( 97750 )	 -0.9999967609349496
# Reward ( 98000 )	 -0.9998245614887566
# Reward ( 98250 )	 -0.44900177784608597
# Reward ( 98500 )	 -5.99997393176764
# Reward ( 98750 )	 -0.982922445715981
# Reward ( 99000 )	 3.6315829323503657
# target reached
# sending: env
# USE FAST MODE
# Reward ( 99250 )	 -0.9999993491535026
# Reward ( 99500 )	 -0.9999701019493717
# Reward ( 99750 )	 -5.99998017429798
# Reward ( 100000 )	 -0.6009360903111002
# target reached
# sending: env
# USE FAST MODE
# sending: env
# USE FAST MODE
# Reward ( 100250 )	 -0.9999999985416115
# sending: env
# USE FAST MODE
# Reward ( 100500 )	 -0.9999944234690701
# Reward ( 100750 )	 -5.999999982645056
# Reward ( 101000 )	 -5.999999999379814
# Reward ( 101250 )	 -0.9999993633136366
# Reward ( 101500 )	 -5.9999999998939
# Reward ( 101750 )	 -0.9999986223137192
# Reward ( 102000 )	 -0.9999999999779943
# Reward ( 102250 )	 -0.9998803048961763
# Reward ( 102500 )	 -0.9999740495487969
# Reward ( 102750 )	 -0.999991569201136
# Reward ( 103000 )	 -0.9999999631526524
# Reward ( 103250 )	 -0.9999995111807802
# reward boundary
# sending: env
# USE FAST MODE
# Reward ( 103500 )	 -0.9999946902599296
# Reward ( 103750 )	 -5.999993388931977
# Reward ( 104000 )	 -5.999999919064416
# Reward ( 104250 )	 -5.999999831047892
# Reward ( 104500 )	 -5.999999968080095
# target reached
# sending: env
# USE FAST MODE
# Reward ( 104750 )	 -0.9999985792974536
# target reached
# sending: env
# USE FAST MODE
# Reward ( 105000 )	 -0.9999999975390046
# Reward ( 105250 )	 -5.99999999994917
# Reward ( 105500 )	 -5.999999999999155
# Reward ( 105750 )	 -5.999999999720924
# Reward ( 106000 )	 27.288805558211234
# Reward ( 106250 )	 -0.7742978874980181
# Reward ( 106500 )	 -0.9999980752552743
# Reward ( 106750 )	 -0.9999934642844861
# Reward ( 107000 )	 -5.999999999990766
# Reward ( 107250 )	 -0.9999999930951532
# Reward ( 107500 )	 -5.999999997675454
# Reward ( 107750 )	 -0.9999908952429499
# Reward ( 108000 )	 -0.9997643604335481
# Reward ( 108250 )	 -0.9963050746814764
# Reward ( 108500 )	 -0.9981052784577791
# reward boundary
# sending: env
# USE FAST MODE
# sending: env
# USE FAST MODE
# sending: env
# USE FAST MODE
# Reward ( 108750 )	 -0.9999730617858799
# Reward ( 109000 )	 -0.999997110993214
# Reward ( 109250 )	 -0.9999350819520266
# Reward ( 109500 )	 -5.999999653374056
# Reward ( 109750 )	 1.320009691532094
# Reward ( 110000 )	 -5.999999904975962
# Reward ( 110250 )	 -5.999999992234357
# Reward ( 110500 )	 -0.999929500530238
# Reward ( 110750 )	 -5.999999997181187
# Reward ( 111000 )	 -0.9999824492673408
# Reward ( 111250 )	 -5.998271450160191
# target reached
# sending: env
# USE FAST MODE
# Reward ( 111500 )	 -0.9935798548414605
# Reward ( 111750 )	 -0.9999552658761739
# Reward ( 112000 )	 -0.9999972907768595
# Reward ( 112250 )	 -0.9996066128175052
# Reward ( 112500 )	 -0.998560514264112
# Reward ( 112750 )	 -5.999999999988165
# Reward ( 113000 )	 -5.999999999999574
# Reward ( 113250 )	 -5.9999999999995595
# Reward ( 113500 )	 -0.9999999999278507
# Reward ( 113750 )	 -0.9999998633034101
# Reward ( 114000 )	 -0.9999996814306444
# Reward ( 114250 )	 -0.9999855653482367
# target reached
# sending: env
# USE FAST MODE
# Reward ( 114500 )	 -5.999813073676462
# Reward ( 114750 )	 -5.989387815685648
# target reached
# sending: env
# USE FAST MODE
# sending: env
# USE FAST MODE
# Reward ( 115000 )	 -0.9999911568328383
# Reward ( 115250 )	 -4.835392256126688
# Reward ( 115500 )	 -0.573706307142732
# Reward ( 115750 )	 -0.9999582831255904
# Reward ( 116000 )	 -5.999999999637896
# Reward ( 116250 )	 -5.999999999998882
# Reward ( 116500 )	 -0.9999999854496362
# Reward ( 116750 )	 -5.999999998234129
# target reached
# sending: env
# USE FAST MODE
# Reward ( 117000 )	 -0.9999999987997598
# target reached
# sending: env
# USE FAST MODE
# Reward ( 117250 )	 -0.999995062136281
# Reward ( 117500 )	 -5.999999779809244
# Reward ( 117750 )	 -5.99999999456791
# Reward ( 118000 )	 -5.75277631363306
# Reward ( 118250 )	 -5.999999993868889
# Reward ( 118500 )	 -5.999945679602492
# Reward ( 118750 )	 -5.9999999939762
# Reward ( 119000 )	 -0.9987968235211252
# Reward ( 119250 )	 -5.9999999996736015
# Reward ( 119500 )	 -0.7907051777806571
# Reward ( 119750 )	 -0.9999999745894421
# Reward ( 120000 )	 -0.9999984056901373
# Reward ( 120250 )	 -5.999999999444452
# Reward ( 120500 )	 -0.9999999795321514
# Reward ( 120750 )	 -0.998124052482843
# Reward ( 121000 )	 -0.9993244287184472
# reward boundary
# sending: env
# USE FAST MODE
# Reward ( 121250 )	 -5.999999990143602
# Reward ( 121500 )	 -5.9999999992805675
# Reward ( 121750 )	 -0.9998998503606892
# Reward ( 122000 )	 -0.9999742204598794
# Reward ( 122250 )	 -0.910893278163516
# Reward ( 122500 )	 -0.9998460832246328
# target reached
# sending: env
# USE FAST MODE
# sending: env
# USE FAST MODE
# Reward ( 122750 )	 -0.9997677653196905
# Reward ( 123000 )	 -0.9999999652212652
# Reward ( 123250 )	 -0.9999840185680677
# Reward ( 123500 )	 -0.9999999904348564
# Reward ( 123750 )	 -0.9999999765550006
# Reward ( 124000 )	 -5.999999999917485
# Reward ( 124250 )	 -0.9999906563506621
# Reward ( 124500 )	 -5.999999999999186
# Reward ( 124750 )	 -5.999999999926416
# Reward ( 125000 )	 -0.9999997914247777
# Reward ( 125250 )	 -0.5133441169413875
# Reward ( 125500 )	 -0.9999999676924992
# Reward ( 125750 )	 -5.999999999840335
# reward boundary
# sending: env
# USE FAST MODE
# Reward ( 126000 )	 -0.9999999994758813
# Reward ( 126250 )	 -0.9723134543309057
# Reward ( 126500 )	 -0.9995663878150276
# Reward ( 126750 )	 -5.99999979792348
# Reward ( 127000 )	 -0.9999971191305684
# target reached
# sending: env
# USE FAST MODE
# Reward ( 127250 )	 -0.9999999981765773
# Reward ( 127500 )	 -0.9999999627094079
# Reward ( 127750 )	 -0.9999999895048144
# Reward ( 128000 )	 -5.999999998944409
# Reward ( 128250 )	 -5.999999999195918
# Reward ( 128500 )	 -5.99999999742142
# Reward ( 128750 )	 -0.9893445162567013
# Reward ( 129000 )	 -5.9945289069602286
# target reached
# sending: env
# USE FAST MODE
# Reward ( 129250 )	 -5.999999999828216
# Reward ( 129500 )	 -0.9999996270194718
# Reward ( 129750 )	 -0.9999979650781908
# Reward ( 130000 )	 -5.999999989133362
# Reward ( 130250 )	 -0.8766423355306349
# Reward ( 130500 )	 -5.954665251969784
# Reward ( 130750 )	 2.0018513583616073
# Reward ( 131000 )	 10000
# target reached
# sending: env
# USE FAST MODE
# Reward ( 131250 )	 -5.999997916756973
# Reward ( 131500 )	 -0.9999998492016877
# Reward ( 131750 )	 -0.9999998446718721
# Reward ( 132000 )	 -5.999999987080757
# Reward ( 132250 )	 -5.999999975999638
# Reward ( 132500 )	 -5.999960869728494
# Reward ( 132750 )	 -0.9999994438583938
# target reached
# sending: env
# USE FAST MODE
# sending: env
# USE FAST MODE
# sending: env
# USE FAST MODE
# Reward ( 133000 )	 -0.9861739035440148
# Reward ( 133250 )	 -5.999999992953468
# Reward ( 133500 )	 -5.999999983774382
# Reward ( 133750 )	 -5.999999777748255
# target reached
# sending: env
# USE FAST MODE
# sending: env
# USE FAST MODE
# sending: env
# USE FAST MODE
# sending: env
# USE FAST MODE
# sending: env
# USE FAST MODE
# Reward ( 134000 )	 -5.999996986470956
# Reward ( 134250 )	 -0.9997456923546342
# Reward ( 134500 )	 -5.99999999999849
# Reward ( 134750 )	 -5.99999999999935
# Reward ( 135000 )	 -5.999999999978651
# Reward ( 135250 )	 -5.999999996707664
# Reward ( 135500 )	 13.804109986473648
# target reached
# sending: env
# USE FAST MODE
# Reward ( 135750 )	 -0.9999965831583493
# Reward ( 136000 )	 -0.999999999937579
# Reward ( 136250 )	 -5.99999999999704
# Reward ( 136500 )	 -5.999999999998586
# Reward ( 136750 )	 -5.99999999999902
# Reward ( 137000 )	 -5.99999999552155
# Reward ( 137250 )	 -5.999999981169438
# Reward ( 137500 )	 -5.999999988661863
# Reward ( 137750 )	 5.384149366005298
# Reward ( 138000 )	 -0.9999996938941579
# reward boundary
# sending: env
# USE FAST MODE
# Reward ( 138250 )	 -0.9999999994522111
# Reward ( 138500 )	 -0.9903784488620885
# target reached
# sending: env
# USE FAST MODE
# sending: env
# USE FAST MODE
# Reward ( 138750 )	 -5.99999916675669
# Reward ( 139000 )	 2.066185754900603
# Reward ( 139250 )	 -5.99836139456715
# target reached
# sending: env
# USE FAST MODE
# Reward ( 139500 )	 -5.999999992826931
# Reward ( 139750 )	 -0.9999999584173449
# Reward ( 140000 )	 -5.999999998215897
# Reward ( 140250 )	 -5.99999997133106
# Reward ( 140500 )	 -5.999999999408729
# Reward ( 140750 )	 -0.9999984273336435
# target reached
# sending: env
# USE FAST MODE
# target reached
# sending: env
# USE FAST MODE
# Reward ( 141000 )	 -0.999999999092275
# Reward ( 141250 )	 -0.9994530901901664
# Reward ( 141500 )	 -0.9999996259992812
# Reward ( 141750 )	 -5.999999972955928
# Reward ( 142000 )	 -5.999999999911447
# Reward ( 142250 )	 -0.9999999995289824
# Reward ( 142500 )	 -5.9999999999996225
# Reward ( 142750 )	 -5.9999999999987885
# Reward ( 143000 )	 -0.9999999981218718
# Reward ( 143250 )	 -5.9999999906052
# reward boundary
# sending: env
# USE FAST MODE
# sending: env
# USE FAST MODE
# Reward ( 143500 )	 -0.9999990659569384
# Reward ( 143750 )	 -0.4289077447233258
# Reward ( 144000 )	 -5.999999969490394
# Reward ( 144250 )	 2.227814651521112
# Reward ( 144500 )	 -5.999999999596407
# Reward ( 144750 )	 -5.999958143754996
# target reached
# sending: env
# USE FAST MODE
# Reward ( 145000 )	 -0.9999956915396094
# Reward ( 145250 )	 -5.993562841214482
# Reward ( 145500 )	 -5.999999977396038
# Reward ( 145750 )	 -5.999999973512697
# Reward ( 146000 )	 -5.999999903519098
# Reward ( 146250 )	 -0.6239809168078452
# Reward ( 146500 )	 -0.9999999803606913
# Reward ( 146750 )	 5.902595602273583
# Reward ( 147000 )	 2.1365290861047193
# target reached
# sending: env
# USE FAST MODE
# Reward ( 147250 )	 -0.9999914153358092
# Reward ( 147500 )	 -5.999999996701848
# Reward ( 147750 )	 -5.999999988412628
# Reward ( 148000 )	 -3.271709681247392
# Reward ( 148250 )	 -5.599029283828513
# Reward ( 148500 )	 -5.999999967399584
# Reward ( 148750 )	 -5.999999999867089
# Reward ( 149000 )	 -5.999999998533898
# Reward ( 149250 )	 -0.9249750715137601
# reward boundary
# sending: env
# USE FAST MODE
# Reward ( 149500 )	 -0.9999913366383789
# Reward ( 149750 )	 -5.999999974006725
# Reward ( 150000 )	 -5.999999998949239
# Reward ( 150250 )	 -5.999999999998829
# Reward ( 150500 )	 -5.999999999998075
# sending: env
# USE FAST MODE
# Reward ( 150750 )	 -0.9999860479455738
# Reward ( 151000 )	 -5.999999906949492
# Reward ( 151250 )	 -5.999999972567211
# Reward ( 151500 )	 -5.999999988585411
# Reward ( 151750 )	 -0.9999940883368662
# Reward ( 152000 )	 -5.999999999738294
# Reward ( 152250 )	 -5.9999999999980576
# Reward ( 152500 )	 -5.999999999579656
# Reward ( 152750 )	 -5.999998296820507
# reward boundary
# sending: env
# USE FAST MODE
# Reward ( 153000 )	 -0.9999974359096958
# target reached
# sending: env
# USE FAST MODE
# Reward ( 153250 )	 -0.9999977027309561
# Reward ( 153500 )	 -5.999034616732495
# Reward ( 153750 )	 -5.999999979362849
# Reward ( 154000 )	 -5.999999999431672
# Reward ( 154250 )	 -5.999999999998908
# Reward ( 154500 )	 -5.999999998145456
# Reward ( 154750 )	 -5.999999948461605
# target reached
# sending: env
# USE FAST MODE
# Reward ( 155000 )	 -0.9999999994205353
# Reward ( 155250 )	 -0.9920718392074475
# Reward ( 155500 )	 -5.9999999938024935
# Reward ( 155750 )	 -0.7874014179443258
# Reward ( 156000 )	 -0.9999965882201974
# Reward ( 156250 )	 -5.999999999895946
# Reward ( 156500 )	 -5.999999999996361
# Reward ( 156750 )	 -5.99999999999936
# Reward ( 157000 )	 -5.999999999998073
# Reward ( 157250 )	 -5.999999999998898
# reward boundary
# sending: env
# USE FAST MODE
# Reward ( 157500 )	 -5.991598683511312
# target reached
# sending: env
# USE FAST MODE
# Reward ( 157750 )	 -0.9999999990954094
# Reward ( 158000 )	 -0.9999882038758681
# Reward ( 158250 )	 -0.9999996579855006
# Reward ( 158500 )	 -5.994153352998337
# target reached
# sending: env
# USE FAST MODE
# Reward ( 158750 )	 -0.9999971211905382
# Reward ( 159000 )	 -0.9901603920340785
# Reward ( 159250 )	 -5.99999990703508
# Reward ( 159500 )	 -4.524544326661317
# Reward ( 159750 )	 -5.999833630864011
# Reward ( 160000 )	 -0.9999999762248456
# Reward ( 160250 )	 -3.314459093141521
# target reached
# sending: env
# USE FAST MODE
# Reward ( 160500 )	 -0.9999932913379752
# Reward ( 160750 )	 -0.7088184653709296
# Reward ( 161000 )	 -5.750729468819928
# Reward ( 161250 )	 -5.999280338699597
# Reward ( 161500 )	 -5.999999929011563
# Reward ( 161750 )	 -5.999999995567213
# Reward ( 162000 )	 -5.999999961762706
# Reward ( 162250 )	 -5.999999992448827
# Reward ( 162500 )	 -0.9988388673753007
# Reward ( 162750 )	 -0.9999988965012816
# reward boundary
# sending: env
# USE FAST MODE
# Reward ( 163000 )	 -0.9999999994368266
# Reward ( 163250 )	 -0.9999976844727035
# Reward ( 163500 )	 -5.999879919545738
# target reached
# sending: env
# USE FAST MODE
# sending: env
# USE FAST MODE
# Reward ( 163750 )	 -5.999999977639413
# Reward ( 164000 )	 -5.9999999997755245
# Reward ( 164250 )	 -5.999999999998936
# Reward ( 164500 )	 -5.999999999999548
# Reward ( 164750 )	 -5.999999999999363
# Reward ( 165000 )	 -5.999999999999601
# Reward ( 165250 )	 -5.9999999999984945
# Reward ( 165500 )	 -0.9688387459141587
# reward boundary
# sending: env
# USE FAST MODE
# Reward ( 165750 )	 -0.9999897252304478
# Reward ( 166000 )	 -5.999999974968364
# Reward ( 166250 )	 -5.999999995382337
# Reward ( 166500 )	 -0.9993864683961349
# Reward ( 166750 )	 -5.999999989738441
# Reward ( 167000 )	 -5.99999999965398
# target reached
# sending: env
# USE FAST MODE
# Reward ( 167250 )	 -0.9999975249016972
# Reward ( 167500 )	 -0.9999968359727551
# Reward ( 167750 )	 -5.999999991579835
# Reward ( 168000 )	 -5.99999982542493
# Reward ( 168250 )	 -5.999999995752269
# Reward ( 168500 )	 -5.999999999996546
# Reward ( 168750 )	 -5.99999999632403
# Reward ( 169000 )	 -5.999999985957732
# Reward ( 169250 )	 -5.999881138036105
# reward boundary
# sending: env
# USE FAST MODE
# Reward ( 169500 )	 -5.999999767243716
# Reward ( 169750 )	 -5.999999984226513
# Reward ( 170000 )	 -5.999999955144967
# Reward ( 170250 )	 -5.999989699267839
# Reward ( 170500 )	 -0.9999838020917182
# Reward ( 170750 )	 -0.9999990565274518
# target reached
# sending: env
# USE FAST MODE
# sending: env
# USE FAST MODE
# Reward ( 171000 )	 -0.9999935044968175
# Reward ( 171250 )	 -5.999999999400515
# Reward ( 171500 )	 -5.999999999999465
# Reward ( 171750 )	 -5.999999999999135
# Reward ( 172000 )	 -0.9999999999845411
# Reward ( 172250 )	 -5.999999999999373
# Reward ( 172500 )	 -0.9999548291822143
# Reward ( 172750 )	 -0.9999999463190201
# target reached
# sending: env
# USE FAST MODE
# Reward ( 173000 )	 -0.9999965386068557
# Reward ( 173250 )	 -0.8102625961516865
# Reward ( 173500 )	 -5.999999981810389
# Reward ( 173750 )	 -5.999999999998449
# Reward ( 174000 )	 -5.9999999999991696
# Reward ( 174250 )	 -5.9999999999983835
# Reward ( 174500 )	 -5.999999987382426
# Reward ( 174750 )	 -5.9999999927857255
# Reward ( 175000 )	 -5.99169055792803
# reward boundary
# sending: env
# USE FAST MODE
# Reward ( 175250 )	 -5.999999999719207
# Reward ( 175500 )	 -0.9999100092415624
# Reward ( 175750 )	 -5.999999334400156
# Reward ( 176000 )	 -5.9999999295173705
# Reward ( 176250 )	 -5.999999976347154
# Reward ( 176500 )	 -5.999999976121921
# Reward ( 176750 )	 -5.999999926460097
# Reward ( 177000 )	 -5.999999990646105
# reward boundary
# sending: env
# USE FAST MODE
# Reward ( 177250 )	 -0.9999999946905549
# Reward ( 177500 )	 -0.36086541771248737
# target reached
# sending: env
# USE FAST MODE
# sending: env
# USE FAST MODE
# Reward ( 177750 )	 -5.999999999999287
# Reward ( 178000 )	 -5.9999999999970015
# Reward ( 178250 )	 -0.9999999821453848
# target reached
# sending: env
# USE FAST MODE
# Reward ( 178500 )	 -0.9999991605030726
# target reached
# sending: env
# USE FAST MODE
# sending: env
# USE FAST MODE
# Reward ( 178750 )	 -0.9999963160907155
# Reward ( 179000 )	 4.932319716656129
# Reward ( 179250 )	 8.746384114398367
# Reward ( 179500 )	 -0.9999996891218774
# Reward ( 179750 )	 -5.999999996801896
# Reward ( 180000 )	 -5.999982483323075
# target reached
# sending: env
# USE FAST MODE
# sending: env
# USE FAST MODE
# sending: env
# USE FAST MODE
# Reward ( 180250 )	 -0.999993670391669
# Reward ( 180500 )	 -5.99999997699386
# Reward ( 180750 )	 -0.9986856400613969
# Reward ( 181000 )	 -5.999999941797096
# Reward ( 181250 )	 -0.9999939984653371
# target reached
# sending: env
# USE FAST MODE
# sending: env
# USE FAST MODE
# sending: env
# USE FAST MODE
# Reward ( 181500 )	 -5.999999985003207
# Reward ( 181750 )	 -5.9999999812189895
# Reward ( 182000 )	 -5.999999996891299
# Reward ( 182250 )	 -5.9999967493542
# target reached
# sending: env
# USE FAST MODE
# Reward ( 182500 )	 -0.9999999985953514
# Reward ( 182750 )	 -5.99999999989737
# Reward ( 183000 )	 -5.99999999999946
# Reward ( 183250 )	 -0.9996756021969969
# Reward ( 183500 )	 -0.9999999952965577
# Reward ( 183750 )	 -5.999999999993154
# Reward ( 184000 )	 -0.9845419897476965
# Reward ( 184250 )	 -5.999999987378381
# Reward ( 184500 )	 -5.999999994622201
# Reward ( 184750 )	 -5.9999997344533575
# Reward ( 185000 )	 -0.9999983389906458
# reward boundary
# sending: env
# USE FAST MODE
# Reward ( 185250 )	 -0.9999924267035205
# Reward ( 185500 )	 -5.999999954205606
# Reward ( 185750 )	 -5.999999964974145
# Reward ( 186000 )	 -5.999999994073108
# target reached
# sending: env
# USE FAST MODE
# Reward ( 186250 )	 -0.9999999972646888
# Reward ( 186500 )	 -5.999999999425349
# Reward ( 186750 )	 -5.999999996256283
# Reward ( 187000 )	 -5.99999999475945
# Reward ( 187250 )	 -5.9999999878830215
# Reward ( 187500 )	 -5.999814449840981
# Reward ( 187750 )	 -4.976533323531829
# Reward ( 188000 )	 -5.999998026398091
# reward boundary
# sending: env
# USE FAST MODE
# Reward ( 188250 )	 -0.999986066877685
# Reward ( 188500 )	 -0.092494043188172
# Reward ( 188750 )	 -0.9999999986453255
# Reward ( 189000 )	 -0.9999999976968792
# Reward ( 189250 )	 -5.999999999722379
# Reward ( 189500 )	 -5.999999741898509
# target reached
# sending: env
# USE FAST MODE
# Reward ( 189750 )	 -0.9999999986238177
# Reward ( 190000 )	 -0.9999932560334023
# Reward ( 190250 )	 -5.999998142272236
# target reached
# sending: env
# USE FAST MODE
# Reward ( 190500 )	 -0.9999964609598124
# Reward ( 190750 )	 -0.9999998479464162
# Reward ( 191000 )	 -5.998513575928477
# Reward ( 191250 )	 -5.999999996611915
# Reward ( 191500 )	 -5.999999999997694
# Reward ( 191750 )	 -0.9999999999958491
# Reward ( 192000 )	 -0.9999998520311334
# Reward ( 192250 )	 -5.999999999999673
# Reward ( 192500 )	 -5.999999999997667
# target reached
# sending: env
# USE FAST MODE
# Reward ( 192750 )	 -0.999993692473142
# Reward ( 193000 )	 -5.999989815854142
# Reward ( 193250 )	 -5.704912411327896
# Reward ( 193500 )	 -5.147116604983482
# Reward ( 193750 )	 -0.9966524712124079
# Reward ( 194000 )	 -5.999999999925056
# Reward ( 194250 )	 -0.9999986918638747
# Reward ( 194500 )	 2.094027519972945
# target reached
# sending: env
# USE FAST MODE
# Reward ( 194750 )	 -5.999999998026872
# Reward ( 195000 )	 -5.999999999998829
# Reward ( 195250 )	 -5.999999999998586
# Reward ( 195500 )	 -5.999999999999529
# Reward ( 195750 )	 -5.999999999999607
# Reward ( 196000 )	 -5.999999999999325
# Reward ( 196250 )	 -5.999999999999498
# reward boundary
# sending: env
# USE FAST MODE
# Reward ( 196500 )	 -0.9999970570766159
# Reward ( 196750 )	 -0.9886811793248875
# Reward ( 197000 )	 -4.849759881067985
# Reward ( 197250 )	 -5.033541400428753
# Reward ( 197500 )	 -5.9912188298462645
# Reward ( 197750 )	 -5.994381044670896
# Reward ( 198000 )	 -5.99882590565562
# Reward ( 198250 )	 -5.995367488161531
# Reward ( 198500 )	 -5.9999999512908015
# Reward ( 198750 )	 -5.999999994225899
# target reached
# sending: env
# USE FAST MODE
# Reward ( 199000 )	 -0.9999968025037114
# Reward ( 199250 )	 -5.999999588762105
# Reward ( 199500 )	 -5.999999988138314
# Reward ( 199750 )	 -5.999999973726621
# Reward ( 200000 )	 -5.999999974252655
# Reward ( 200250 )	 -0.9999999722822368
# Reward ( 200500 )	 23.382448945430234
# target reached
# sending: env
# USE FAST MODE
# Reward ( 200750 )	 -5.999999999053449
# sending: env
# USE FAST MODE
# Reward ( 201000 )	 -0.9999944011190064
# Reward ( 201250 )	 -5.999999992701088
# Reward ( 201500 )	 -5.999999992651389
# Reward ( 201750 )	 -5.98851817571031
# Reward ( 202000 )	 -3.5923645409413227
# Reward ( 202250 )	 5.498303854300746
# Reward ( 202500 )	 -0.9999035744589895
# Reward ( 202750 )	 -5.999999781155228
# Reward ( 203000 )	 6.873641177171682
# target reached
# sending: env
# USE FAST MODE
# Reward ( 203250 )	 -0.9999995220944121
# Reward ( 203500 )	 -5.9999999418286
# Reward ( 203750 )	 -5.999999999801947
# Reward ( 204000 )	 -5.999999999999413
# Reward ( 204250 )	 -5.999999999997447
# Reward ( 204500 )	 -0.9999999961027268
# Reward ( 204750 )	 -4.018911382139606
# Reward ( 205000 )	 -5.999999997372376
# reward boundary
# sending: env
# USE FAST MODE
# sending: env
# USE FAST MODE
# sending: env
# USE FAST MODE
# sending: env
# USE FAST MODE
# Reward ( 205250 )	 -0.9999996445743258
# Reward ( 205500 )	 -5.999999996108022
# Reward ( 205750 )	 -5.999999989205392
# Reward ( 206000 )	 -5.967944912991255
# Reward ( 206250 )	 -5.248687130118304
# Reward ( 206500 )	 -4.221924498956919
# Reward ( 206750 )	 -3.9121738033107216
# Reward ( 207000 )	 -5.999948929264433
# Reward ( 207250 )	 -0.9999999459285285
# reward boundary
# sending: env
# USE FAST MODE
# Reward ( 207500 )	 -0.9999862932060215
# Reward ( 207750 )	 -4.270402013832048
# Reward ( 208000 )	 -5.999993495492432
# Reward ( 208250 )	 -5.999999981920913
# Reward ( 208500 )	 -0.9999999924187264
# Reward ( 208750 )	 -5.999999999886001
# Reward ( 209000 )	 -5.999999999999581
# Reward ( 209250 )	 -5.999999987268359
# reward boundary
# sending: env
# USE FAST MODE
# Reward ( 209500 )	 -0.9999764291196286
# Reward ( 209750 )	 -5.995725141699776
# target reached
# sending: env
# USE FAST MODE
# Reward ( 210000 )	 -0.9999769241139762
# Reward ( 210250 )	 -0.9999998560654348
# Reward ( 210500 )	 -5.999999999999517
# Reward ( 210750 )	 -0.9999999999831385
# Reward ( 211000 )	 -5.999999999997539
# Reward ( 211250 )	 -5.999999999818071
# Reward ( 211500 )	 -5.999999992968085
# Reward ( 211750 )	 -5.999999975358048
# Reward ( 212000 )	 -5.99999997641064
# reward boundary
# sending: env
# USE FAST MODE
# sending: env
# USE FAST MODE
# Reward ( 212250 )	 -0.972090501430088
# target reached
# sending: env
# USE FAST MODE
# Reward ( 212500 )	 -0.9999998038558282
# Reward ( 212750 )	 -0.999908151033982
# Reward ( 213000 )	 -5.9999001651485955
# Reward ( 213250 )	 -0.9999999827468974
# Reward ( 213500 )	 -5.999999767864104
# Reward ( 213750 )	 -5.9997749110418725
# target reached
# sending: env
# USE FAST MODE
# Reward ( 214000 )	 -0.9999999970317112
# Reward ( 214250 )	 -5.9999999999860725
# Reward ( 214500 )	 -5.294514129479077
# Reward ( 214750 )	 -4.430903595453634
# target reached
# sending: env
# USE FAST MODE
# Reward ( 215000 )	 -0.9999999990465943
# Reward ( 215250 )	 -0.85880561445816
# Reward ( 215500 )	 -0.9996895815051721
# target reached
# sending: env
# USE FAST MODE
# Reward ( 215750 )	 -0.9999993863747784
# Reward ( 216000 )	 -5.9999999954491345
# Reward ( 216250 )	 -0.999998505767901
# Reward ( 216500 )	 -0.9996402955752367
# Reward ( 216750 )	 -5.999999999976277
# Reward ( 217000 )	 -5.999999999999523
# Reward ( 217250 )	 -0.9999997110139988
# target reached
# sending: env
# USE FAST MODE
# Reward ( 217500 )	 -0.9999999973041739
# Reward ( 217750 )	 -0.9999999999699856
# Reward ( 218000 )	 -5.999999999974168
# Reward ( 218250 )	 -0.9999838326750348
# Reward ( 218500 )	 -5.999999997722634
# Reward ( 218750 )	 -5.999999999998946
# Reward ( 219000 )	 -0.9999999614853107
# Reward ( 219250 )	 12.491294805662019
# target reached
# sending: env
# USE FAST MODE
# Reward ( 219500 )	 -0.999995859011978
# Reward ( 219750 )	 -5.9999999437231555
# Reward ( 220000 )	 -0.9999999985690682
# Reward ( 220250 )	 -0.9999999992117703
# Reward ( 220500 )	 -3.784830723528991
# Reward ( 220750 )	 3.879623613099996
# Reward ( 221000 )	 -4.767847196974094
# Reward ( 221250 )	 -1.4043317992619482
# Reward ( 221500 )	 -5.992121426726031
# Reward ( 221750 )	 -5.999999987530208
# Reward ( 222000 )	 -0.9976023633948135
# Reward ( 222250 )	 -0.9999987834337504
# Reward ( 222500 )	 -5.999999993807267
# Reward ( 222750 )	 -0.9999884129620007
# Reward ( 223000 )	 -5.999999993682481
# reward boundary
# sending: env
# USE FAST MODE
# sending: env
# USE FAST MODE
# Reward ( 223250 )	 -0.9818895499104744
# Reward ( 223500 )	 -0.9944270944747404
# target reached
# sending: env
# USE FAST MODE
# sending: env
# USE FAST MODE
# sending: env
# USE FAST MODE
# Reward ( 223750 )	 -0.9999999894560069
# Reward ( 224000 )	 -0.9999994480483362
# Reward ( 224250 )	 -5.999999999899211
# Reward ( 224500 )	 -5.9999999933184744
# Reward ( 224750 )	 -0.9999998960182981
# Reward ( 225000 )	 -5.999999999546791
# Reward ( 225250 )	 -5.999999999996575
# Reward ( 225500 )	 -5.9999999995109885
# Reward ( 225750 )	 -0.9999890386414733
# Reward ( 226000 )	 -5.975044960300897
# Reward ( 226250 )	 -0.9661792312703402
# target reached
# sending: env
# USE FAST MODE
# Reward ( 226500 )	 -0.9999970515238286
# Reward ( 226750 )	 -0.9468149647091931
# Reward ( 227000 )	 -0.8265613792443202
# Reward ( 227250 )	 -5.99999999887913
# Reward ( 227500 )	 -0.999999024952914
# Reward ( 227750 )	 -5.999999992285589
# target reached
# sending: env
# USE FAST MODE
# sending: env
# USE FAST MODE
# Reward ( 228000 )	 -0.9999999813429771
# Reward ( 228250 )	 -5.999999955666043
# Reward ( 228500 )	 -5.9999999999155555
# Reward ( 228750 )	 -0.9999996126301839
# target reached
# sending: env
# USE FAST MODE
# Reward ( 229000 )	 -0.9999999887965908
# Reward ( 229250 )	 -5.999999999998938
# Reward ( 229500 )	 -0.9999987393030887
# Reward ( 229750 )	 -0.9994134765091927
# target reached
# sending: env
# USE FAST MODE
# Reward ( 230000 )	 -0.9999974252427136
# Reward ( 230250 )	 -5.999999979046935
# Reward ( 230500 )	 -5.999999994553497
# Reward ( 230750 )	 -5.999999999945082
# Reward ( 231000 )	 -5.999999993319584
# Reward ( 231250 )	 -5.999999979864281
# Reward ( 231500 )	 -5.999999999870697
# Reward ( 231750 )	 -0.9999976026226697
# Reward ( 232000 )	 -5.999999999993321
# reward boundary
# sending: env
# USE FAST MODE
# Reward ( 232250 )	 -0.9906700912937466
# Reward ( 232500 )	 -5.999999999956058
# Reward ( 232750 )	 -5.999999999992615
# target reached
# sending: env
# USE FAST MODE
# Reward ( 233000 )	 -0.9999968292921599
# Reward ( 233250 )	 -0.9985563322726063
# Reward ( 233500 )	 -0.9999947722070693
# Reward ( 233750 )	 -0.9998023550008255
# Reward ( 234000 )	 -0.9995025628374599
# Reward ( 234250 )	 -5.999999994112784
# Reward ( 234500 )	 -5.923149504637264
# Reward ( 234750 )	 -5.9999999641003825
# Reward ( 235000 )	 -5.999967362650636
# Reward ( 235250 )	 -5.999970433206704
# reward boundary
# sending: env
# USE FAST MODE
# Reward ( 235500 )	 -0.9999999994471414
# Reward ( 235750 )	 -5.9999999939088955
# Reward ( 236000 )	 -0.9999997360972819
# Reward ( 236250 )	 -5.999999999966888
# Reward ( 236500 )	 -5.999999999999467
# Reward ( 236750 )	 -0.9999999336221833
# Reward ( 237000 )	 -5.999999996838167
# Reward ( 237250 )	 -5.999999995778643
# Reward ( 237500 )	 -5.999999985431728
# reward boundary
# sending: env
# USE FAST MODE
# Reward ( 237750 )	 -0.9999921240315514
# Reward ( 238000 )	 -5.999924671481539
# Reward ( 238250 )	 -5.999999997199996
# Reward ( 238500 )	 -5.999999999999026
# Reward ( 238750 )	 -5.999999999999758
# Reward ( 239000 )	 -5.999999999998134
# Reward ( 239250 )	 -5.999999998039639
# target reached
# sending: env
# USE FAST MODE
# sending: env
# USE FAST MODE
# Reward ( 239500 )	 -0.9999920306794567
# Reward ( 239750 )	 -0.8648044963519248
# Reward ( 240000 )	 -5.999999796236186
# Reward ( 240250 )	 -5.999999999586655
# Reward ( 240500 )	 -5.999999996722589
# Reward ( 240750 )	 -5.999999475277199
# Reward ( 241000 )	 -2.9978092337078603
# target reached
# sending: env
# USE FAST MODE
# Reward ( 241250 )	 -0.9999999995202847
# Reward ( 241500 )	 -5.999999999046602
# Reward ( 241750 )	 -0.999999225132535
# Reward ( 242000 )	 -0.9999998884147056
# Reward ( 242250 )	 -4.875555513958094
# Reward ( 242500 )	 -0.9999690978231278
# Reward ( 242750 )	 -0.9999999932276491
# Reward ( 243000 )	 -5.997769612025881
# target reached
# sending: env
# USE FAST MODE
# Reward ( 243250 )	 -0.9999996055970204
# Reward ( 243500 )	 -5.9999999707778375
# target reached
# sending: env
# USE FAST MODE
# Reward ( 243750 )	 -0.9999936945873827
# Reward ( 244000 )	 -5.998406070028628
# target reached
# sending: env
# USE FAST MODE
# sending: env
# USE FAST MODE
# Reward ( 244250 )	 -5.99995808282067
# Reward ( 244500 )	 -0.9999459581771013
# Reward ( 244750 )	 -5.999983196157403
# Reward ( 245000 )	 -5.999999993550728
# Reward ( 245250 )	 -5.9999999786873985
# Reward ( 245500 )	 -5.999999977339443
# Reward ( 245750 )	 -2.907894652546515
# target reached
# sending: env
# USE FAST MODE
# Reward ( 246000 )	 -0.9999895676350988
# Reward ( 246250 )	 -0.9990705044136539
# Reward ( 246500 )	 -5.999999662775067
# Reward ( 246750 )	 -0.9999864024702106
# Reward ( 247000 )	 -0.999999858319454
# Reward ( 247250 )	 -5.9999999999937526
# Reward ( 247500 )	 -5.9999999999992815
# Reward ( 247750 )	 -5.99999999896621
# Reward ( 248000 )	 -0.9999974867291633
# reward boundary
# sending: env
# USE FAST MODE
# sending: env
# USE FAST MODE
# Reward ( 248250 )	 -0.9999983518743821
# Reward ( 248500 )	 -5.979854702739161
# Reward ( 248750 )	 -5.999999961834897
# Reward ( 249000 )	 -5.999999987920347
# Reward ( 249250 )	 -5.999999993356382
# Reward ( 249500 )	 -0.9999999810909699
# Reward ( 249750 )	 -5.999999946659989
# Reward ( 250000 )	 -5.999999958414319
# Reward ( 250250 )	 -5.99999999974649
# reward boundary
# sending: env
# USE FAST MODE
# Reward ( 250500 )	 -0.9999843487790665
# Reward ( 250750 )	 -5.999999926591698
# Reward ( 251000 )	 -5.9999999971650935
# sending: env
# USE FAST MODE
# Reward ( 251250 )	 -0.9999220174812036
# Reward ( 251500 )	 -5.999373947472058
# Reward ( 251750 )	 -5.999999990459578
# Reward ( 252000 )	 -5.99999995739975
# Reward ( 252250 )	 -5.999999994410928
# Reward ( 252500 )	 -5.9999999999460725
# Reward ( 252750 )	 -5.999999995126318
# Reward ( 253000 )	 -5.984643899276964
# Reward ( 253250 )	 -3.1017505274754544
# reward boundary
# sending: env
# USE FAST MODE
# Reward ( 253500 )	 -0.9999967693389844
# Reward ( 253750 )	 -0.9999993003159218
# Reward ( 254000 )	 -0.9999980380313829
# Reward ( 254250 )	 -5.774568988483058
# Reward ( 254500 )	 -5.325230610849642
# Reward ( 254750 )	 -4.821723362845759
# Reward ( 255000 )	 -4.98286316909263
# Reward ( 255250 )	 -5.192896304987782
# Reward ( 255500 )	 -3.269514483848681
# Reward ( 255750 )	 6.6359935387784255
# Reward ( 256000 )	 -4.53502539302128
# Reward ( 256250 )	 -5.493242225788704
# reward boundary
# sending: env
# USE FAST MODE
# Reward ( 256500 )	 -0.9999962847300966
# Reward ( 256750 )	 -0.9999818332827323
# Reward ( 257000 )	 -0.9996488126720628
# Reward ( 257250 )	 -5.999999990686621
# Reward ( 257500 )	 -0.9999977782088033
# Reward ( 257750 )	 -5.999999992680746
# Reward ( 258000 )	 -5.999999986845806
# Reward ( 258250 )	 -5.999975081866319
# target reached
# sending: env
# USE FAST MODE
# Reward ( 258500 )	 -0.999982579228471
# Reward ( 258750 )	 -5.999999998708825
# Reward ( 259000 )	 -5.999999999884153
# Reward ( 259250 )	 -5.9999999999989475
# Reward ( 259500 )	 -0.9998497509539698
# Reward ( 259750 )	 -0.9999999893083698
# Reward ( 260000 )	 -5.999806693245557
# Reward ( 260250 )	 -4.351989121869353
# Reward ( 260500 )	 -5.96918506818967
# reward boundary
# sending: env
# USE FAST MODE
# Reward ( 260750 )	 -0.999995036365827
# Reward ( 261000 )	 -5.999999959053039
# Reward ( 261250 )	 -5.999999962302217
# Reward ( 261500 )	 -5.9999999922992675
# Reward ( 261750 )	 -5.999988039122927
# Reward ( 262000 )	 -5.984142615749516
# Reward ( 262250 )	 -5.490396453630526
# Reward ( 262500 )	 -0.6537714724051171
# Reward ( 262750 )	 -5.100930196702196
# reward boundary
# sending: env
# USE FAST MODE
# Reward ( 263000 )	 -0.9999999972394787
# Reward ( 263250 )	 -5.999999999998471
# Reward ( 263500 )	 -5.999999999995891
# Reward ( 263750 )	 -5.999999999999606
# Reward ( 264000 )	 -5.999999999999481
# Reward ( 264250 )	 -5.99999999999818
# Reward ( 264500 )	 -5.999999999999349
# Reward ( 264750 )	 -5.999999999999357
# reward boundary
# sending: env
# USE FAST MODE
# Reward ( 265000 )	 -0.9999700437819231
# Reward ( 265250 )	 -0.9999984105400098
# Reward ( 265500 )	 -5.9999999809636355
# Reward ( 265750 )	 -0.9999999634258674
# Reward ( 266000 )	 -5.999999590100938
# Reward ( 266250 )	 -5.999954571178894
# Reward ( 266500 )	 -5.996628340332872
# Reward ( 266750 )	 -5.786173529520053
# Reward ( 267000 )	 -3.247965154428012
# reward boundary
# sending: env
# USE FAST MODE
# Reward ( 267250 )	 -0.9999886635326877
# Reward ( 267500 )	 -5.99999999752408
# Reward ( 267750 )	 -5.999999982011133
# Reward ( 268000 )	 -0.9999993444559447
# Reward ( 268250 )	 -5.858503535876629
# Reward ( 268500 )	 10000
# target reached
# sending: env
# USE FAST MODE
# Reward ( 268750 )	 -0.9999999987158154
# Reward ( 269000 )	 -5.999999999298257
# Reward ( 269250 )	 -5.9999999943628355
# Reward ( 269500 )	 -5.99999997452245
# Reward ( 269750 )	 -5.999999977713242
# Reward ( 270000 )	 -5.99999997026635
# Reward ( 270250 )	 -0.9998247937938178
# Reward ( 270500 )	 -0.9996543604782779
# Reward ( 270750 )	 -0.9251376798470827
# Reward ( 271000 )	 -0.986249199444745
# Reward ( 271250 )	 1.5261914808314208
# target reached
# sending: env
# USE FAST MODE
# Reward ( 271500 )	 -0.9998055261012437
# Reward ( 271750 )	 1.6259339730266333
# Reward ( 272000 )	 -5.376053044537943
# Reward ( 272250 )	 2.4522573961014724
# Reward ( 272500 )	 -0.9992067768174477
# Reward ( 272750 )	 -0.9629784305382819
# Reward ( 273000 )	 -0.9999714172921248
# Reward ( 273250 )	 -0.999994302775447
# Reward ( 273500 )	 -0.9999995329872785
# Reward ( 273750 )	 -5.999999975356813
# Reward ( 274000 )	 -5.999999991220921
# Reward ( 274250 )	 -5.999999955058825
# Reward ( 274500 )	 -5.9999985992321
# Reward ( 274750 )	 -0.9999995943302079
# Reward ( 275000 )	 -0.9999955845986267
# Reward ( 275250 )	 -0.9999949964656717
# Reward ( 275500 )	 -0.9879789884748699
# Reward ( 275750 )	 -0.9999623228497772
# Reward ( 276000 )	 -0.9999997494776093
# reward boundary
# sending: env
# USE FAST MODE
# Reward ( 276250 )	 -0.9999977903130028
# Reward ( 276500 )	 -0.9990299456167879
# Reward ( 276750 )	 -5.991933189118776
# Reward ( 277000 )	 -5.999989300243749
# Reward ( 277250 )	 -0.9999977445486857
# Reward ( 277500 )	 -0.9999911161994994
# Reward ( 277750 )	 -0.9999954180872219
# Reward ( 278000 )	 -0.999999945369294
# Reward ( 278250 )	 -5.999999958696233
# Reward ( 278500 )	 -5.999999940079157
# Reward ( 278750 )	 -5.999999899289801
# Reward ( 279000 )	 -0.9999999587943653
# Reward ( 279250 )	 -5.999999996009071
# reward boundary
# sending: env
# USE FAST MODE
# Reward ( 279500 )	 -0.9999897602006179
# Reward ( 279750 )	 -0.9999798948111916
# Reward ( 280000 )	 -5.999999974639723
# Reward ( 280250 )	 -5.999999994014711
# Reward ( 280500 )	 -5.9999999968876825
# Reward ( 280750 )	 -5.999999999782549
# Reward ( 281000 )	 -0.9999993508460016
# Reward ( 281250 )	 -0.9999989020004425
# Reward ( 281500 )	 -5.999999994010585
# Reward ( 281750 )	 -0.999999651835088
# Reward ( 282000 )	 -0.9744165443928824
# Reward ( 282250 )	 -5.408139136161219
# Reward ( 282500 )	 -0.988909134684274
# Reward ( 282750 )	 -0.9812589389716823
# Reward ( 283000 )	 1.2545860316005735
# Reward ( 283250 )	 -0.36128797086317044
# Reward ( 283500 )	 0.7110778948615128
# target reached
# sending: env
# USE FAST MODE
# Reward ( 283750 )	 -5.99999999999974
# Reward ( 284000 )	 -5.999999999999556
# Reward ( 284250 )	 -5.999999999999113
# Reward ( 284500 )	 -5.999999999998402
# Reward ( 284750 )	 -5.999999999994934
# Reward ( 285000 )	 -5.999999999993313
# Reward ( 285250 )	 -5.999999999994994
# reward boundary
# sending: env
# USE FAST MODE
# Reward ( 285500 )	 -5.999999998451435
# Reward ( 285750 )	 -5.999999997002798
# Reward ( 286000 )	 -0.999999748390647
# Reward ( 286250 )	 -5.999999999721524
# Reward ( 286500 )	 -5.999999999896981
# Reward ( 286750 )	 -5.999999997121447
# Reward ( 287000 )	 -0.9992449973958106
# Reward ( 287250 )	 -0.9999999781505725
# Reward ( 287500 )	 -0.9999916343780562
# Reward ( 287750 )	 -5.999999999982184
# Reward ( 288000 )	 -5.99999999999956
# reward boundary
# sending: env
# USE FAST MODE
# sending: env
# USE FAST MODE
# Reward ( 288250 )	 -0.9999991256234673
# Reward ( 288500 )	 -5.999999969902322
# Reward ( 288750 )	 -0.9999965025403571
# Reward ( 289000 )	 -5.999999994728482
# Reward ( 289250 )	 -0.9999940472016132
# Reward ( 289500 )	 -5.999999996048118
# Reward ( 289750 )	 -5.999999992551779
# Reward ( 290000 )	 -0.9884232864156627
# Reward ( 290250 )	 -0.9980888626146028
# Reward ( 290500 )	 -0.9989626697690724
# Reward ( 290750 )	 -0.9999998959902442
# Reward ( 291000 )	 -0.9566611088016448
# Reward ( 291250 )	 -0.9999999695141647
# reward boundary
# sending: env
# USE FAST MODE
# Reward ( 291500 )	 -0.99996494036261
# Reward ( 291750 )	 -5.999999948607616
# Reward ( 292000 )	 -5.999999965864192
# Reward ( 292250 )	 -0.9999999901446338
# Reward ( 292500 )	 -2.2367540623953452
# Reward ( 292750 )	 -4.688158650333715
# Reward ( 293000 )	 -5.571910552176494
# Reward ( 293250 )	 -4.608347272404151
# Reward ( 293500 )	 -3.8710727836986445
# Reward ( 293750 )	 -2.230388109163565
# Reward ( 294000 )	 -0.9777053816595166
# Reward ( 294250 )	 -0.9995388518862722
# Reward ( 294500 )	 -0.9982189855346199
# Reward ( 294750 )	 -0.9999471239875096
# Reward ( 295000 )	 -0.9999970141770568
# reward boundary
# sending: env
# USE FAST MODE
# Reward ( 295250 )	 -0.9999999999303852
# Reward ( 295500 )	 -5.999999999999327
# Reward ( 295750 )	 -5.999999999999667
# Reward ( 296000 )	 -5.999999999999022
# Reward ( 296250 )	 -5.9999999999974385
# Reward ( 296500 )	 -0.9999999982190678
# Reward ( 296750 )	 -0.999996897419578
# Reward ( 297000 )	 -5.999999948626754
# Reward ( 297250 )	 -0.999999997414647
# Reward ( 297500 )	 -0.9896592929755843
# reward boundary
# sending: env
# USE FAST MODE
# sending: env
# USE FAST MODE
# Reward ( 297750 )	 -0.9999857041911496
# Reward ( 298000 )	 -0.9999157366169995
# Reward ( 298250 )	 -0.9999492552664989
# Reward ( 298500 )	 -0.9999999188410381
# Reward ( 298750 )	 -5.999999996336507
# Reward ( 299000 )	 -5.999999991432865
# Reward ( 299250 )	 -5.999999981003835
# Reward ( 299500 )	 -5.999999978541411
# Reward ( 299750 )	 -0.9999999792535301
# Reward ( 300000 )	 -5.999999474267541
# Reward ( 300250 )	 -5.999999986217569
# reward boundary
# sending: env
# USE FAST MODE
# Reward ( 300500 )	 -0.9999999991585451
# Reward ( 300750 )	 -0.9999999996881304
# Reward ( 301000 )	 -5.999999999946333
# Reward ( 301250 )	 -5.999999999999725
# sending: env
# USE FAST MODE
# Reward ( 301500 )	 -0.999997740503794
# Reward ( 301750 )	 -0.9999999892438622
# Reward ( 302000 )	 -0.9999780668536384
# Reward ( 302250 )	 -0.996054699642257
# Reward ( 302500 )	 -0.9999825920579769
# Reward ( 302750 )	 -5.987701246013742
# Reward ( 303000 )	 -0.9999999517575432
# Reward ( 303250 )	 -5.999999991125151
# Reward ( 303500 )	 -5.999999994353784
# Reward ( 303750 )	 -5.999999988355009
# Reward ( 304000 )	 -5.999999984038232
# Reward ( 304250 )	 -5.999999994336064
# reward boundary
# sending: env
# USE FAST MODE
# Reward ( 304500 )	 -0.9999951376351788
# Reward ( 304750 )	 -0.9999929992067733
# Reward ( 305000 )	 -5.768275197590887
# Reward ( 305250 )	 -4.736616745311046
# Reward ( 305500 )	 -5.8409781298851104
# Reward ( 305750 )	 -5.999857900133358
# target reached
# sending: env
# USE FAST MODE
# Reward ( 306000 )	 -0.9999999988880577
# Reward ( 306250 )	 -5.9999999997603295
# Reward ( 306500 )	 -0.9999999299775713
# Reward ( 306750 )	 -5.99999999999888
# Reward ( 307000 )	 -0.9999999994675464
# Reward ( 307250 )	 -0.9999999582375277
# Reward ( 307500 )	 -0.9999758294270973
# target reached
# sending: env
# USE FAST MODE
# Reward ( 307750 )	 -0.9999984255388524
# Reward ( 308000 )	 -0.997432263507301
# Reward ( 308250 )	 -0.8750231820184082
# Reward ( 308500 )	 -5.999999925090622
# Reward ( 308750 )	 -0.9999999197421595
# Reward ( 309000 )	 -5.999998335439857
# Reward ( 309250 )	 -5.688303313906871
# Reward ( 309500 )	 -5.996077722063189
# Reward ( 309750 )	 -0.9999992899494805
# Reward ( 310000 )	 -5.9999999814363445
# reward boundary
# sending: env
# USE FAST MODE
# Reward ( 310250 )	 -0.9999951928498199
# Reward ( 310500 )	 -0.9999984105615736
# Reward ( 310750 )	 -5.9999999577907275
# Reward ( 311000 )	 -5.999999995751398
# Reward ( 311250 )	 -5.999999204247658
# Reward ( 311500 )	 -5.9999999971088895
# target reached
# sending: env
# USE FAST MODE
# Reward ( 311750 )	 -0.999998611566239
# Reward ( 312000 )	 -5.999999699391292
# Reward ( 312250 )	 -5.999999671371539
# Reward ( 312500 )	 -5.676892697997199
# target reached
# sending: env
# USE FAST MODE
# Reward ( 312750 )	 -0.9999999988624031
# Reward ( 313000 )	 -0.9999999999263727
# Reward ( 313250 )	 -0.9999998864668034
# Reward ( 313500 )	 -0.9999998917813089
# Reward ( 313750 )	 -5.9999999660630134
# Reward ( 314000 )	 -5.999999968812611
# Reward ( 314250 )	 -5.999999995908558
# Reward ( 314500 )	 -5.9999999999623626
# Reward ( 314750 )	 -5.9999999999989075
# reward boundary
# sending: env
# USE FAST MODE
# Reward ( 315000 )	 -0.9999948735862615
# Reward ( 315250 )	 -5.9998035851419464
# Reward ( 315500 )	 -0.86751261441148
# Reward ( 315750 )	 -5.999984541761415
# Reward ( 316000 )	 8.966677927678013
# Reward ( 316250 )	 -5.287938564282564
# Reward ( 316500 )	 -4.775885180445681
# Reward ( 316750 )	 -3.4401938307344557
# Reward ( 317000 )	 -2.768967304289386
# Reward ( 317250 )	 -0.6921438792985083
# Reward ( 317500 )	 -5.999992789092166
# target reached
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-86e7eaab7dd8> in <module>
#       1 while True:
# ----> 2     model.learn(total_timesteps=50000, log_interval=10000)
#       3     model.save("models/" + model_name)
#       4
#       5 # model = PPO1.load("models/{}".format('DQN_WebotFakeMini_TRPO_pj1_nReward2_200000'))
#
# ~/anaconda3/envs/spinningup/lib/python3.6/site-packages/stable_baselines/ppo1/pposgd_simple.py in learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps)
#     240                     logger.log("********** Iteration %i ************" % iters_so_far)
#     241
# --> 242                     seg = seg_gen.__next__()
#     243
#     244                     # Stop training early (triggered by the callback)
#
# ~/anaconda3/envs/spinningup/lib/python3.6/site-packages/stable_baselines/common/runners.py in traj_segment_generator(policy, env, horizon, reward_giver, gail, callback)
#     204             current_ep_len = 0
#     205             if not isinstance(env, VecEnv):
# --> 206                 observation = env.reset()
#     207         step += 1
#
# ~/uni/ees-pees/backend/webotsgym/environment.py in reset(self)
#     177             # print("resetting with seed: ", seed)
#     178             # self.supervisor.reset_environment(self.main_seed) # this leads to breakdown of robbie
# --> 179             self.supervisor.start_env(self.main_seed)
#     180             # print("========= TARGET", self.config.gps_target)
#     181
#
# ~/uni/ees-pees/backend/webotsgym/automate.py in start_env(self, seed, waiting_time)
#     107     def start_env(self, seed=None, waiting_time=1):
#     108         """Start environment with seed and config info."""
# --> 109         self.extr_ctrl.reset()
#     110         if seed is None:
#     111             seed = utils.set_random_seed()
#
# ~/uni/ees-pees/backend/webotsgym/automate.py in reset(self)
#     171         """Reset external controller."""
#     172         self.close()
# --> 173         self.init()
#     174
#     175     def compile(self):
#
# ~/uni/ees-pees/backend/webotsgym/automate.py in init(self)
#     166     def init(self):
#     167         self.compile()
# --> 168         self.start()
#     169
#     170     def reset(self):
#
# ~/uni/ees-pees/backend/webotsgym/automate.py in start(self)
#     184         """Start external controller."""
#     185         subprocess.Popen([os.path.join(get_repo_dir(),
# --> 186                                        "controller/build/controller")])
#     187
#     188     def close(self):
#
# ~/anaconda3/envs/spinningup/lib/python3.6/subprocess.py in __init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, encoding, errors)
#     727                                 c2pread, c2pwrite,
#     728                                 errread, errwrite,
# --> 729                                 restore_signals, start_new_session)
#     730         except:
#     731             # Cleanup if the child failed starting.
#
# ~/anaconda3/envs/spinningup/lib/python3.6/subprocess.py in _execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, restore_signals, start_new_session)
#    1362                         if errno_num == errno.ENOENT:
#    1363                             err_msg += ': ' + repr(err_filename)
# -> 1364                     raise child_exception_type(errno_num, err_msg, err_filename)
#    1365                 raise child_exception_type(err_msg)
#    1366
#
# FileNotFoundError: [Errno 2] No such file or directory: '/home/fabian/uni/ees-pees/controller/build/controller': '/home/fabian/uni/ees-pees/controller/build/controller'

# %%
model = PPO1.load("models/Webots_find_target_small")

def exponential_decay(x, N0=1, lambda_=5):
    return N0*np.exp(-lambda_*x)

class MyObs(Observation):
    def __init__(self, env):
        super(MyObs, self).__init__(env)
        self.env = env

class MyEval(Evaluate):
    def __init__(self, env, config: WebotConfig = WebotConfig()):
        super(MyEval, self).__init__(env, config)
        self.reward_range = (-1000, 1000)

    def calc_reward(self):
        reward = -1
        distance_norm = self.env.get_target_distance()
        distance_abs = self.env.get_target_distance(False)

        if distance_abs < 0.1 and abs(self.env.state.speed) < 0.05 and self.env.state.touching is False:
            return 10000
        else:
            reward += 2500 * exponential_decay(distance_abs, lambda_=40) * exponential_decay(abs(self.env.state.speed), lambda_=10)
        
        if self.env.state.touching:
             reward -= 5
        return reward

    def check_done(self):
        if self.env.total_reward < -10000:
            print("reward boundary")
            return True
        if self.env.get_target_distance(False) < 0.1 and abs(self.env.state.speed) < 0.05 and self.env.state.touching is False:
            print("target reached")
            return True
        return False
    

config = WebotConfig()
config.fast_simulation = False
config.reset_env_after = 200000
config.num_obstacles = 0
config.world_size = 2
config.world_scaling = 0.5

action_class = ContinuousAction(direction_type="steering", relative=False)
env = WebotsEnv(train=True, 
                action_class=action_class, 
                evaluate_class=MyEval,
                observation_class=MyObs,
                config=config)

obs = env.reset()

for _ in range(100000):
    action, _states = model.predict(obs)
    obs, rewards, done, info = env.step(action)
    env.render()
    if done is True:
        break

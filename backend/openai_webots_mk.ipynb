# %%
import webotsgym as wg

from webotsgym.config import WebotConfig
from webotsgym.environment import WebotsEnv, WebotsGrid
from webotsgym.evaluate import Evaluate, EvaluateMats, EvaluatePJ0
from webotsgym.action import DiscreteAction, ContinuousAction
from webotsgym.observation import Observation

import numpy as np

import gym
import stable_baselines
from stable_baselines import A2C, ACER, ACKTR, DQN, DDPG, SAC, PPO1, PPO2, TD3, TRPO
from stable_baselines.common.env_checker import check_env
from stable_baselines.common.policies import MlpPolicy
# Out:
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.

# %%
class MyObs(Observation):
    def __init__(self, env):
        super(MyObs, self).__init__(env)
        self.env = env

class MyEval(Evaluate):
    def __init__(self, env, config: WebotConfig = WebotConfig()):
        super(MyEval, self).__init__(env, config)
        self.reward_range = (-100, 100)

    def calc_reward(self):
        if self.env.get_target_distance() < 0.1:
            return self.reward_range[1]
        else:
            dist = self.env.get_target_distance()
            denom = self.env.max_distance / 2
            return -1 * np.tanh(dist / denom)

    def check_done(self):
        if self.env.iterations % self.config.reset_env_after == 0:
            return True
        if self.env.get_target_distance() < 0.25:
            return True
        return False
    

config = WebotConfig()
config.fast_simulation = False
config.reset_env_after = 20000
config.num_obstacles = 2
config.world_size = 8
config.world_scaling = 0.5
#action_class = ContinuousAction(direction_type="steering", relative=False)
env = WebotsGrid(train=True, 
                evaluate_class=MyEval,
                config=config)
# Out:
# /home/mats/anaconda3/lib/python3.7/site-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# Accepting on Port:  10201
# sending: env

# %%
env.step(2)
# Out:
# (array([0.2651177 , 1.76268482, 2.25      , 3.25      , 0.21443133,
#         0.21407032, 1.72854364, 3.5       , 0.        ]),
#  None,
#  None,
#  {})

# %%
time_steps = 499999
model_name = "Webots2"

model = PPO1("MlpPolicy", env, verbose=1)
model.learn(total_timesteps=time_steps, log_interval=100)
model.save("models/{}".format(model_name))

# model = PPO1.load("models/{}".format('DQN_WebotFakeMini_TRPO_pj1_nReward2_200000'))
# env = MyEnv()
# obs = env.reset()

# env.render()
# done = False
# max_num_steps = 100
# time = 0
# Out:
# WARNING:tensorflow:From /home/pj/anaconda3/envs/spinningup/lib/python3.6/site-packages/stable_baselines/common/tf_util.py:191: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /home/pj/anaconda3/envs/spinningup/lib/python3.6/site-packages/stable_baselines/common/tf_util.py:200: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# WARNING:tensorflow:From /home/pj/anaconda3/envs/spinningup/lib/python3.6/site-packages/stable_baselines/common/policies.py:116: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# WARNING:tensorflow:From /home/pj/anaconda3/envs/spinningup/lib/python3.6/site-packages/stable_baselines/common/input.py:25: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /home/pj/anaconda3/envs/spinningup/lib/python3.6/site-packages/stable_baselines/common/policies.py:561: flatten (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.flatten instead.
# WARNING:tensorflow:From /home/pj/anaconda3/envs/spinningup/lib/python3.6/site-packages/tensorflow_core/python/layers/core.py:332: Layer.apply (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.__call__` method instead.
# WARNING:tensorflow:From /home/pj/anaconda3/envs/spinningup/lib/python3.6/site-packages/stable_baselines/common/tf_layers.py:123: The name tf.get_variable is deprecated. Please use tf.compat.v1.get_variable instead.
#
# WARNING:tensorflow:From /home/pj/anaconda3/envs/spinningup/lib/python3.6/site-packages/stable_baselines/common/distributions.py:418: The name tf.random_normal is deprecated. Please use tf.random.normal instead.
#
# WARNING:tensorflow:From /home/pj/anaconda3/envs/spinningup/lib/python3.6/site-packages/stable_baselines/ppo1/pposgd_simple.py:153: The name tf.summary.scalar is deprecated. Please use tf.compat.v1.summary.scalar instead.
#
# WARNING:tensorflow:From /home/pj/anaconda3/envs/spinningup/lib/python3.6/site-packages/stable_baselines/common/tf_util.py:449: The name tf.get_collection is deprecated. Please use tf.compat.v1.get_collection instead.
#
# WARNING:tensorflow:From /home/pj/anaconda3/envs/spinningup/lib/python3.6/site-packages/stable_baselines/common/tf_util.py:449: The name tf.GraphKeys is deprecated. Please use tf.compat.v1.GraphKeys instead.
#
# WARNING:tensorflow:From /home/pj/anaconda3/envs/spinningup/lib/python3.6/site-packages/stable_baselines/ppo1/pposgd_simple.py:163: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# WARNING:tensorflow:From /home/pj/anaconda3/envs/spinningup/lib/python3.6/site-packages/stable_baselines/common/tf_util.py:241: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From /home/pj/anaconda3/envs/spinningup/lib/python3.6/site-packages/stable_baselines/common/tf_util.py:242: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
#
# WARNING:tensorflow:From /home/pj/anaconda3/envs/spinningup/lib/python3.6/site-packages/stable_baselines/ppo1/pposgd_simple.py:191: The name tf.summary.merge_all is deprecated. Please use tf.compat.v1.summary.merge_all instead.
#
# WARNING:tensorflow:From /home/pj/anaconda3/envs/spinningup/lib/python3.6/site-packages/tensorflow_core/python/ops/math_grad.py:1424: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# ********** Iteration 0 ************
# sending: reset
# Reward ( 250 )	 -0.09901840057042414
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#      -0.00247 |      -0.02835 |       0.90671 |       0.00124 |       2.83529
#      -0.00446 |      -0.02833 |       0.26141 |       0.00557 |       2.83279
#      -0.00820 |      -0.02831 |       0.13836 |       0.00745 |       2.83147
#      -0.01132 |      -0.02829 |       0.09601 |       0.00545 |       2.82915
# Evaluating losses...
#      -0.01295 |      -0.02827 |       0.07373 |       0.00439 |       2.82738
# ----------------------------------
# | EpThisIter      | 0            |
# | EpisodesSoFar   | 0            |
# | TimeElapsed     | 5.83         |
# | TimestepsSoFar  | 256          |
# | ev_tdlam_before | 0.232        |
# | loss_ent        | 2.827381     |
# | loss_kl         | 0.004386589  |
# | loss_pol_entpen | -0.028273808 |
# | loss_pol_surr   | -0.01294611  |
# | loss_vf_loss    | 0.07372631   |
# ----------------------------------
# ********** Iteration 1 ************
# Reward ( 500 )	 -0.08983078676673804
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#       0.00085 |      -0.02826 |       1.05780 |       0.00015 |       2.82644
#      -0.00742 |      -0.02824 |       0.12703 |       0.00442 |       2.82407
#      -0.00911 |      -0.02822 |       0.25815 |       0.01391 |       2.82226
#      -0.00959 |      -0.02821 |       0.11779 |       0.01306 |       2.82129
# Evaluating losses...
#      -0.01051 |      -0.02821 |       0.03525 |       0.00778 |       2.82092
# ----------------------------------
# | EpThisIter      | 0            |
# | EpisodesSoFar   | 0            |
# | TimeElapsed     | 6.51         |
# | TimestepsSoFar  | 512          |
# | ev_tdlam_before | -0.274       |
# | loss_ent        | 2.8209155    |
# | loss_kl         | 0.0077830097 |
# | loss_pol_entpen | -0.028209154 |
# | loss_pol_surr   | -0.010512762 |
# | loss_vf_loss    | 0.035247445  |
# ----------------------------------
# ********** Iteration 2 ************
# Reward ( 750 )	 -0.08086898658726059
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#      -0.00317 |      -0.02820 |       0.73330 |       0.00177 |       2.82045
#      -0.00830 |      -0.02819 |       0.23912 |       0.00970 |       2.81925
#      -0.00794 |      -0.02817 |       0.04650 |       0.01337 |       2.81736
#      -0.01038 |      -0.02815 |       0.06815 |       0.01014 |       2.81545
# Evaluating losses...
#      -0.01163 |      -0.02814 |       0.06411 |       0.00794 |       2.81443
# ----------------------------------
# | EpThisIter      | 0            |
# | EpisodesSoFar   | 0            |
# | TimeElapsed     | 7.19         |
# | TimestepsSoFar  | 768          |
# | ev_tdlam_before | 0.124        |
# | loss_ent        | 2.8144321    |
# | loss_kl         | 0.007936165  |
# | loss_pol_entpen | -0.02814432  |
# | loss_pol_surr   | -0.011633769 |
# | loss_vf_loss    | 0.06411253   |
# ----------------------------------
# ********** Iteration 3 ************
# Reward ( 1000 )	 -0.0721549056769936
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#       0.00142 |      -0.02814 |       0.28176 |      8.54e-05 |       2.81384
#      -0.00087 |      -0.02812 |       0.04585 |       0.00059 |       2.81240
#      -0.00083 |      -0.02811 |       0.06898 |       0.00193 |       2.81095
#      -0.00504 |      -0.02809 |       0.06876 |       0.00287 |       2.80949
# Evaluating losses...
#      -0.00854 |      -0.02809 |       0.03683 |       0.00357 |       2.80851
# ----------------------------------
# | EpThisIter      | 0            |
# | EpisodesSoFar   | 0            |
# | TimeElapsed     | 7.88         |
# | TimestepsSoFar  | 1024         |
# | ev_tdlam_before | -0.737       |
# | loss_ent        | 2.8085146    |
# | loss_kl         | 0.0035684684 |
# | loss_pol_entpen | -0.028085146 |
# | loss_pol_surr   | -0.008536599 |
# | loss_vf_loss    | 0.03683484   |
# ----------------------------------
# ********** Iteration 4 ************
# Reward ( 1250 )	 -0.06874051284263437
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#      -0.00232 |      -0.02808 |       0.18215 |       0.00038 |       2.80783
#      -0.01933 |      -0.02807 |       0.07625 |       0.00890 |       2.80670
#      -0.01969 |      -0.02806 |       0.01232 |       0.01690 |       2.80576
#      -0.02241 |      -0.02805 |       0.03030 |       0.01525 |       2.80497
# Evaluating losses...
#      -0.02426 |      -0.02805 |       0.03608 |       0.01285 |       2.80459
# ----------------------------------
# | EpThisIter      | 0            |
# | EpisodesSoFar   | 0            |
# | TimeElapsed     | 8.56         |
# | TimestepsSoFar  | 1280         |
# | ev_tdlam_before | -0.116       |
# | loss_ent        | 2.804593     |
# | loss_kl         | 0.012853502  |
# | loss_pol_entpen | -0.02804593  |
# | loss_pol_surr   | -0.024258677 |
# | loss_vf_loss    | 0.03607729   |
# ----------------------------------
# ********** Iteration 5 ************
# Reward ( 1500 )	 -0.06585694114115476
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#       0.00228 |      -0.02804 |       0.05217 |       0.00043 |       2.80419
#       0.00110 |      -0.02804 |       0.01043 |       0.00262 |       2.80379
#      -0.00201 |      -0.02804 |       0.00942 |       0.00533 |       2.80365
#      -0.00165 |      -0.02804 |       0.01435 |       0.00693 |       2.80371
# Evaluating losses...
#      -0.00477 |      -0.02804 |       0.00628 |       0.00685 |       2.80389
# ----------------------------------
# | EpThisIter      | 0            |
# | EpisodesSoFar   | 0            |
# | TimeElapsed     | 9.25         |
# | TimestepsSoFar  | 1536         |
# | ev_tdlam_before | 0.0578       |
# | loss_ent        | 2.8038912    |
# | loss_kl         | 0.006846484  |
# | loss_pol_entpen | -0.028038912 |
# | loss_pol_surr   | -0.00477265  |
# | loss_vf_loss    | 0.0062790904 |
# ----------------------------------
# ********** Iteration 6 ************
# Reward ( 1750 )	 -0.05784185629148178
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#       0.00115 |      -0.02804 |       0.01147 |       0.00010 |       2.80434
#      -0.00094 |      -0.02807 |       0.00617 |       0.00079 |       2.80663
#      -0.00446 |      -0.02810 |       0.00250 |       0.00297 |       2.80978
#      -0.00524 |      -0.02813 |       0.00454 |       0.00528 |       2.81297
# Evaluating losses...
#      -0.00572 |      -0.02815 |       0.00311 |       0.00770 |       2.81479
# -----------------------------------
# | EpThisIter      | 0             |
# | EpisodesSoFar   | 0             |
# | TimeElapsed     | 9.93          |
# | TimestepsSoFar  | 1792          |
# | ev_tdlam_before | -0.124        |
# | loss_ent        | 2.8147852     |
# | loss_kl         | 0.0077016186  |
# | loss_pol_entpen | -0.028147852  |
# | loss_pol_surr   | -0.0057228506 |
# | loss_vf_loss    | 0.0031131767  |
# -----------------------------------
# ********** Iteration 7 ************
# Reward ( 2000 )	 -0.06093952060038914
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#      -0.00136 |      -0.02816 |       0.00566 |       0.00039 |       2.81566
#      -0.00620 |      -0.02818 |       0.00149 |       0.00610 |       2.81783
#      -0.00672 |      -0.02819 |       0.00115 |       0.01381 |       2.81931
#      -0.00834 |      -0.02820 |       0.00173 |       0.01169 |       2.82010
# Evaluating losses...
#      -0.00897 |      -0.02820 |       0.00097 |       0.00885 |       2.82047
# -----------------------------------
# | EpThisIter      | 0             |
# | EpisodesSoFar   | 0             |
# | TimeElapsed     | 10.6          |
# | TimestepsSoFar  | 2048          |
# | ev_tdlam_before | -0.0616       |
# | loss_ent        | 2.8204744     |
# | loss_kl         | 0.008852129   |
# | loss_pol_entpen | -0.028204743  |
# | loss_pol_surr   | -0.008971464  |
# | loss_vf_loss    | 0.00097236934 |
# -----------------------------------
# ********** Iteration 8 ************
# Reward ( 2250 )	 -0.06203694208017342
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#       0.00233 |      -0.02820 |       0.00906 |       0.00070 |       2.82036
#      -0.00952 |      -0.02820 |       0.00371 |       0.00300 |       2.82041
#      -0.00966 |      -0.02820 |       0.00255 |       0.00643 |       2.82012
#      -0.01210 |      -0.02820 |       0.00329 |       0.00799 |       2.81966
# Evaluating losses...
#      -0.01323 |      -0.02819 |       0.00268 |       0.00677 |       2.81932
# ----------------------------------
# | EpThisIter      | 0            |
# | EpisodesSoFar   | 0            |
# | TimeElapsed     | 11.3         |
# | TimestepsSoFar  | 2304         |
# | ev_tdlam_before | -3.32        |
# | loss_ent        | 2.8193166    |
# | loss_kl         | 0.0067719975 |
# | loss_pol_entpen | -0.028193166 |
# | loss_pol_surr   | -0.013233162 |
# | loss_vf_loss    | 0.0026792015 |
# ----------------------------------
# ********** Iteration 9 ************
# Reward ( 2500 )	 -0.06310355911950766
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#       0.00010 |      -0.02819 |       0.01237 |      3.65e-05 |       2.81920
#      -0.00101 |      -0.02818 |       0.00349 |       0.00043 |       2.81821
#      -0.00479 |      -0.02816 |       0.00203 |       0.00167 |       2.81629
#      -0.00416 |      -0.02814 |       0.00368 |       0.00691 |       2.81423
# Evaluating losses...
#      -0.00776 |      -0.02813 |       0.00239 |       0.01138 |       2.81283
# -----------------------------------
# | EpThisIter      | 0             |
# | EpisodesSoFar   | 0             |
# | TimeElapsed     | 12            |
# | TimestepsSoFar  | 2560          |
# | ev_tdlam_before | 0.0777        |
# | loss_ent        | 2.8128335     |
# | loss_kl         | 0.011376802   |
# | loss_pol_entpen | -0.028128335  |
# | loss_pol_surr   | -0.0077620223 |
# | loss_vf_loss    | 0.0023929875  |
# -----------------------------------
# ********** Iteration 10 ************
# Reward ( 2750 )	 -0.07158665501915487
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#       0.00190 |      -0.02812 |       0.03135 |       0.00022 |       2.81209
#      -0.00081 |      -0.02809 |       0.00698 |       0.00677 |       2.80942
#      -0.00132 |      -0.02806 |       0.00821 |       0.01205 |       2.80613
#      -0.00563 |      -0.02802 |       0.00929 |       0.00551 |       2.80226
# Evaluating losses...
#      -0.00614 |      -0.02800 |       0.00356 |       0.00257 |       2.79954
# -----------------------------------
# | EpThisIter      | 0             |
# | EpisodesSoFar   | 0             |
# | TimeElapsed     | 12.6          |
# | TimestepsSoFar  | 2816          |
# | ev_tdlam_before | -2.02         |
# | loss_ent        | 2.799542      |
# | loss_kl         | 0.0025681227  |
# | loss_pol_entpen | -0.027995419  |
# | loss_pol_surr   | -0.0061393566 |
# | loss_vf_loss    | 0.0035610308  |
# -----------------------------------
# ********** Iteration 11 ************
# Reward ( 3000 )	 -0.07825787987721983
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#      -0.00370 |      -0.02798 |       0.05617 |       0.00065 |       2.79773
#      -0.00805 |      -0.02792 |       0.01076 |       0.00986 |       2.79241
#      -0.00779 |      -0.02787 |       0.01191 |       0.01869 |       2.78723
#      -0.01386 |      -0.02783 |       0.01312 |       0.01243 |       2.78322
# Evaluating losses...
#      -0.01495 |      -0.02781 |       0.00482 |       0.00742 |       2.78086
# ----------------------------------
# | EpThisIter      | 0            |
# | EpisodesSoFar   | 0            |
# | TimeElapsed     | 13.3         |
# | TimestepsSoFar  | 3072         |
# | ev_tdlam_before | 0.215        |
# | loss_ent        | 2.7808614    |
# | loss_kl         | 0.0074213496 |
# | loss_pol_entpen | -0.027808614 |
# | loss_pol_surr   | -0.014947783 |
# | loss_vf_loss    | 0.0048217205 |
# ----------------------------------
# ********** Iteration 12 ************
# Reward ( 3250 )	 -0.08505698987061988
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#      -0.00287 |      -0.02779 |       0.09941 |       0.00060 |       2.77937
#      -0.00845 |      -0.02776 |       0.01972 |       0.00751 |       2.77560
#      -0.00462 |      -0.02772 |       0.01165 |       0.01480 |       2.77222
#      -0.00838 |      -0.02770 |       0.02378 |       0.00840 |       2.76955
# Evaluating losses...
#      -0.01186 |      -0.02768 |       0.01787 |       0.00403 |       2.76782
# ----------------------------------
# | EpThisIter      | 0            |
# | EpisodesSoFar   | 0            |
# | TimeElapsed     | 14           |
# | TimestepsSoFar  | 3328         |
# | ev_tdlam_before | -0.134       |
# | loss_ent        | 2.7678185    |
# | loss_kl         | 0.0040302584 |
# | loss_pol_entpen | -0.027678184 |
# | loss_pol_surr   | -0.011858047 |
# | loss_vf_loss    | 0.017872717  |
# ----------------------------------
# ********** Iteration 13 ************
# Reward ( 3500 )	 -0.09436057304970316
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#       0.00395 |      -0.02767 |       0.15268 |       0.00128 |       2.76679
#      -0.00385 |      -0.02764 |       0.03817 |       0.00598 |       2.76377
#      -0.00527 |      -0.02761 |       0.00879 |       0.00883 |       2.76094
#      -0.00314 |      -0.02759 |       0.03004 |       0.00797 |       2.75862
# Evaluating losses...
#      -0.00721 |      -0.02757 |       0.03217 |       0.00564 |       2.75744
# -----------------------------------
# | EpThisIter      | 0             |
# | EpisodesSoFar   | 0             |
# | TimeElapsed     | 14.6          |
# | TimestepsSoFar  | 3584          |
# | ev_tdlam_before | -0.086        |
# | loss_ent        | 2.757437      |
# | loss_kl         | 0.0056393994  |
# | loss_pol_entpen | -0.02757437   |
# | loss_pol_surr   | -0.0072132642 |
# | loss_vf_loss    | 0.032174297   |
# -----------------------------------
# ********** Iteration 14 ************
# Reward ( 3750 )	 -0.10395823598522609
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#      -0.00052 |      -0.02757 |       0.20052 |      4.03e-05 |       2.75690
#      -0.00428 |      -0.02755 |       0.06165 |       0.00147 |       2.75539
#      -0.00479 |      -0.02754 |       0.00790 |       0.00767 |       2.75392
#      -0.00520 |      -0.02752 |       0.02806 |       0.01212 |       2.75221
# Evaluating losses...
#      -0.00591 |      -0.02751 |       0.03502 |       0.01001 |       2.75103
# ----------------------------------
# | EpThisIter      | 0            |
# | EpisodesSoFar   | 0            |
# | TimeElapsed     | 15.3         |
# | TimestepsSoFar  | 3840         |
# | ev_tdlam_before | 0.0372       |
# | loss_ent        | 2.7510333    |
# | loss_kl         | 0.010009864  |
# | loss_pol_entpen | -0.027510332 |
# | loss_pol_surr   | -0.005912196 |
# | loss_vf_loss    | 0.03502087   |
# ----------------------------------
# ********** Iteration 15 ************
# Reward ( 4000 )	 -0.1218421219412336
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#       0.00097 |      -0.02751 |       0.35541 |       0.00049 |       2.75070
#      -0.00508 |      -0.02751 |       0.11934 |       0.00443 |       2.75082
#      -0.00609 |      -0.02752 |       0.01728 |       0.01205 |       2.75171
#      -0.00728 |      -0.02753 |       0.04488 |       0.01152 |       2.75270
# Evaluating losses...
#      -0.01145 |      -0.02753 |       0.06530 |       0.01078 |       2.75327
# ----------------------------------
# | EpThisIter      | 0            |
# | EpisodesSoFar   | 0            |
# | TimeElapsed     | 16           |
# | TimestepsSoFar  | 4096         |
# | ev_tdlam_before | 0.0325       |
# | loss_ent        | 2.7532675    |
# | loss_kl         | 0.010784516  |
# | loss_pol_entpen | -0.027532674 |
# | loss_pol_surr   | -0.011450466 |
# | loss_vf_loss    | 0.065299146  |
# ----------------------------------
# ********** Iteration 16 ************
# Reward ( 4250 )	 -0.13554317299905183
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#      -0.00027 |      -0.02753 |       0.45874 |      9.10e-05 |       2.75320
#      -0.00414 |      -0.02752 |       0.15728 |       0.00216 |       2.75231
#      -0.00586 |      -0.02750 |       0.02243 |       0.00928 |       2.75036
#      -0.00697 |      -0.02748 |       0.04874 |       0.01358 |       2.74775
# Evaluating losses...
#      -0.00805 |      -0.02746 |       0.07730 |       0.01298 |       2.74599
# -----------------------------------
# | EpThisIter      | 0             |
# | EpisodesSoFar   | 0             |
# | TimeElapsed     | 16.7          |
# | TimestepsSoFar  | 4352          |
# | ev_tdlam_before | 0.00334       |
# | loss_ent        | 2.7459922     |
# | loss_kl         | 0.0129814185  |
# | loss_pol_entpen | -0.027459921  |
# | loss_pol_surr   | -0.0080517195 |
# | loss_vf_loss    | 0.07729803    |
# -----------------------------------
# ********** Iteration 17 ************
# Reward ( 4500 )	 -0.13849603982505765
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#       0.00199 |      -0.02745 |       0.33893 |       0.00039 |       2.74525
#      -0.00134 |      -0.02743 |       0.12267 |       0.00116 |       2.74338
#      -0.00362 |      -0.02742 |       0.01779 |       0.00386 |       2.74208
#      -0.00535 |      -0.02741 |       0.03496 |       0.00856 |       2.74110
# Evaluating losses...
#      -0.00483 |      -0.02741 |       0.05738 |       0.01141 |       2.74073
# ----------------------------------
# | EpThisIter      | 0            |
# | EpisodesSoFar   | 0            |
# | TimeElapsed     | 17.3         |
# | TimestepsSoFar  | 4608         |
# | ev_tdlam_before | 0.0251       |
# | loss_ent        | 2.7407286    |
# | loss_kl         | 0.011412855  |
# | loss_pol_entpen | -0.027407285 |
# | loss_pol_surr   | -0.004831475 |
# | loss_vf_loss    | 0.057379693  |
# ----------------------------------
# ********** Iteration 18 ************
# Reward ( 4750 )	 -0.14441508574598258
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#      -0.00040 |      -0.02741 |       0.29695 |       0.00085 |       2.74093
#      -0.00759 |      -0.02743 |       0.10757 |       0.00625 |       2.74284
#      -0.01343 |      -0.02745 |       0.01670 |       0.00672 |       2.74542
#      -0.01198 |      -0.02749 |       0.03134 |       0.00355 |       2.74865
# Evaluating losses...
#      -0.01834 |      -0.02751 |       0.05120 |       0.00411 |       2.75134
# ----------------------------------
# | EpThisIter      | 0            |
# | EpisodesSoFar   | 0            |
# | TimeElapsed     | 18           |
# | TimestepsSoFar  | 4864         |
# | ev_tdlam_before | 0.0279       |
# | loss_ent        | 2.751336     |
# | loss_kl         | 0.0041106427 |
# | loss_pol_entpen | -0.02751336  |
# | loss_pol_surr   | -0.01833953  |
# | loss_vf_loss    | 0.051195838  |
# ----------------------------------
# ********** Iteration 19 ************
# Reward ( 5000 )	 -0.1535455593731916
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#      -0.00201 |      -0.02753 |       0.35188 |       0.00062 |       2.75251
#      -0.00914 |      -0.02756 |       0.13433 |       0.00798 |       2.75603
#      -0.01059 |      -0.02760 |       0.02096 |       0.01329 |       2.75969
#      -0.01215 |      -0.02763 |       0.02781 |       0.00737 |       2.76316
# Evaluating losses...
#      -0.01599 |      -0.02765 |       0.05149 |       0.00531 |       2.76528
# ----------------------------------
# | EpThisIter      | 0            |
# | EpisodesSoFar   | 0            |
# | TimeElapsed     | 18.7         |
# | TimestepsSoFar  | 5120         |
# | ev_tdlam_before | -0.0478      |
# | loss_ent        | 2.76528      |
# | loss_kl         | 0.0053060413 |
# | loss_pol_entpen | -0.0276528   |
# | loss_pol_surr   | -0.015988445 |
# | loss_vf_loss    | 0.051493783  |
# ----------------------------------
# ********** Iteration 20 ************
# Reward ( 5250 )	 -0.16481270429953074
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#      -0.00052 |      -0.02767 |       0.37858 |       0.00026 |       2.76661
#      -0.00813 |      -0.02770 |       0.14453 |       0.00466 |       2.76980
#      -0.00803 |      -0.02772 |       0.02380 |       0.01020 |       2.77231
#      -0.01037 |      -0.02774 |       0.03319 |       0.00921 |       2.77374
# Evaluating losses...
#      -0.01171 |      -0.02774 |       0.05780 |       0.00708 |       2.77412
# -----------------------------------
# | EpThisIter      | 0             |
# | EpisodesSoFar   | 0             |
# | TimeElapsed     | 19.4          |
# | TimestepsSoFar  | 5376          |
# | ev_tdlam_before | -0.0184       |
# | loss_ent        | 2.7741213     |
# | loss_kl         | 0.0070820963  |
# | loss_pol_entpen | -0.027741212  |
# | loss_pol_surr   | -0.0117128305 |
# | loss_vf_loss    | 0.05780448    |
# -----------------------------------
# ********** Iteration 21 ************
# Reward ( 5500 )	 -0.1644710957915278
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#       0.00889 |      -0.02775 |       0.23344 |       0.00384 |       2.77470
#       0.00355 |      -0.02777 |       0.08326 |       0.01303 |       2.77702
#      -0.00592 |      -0.02779 |       0.01324 |       0.00671 |       2.77872
#      -0.00811 |      -0.02780 |       0.02405 |       0.00562 |       2.78008
# Evaluating losses...
#      -0.00715 |      -0.02781 |       0.03899 |       0.00824 |       2.78064
# ----------------------------------
# | EpThisIter      | 0            |
# | EpisodesSoFar   | 0            |
# | TimeElapsed     | 20.1         |
# | TimestepsSoFar  | 5632         |
# | ev_tdlam_before | -0.00332     |
# | loss_ent        | 2.7806375    |
# | loss_kl         | 0.008242819  |
# | loss_pol_entpen | -0.027806375 |
# | loss_pol_surr   | -0.007151533 |
# | loss_vf_loss    | 0.038988613  |
# ----------------------------------
# ********** Iteration 22 ************
# Reward ( 5750 )	 -0.16623307985834015
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#       0.00072 |      -0.02781 |       0.16236 |       0.00076 |       2.78105
#      -0.00110 |      -0.02782 |       0.06007 |       0.00658 |       2.78183
#      -0.00355 |      -0.02783 |       0.01050 |       0.01185 |       2.78260
#      -0.00541 |      -0.02783 |       0.01513 |       0.00835 |       2.78346
# Evaluating losses...
#      -0.00505 |      -0.02784 |       0.02590 |       0.00446 |       2.78397
# -----------------------------------
# | EpThisIter      | 0             |
# | EpisodesSoFar   | 0             |
# | TimeElapsed     | 20.8          |
# | TimestepsSoFar  | 5888          |
# | ev_tdlam_before | -0.0313       |
# | loss_ent        | 2.7839682     |
# | loss_kl         | 0.004461673   |
# | loss_pol_entpen | -0.027839681  |
# | loss_pol_surr   | -0.0050512813 |
# | loss_vf_loss    | 0.025903989   |
# -----------------------------------
# ********** Iteration 23 ************
# Reward ( 6000 )	 -0.16638479536809908
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#       0.00066 |      -0.02784 |       0.10263 |       0.00036 |       2.78442
#      -0.00077 |      -0.02788 |       0.03623 |       0.00268 |       2.78768
#      -0.00373 |      -0.02793 |       0.00616 |       0.00647 |       2.79254
#      -0.00578 |      -0.02798 |       0.01114 |       0.00851 |       2.79813
# Evaluating losses...
#      -0.01018 |      -0.02802 |       0.01800 |       0.00777 |       2.80171
# ----------------------------------
# | EpThisIter      | 0            |
# | EpisodesSoFar   | 0            |
# | TimeElapsed     | 21.5         |
# | TimestepsSoFar  | 6144         |
# | ev_tdlam_before | 0.0927       |
# | loss_ent        | 2.8017082    |
# | loss_kl         | 0.007767488  |
# | loss_pol_entpen | -0.028017081 |
# | loss_pol_surr   | -0.010179117 |
# | loss_vf_loss    | 0.018003669  |
# ----------------------------------
# ********** Iteration 24 ************
# Reward ( 6250 )	 -0.16706551213706067
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#      -0.00163 |      -0.02803 |       0.07038 |       0.00094 |       2.80310
#      -0.00942 |      -0.02805 |       0.02548 |       0.01038 |       2.80463
#      -0.00439 |      -0.02803 |       0.00351 |       0.02786 |       2.80322
#      -0.00862 |      -0.02801 |       0.00687 |       0.02195 |       2.80054
# Evaluating losses...
#      -0.01125 |      -0.02799 |       0.01162 |       0.01272 |       2.79864
# ----------------------------------
# | EpThisIter      | 0            |
# | EpisodesSoFar   | 0            |
# | TimeElapsed     | 22.2         |
# | TimestepsSoFar  | 6400         |
# | ev_tdlam_before | -0.00959     |
# | loss_ent        | 2.7986383    |
# | loss_kl         | 0.012723224  |
# | loss_pol_entpen | -0.027986383 |
# | loss_pol_surr   | -0.0112453   |
# | loss_vf_loss    | 0.011619363  |
# ----------------------------------
# ********** Iteration 25 ************
# Reward ( 6500 )	 -0.16703230123327692
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#       0.00182 |      -0.02798 |       0.04107 |       0.00113 |       2.79778
#      -0.00045 |      -0.02796 |       0.01426 |       0.00563 |       2.79576
#      -0.00190 |      -0.02794 |       0.00278 |       0.00598 |       2.79417
#       0.00056 |      -0.02793 |       0.00485 |       0.00645 |       2.79335
# Evaluating losses...
#      -0.00171 |      -0.02793 |       0.00772 |       0.00770 |       2.79301
# -----------------------------------
# | EpThisIter      | 0             |
# | EpisodesSoFar   | 0             |
# | TimeElapsed     | 22.9          |
# | TimestepsSoFar  | 6656          |
# | ev_tdlam_before | -0.00801      |
# | loss_ent        | 2.7930124     |
# | loss_kl         | 0.0076997317  |
# | loss_pol_entpen | -0.027930124  |
# | loss_pol_surr   | -0.0017094975 |
# | loss_vf_loss    | 0.0077210283  |
# -----------------------------------
# ********** Iteration 26 ************
# Reward ( 6750 )	 -0.16581939984800428
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#       0.00155 |      -0.02793 |       0.02383 |       0.00029 |       2.79277
#      -0.00329 |      -0.02793 |       0.00830 |       0.00203 |       2.79307
#      -0.00649 |      -0.02794 |       0.00141 |       0.00781 |       2.79402
#      -0.00552 |      -0.02796 |       0.00267 |       0.01308 |       2.79572
# Evaluating losses...
#      -0.00667 |      -0.02797 |       0.00432 |       0.01309 |       2.79715
# ----------------------------------
# | EpThisIter      | 0            |
# | EpisodesSoFar   | 0            |
# | TimeElapsed     | 23.6         |
# | TimestepsSoFar  | 6912         |
# | ev_tdlam_before | 0.0179       |
# | loss_ent        | 2.7971463    |
# | loss_kl         | 0.013090525  |
# | loss_pol_entpen | -0.027971463 |
# | loss_pol_surr   | -0.006666638 |
# | loss_vf_loss    | 0.0043167146 |
# ----------------------------------
# ********** Iteration 27 ************
# Reward ( 7000 )	 -0.16436808983978654
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#       0.00159 |      -0.02798 |       0.01195 |       0.00050 |       2.79784
#      -0.00263 |      -0.02801 |       0.00396 |       0.00293 |       2.80080
#      -0.00672 |      -0.02804 |       0.00069 |       0.00525 |       2.80397
#      -0.00653 |      -0.02807 |       0.00150 |       0.00590 |       2.80657
# Evaluating losses...
#      -0.00917 |      -0.02808 |       0.00233 |       0.00471 |       2.80846
# ----------------------------------
# | EpThisIter      | 0            |
# | EpisodesSoFar   | 0            |
# | TimeElapsed     | 24.3         |
# | TimestepsSoFar  | 7168         |
# | ev_tdlam_before | -0.0398      |
# | loss_ent        | 2.808462     |
# | loss_kl         | 0.0047099716 |
# | loss_pol_entpen | -0.028084619 |
# | loss_pol_surr   | -0.00917143  |
# | loss_vf_loss    | 0.0023315405 |
# ----------------------------------
# ********** Iteration 28 ************
# Reward ( 7250 )	 -0.16602418251012446
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#       0.00014 |      -0.02809 |       0.01200 |      4.46e-05 |       2.80933
#      -0.00202 |      -0.02811 |       0.00440 |       0.00127 |       2.81118
#      -0.00744 |      -0.02812 |       0.00070 |       0.00491 |       2.81170
#      -0.00456 |      -0.02811 |       0.00126 |       0.01080 |       2.81087
# Evaluating losses...
#      -0.00695 |      -0.02810 |       0.00210 |       0.01370 |       2.80986
# ----------------------------------
# | EpThisIter      | 0            |
# | EpisodesSoFar   | 0            |
# | TimeElapsed     | 25           |
# | TimestepsSoFar  | 7424         |
# | ev_tdlam_before | 0.024        |
# | loss_ent        | 2.8098602    |
# | loss_kl         | 0.01369877   |
# | loss_pol_entpen | -0.028098602 |
# | loss_pol_surr   | -0.006952727 |
# | loss_vf_loss    | 0.0020999503 |
# ----------------------------------
# ********** Iteration 29 ************
# Reward ( 7500 )	 -0.16899633007834877
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#       0.00153 |      -0.02809 |       0.01542 |       0.00061 |       2.80948
#      -0.00418 |      -0.02810 |       0.00560 |       0.00281 |       2.80965
#      -0.00626 |      -0.02811 |       0.00077 |       0.00863 |       2.81073
#      -0.00045 |      -0.02812 |       0.00173 |       0.01705 |       2.81234
# Evaluating losses...
#      -0.00410 |      -0.02814 |       0.00282 |       0.02044 |       2.81371
# -----------------------------------
# | EpThisIter      | 0             |
# | EpisodesSoFar   | 0             |
# | TimeElapsed     | 25.8          |
# | TimestepsSoFar  | 7680          |
# | ev_tdlam_before | -0.0113       |
# | loss_ent        | 2.8137057     |
# | loss_kl         | 0.020441022   |
# | loss_pol_entpen | -0.028137056  |
# | loss_pol_surr   | -0.0040956177 |
# | loss_vf_loss    | 0.002820882   |
# -----------------------------------
# ********** Iteration 30 ************
# Reward ( 7750 )	 -0.1744123556964021
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#     -6.48e-05 |      -0.02814 |       0.03316 |      2.53e-05 |       2.81388
#      -0.00423 |      -0.02813 |       0.01266 |       0.00113 |       2.81344
#      -0.00773 |      -0.02811 |       0.00193 |       0.00807 |       2.81149
#      -0.00338 |      -0.02808 |       0.00356 |       0.01822 |       2.80801
# Evaluating losses...
#      -0.00435 |      -0.02806 |       0.00590 |       0.01819 |       2.80551
# -----------------------------------
# | EpThisIter      | 0             |
# | EpisodesSoFar   | 0             |
# | TimeElapsed     | 26.4          |
# | TimestepsSoFar  | 7936          |
# | ev_tdlam_before | -0.000581     |
# | loss_ent        | 2.8055096     |
# | loss_kl         | 0.018190607   |
# | loss_pol_entpen | -0.028055094  |
# | loss_pol_surr   | -0.0043460745 |
# | loss_vf_loss    | 0.0058984673  |
# -----------------------------------
# ********** Iteration 31 ************
# Reward ( 8000 )	 -0.17609895316323157
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#      -0.00068 |      -0.02804 |       0.02465 |       0.00035 |       2.80432
#      -0.00696 |      -0.02802 |       0.00809 |       0.00595 |       2.80152
#      -0.00529 |      -0.02799 |       0.00140 |       0.01368 |       2.79859
#      -0.00595 |      -0.02795 |       0.00348 |       0.00859 |       2.79550
# Evaluating losses...
#      -0.00862 |      -0.02794 |       0.00517 |       0.00482 |       2.79353
# -----------------------------------
# | EpThisIter      | 0             |
# | EpisodesSoFar   | 0             |
# | TimeElapsed     | 27.1          |
# | TimestepsSoFar  | 8192          |
# | ev_tdlam_before | -0.00101      |
# | loss_ent        | 2.7935266     |
# | loss_kl         | 0.004821238   |
# | loss_pol_entpen | -0.027935266  |
# | loss_pol_surr   | -0.0086201355 |
# | loss_vf_loss    | 0.00517033    |
# -----------------------------------
# ********** Iteration 32 ************
# Reward ( 8250 )	 -0.17743012554477375
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#       0.00049 |      -0.02792 |       0.02749 |       0.00043 |       2.79194
#      -0.00512 |      -0.02788 |       0.01000 |       0.00287 |       2.78765
#      -0.00801 |      -0.02784 |       0.00155 |       0.00671 |       2.78366
#      -0.00742 |      -0.02780 |       0.00355 |       0.00814 |       2.77986
# Evaluating losses...
#      -0.01052 |      -0.02777 |       0.00548 |       0.00724 |       2.77736
# -----------------------------------
# | EpThisIter      | 0             |
# | EpisodesSoFar   | 0             |
# | TimeElapsed     | 27.8          |
# | TimestepsSoFar  | 8448          |
# | ev_tdlam_before | -0.00871      |
# | loss_ent        | 2.7773569     |
# | loss_kl         | 0.007236391   |
# | loss_pol_entpen | -0.027773568  |
# | loss_pol_surr   | -0.0105227195 |
# | loss_vf_loss    | 0.005480457   |
# -----------------------------------
# ********** Iteration 33 ************
# Reward ( 8500 )	 -0.18395530270348986
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#       0.00196 |      -0.02777 |       0.04970 |       0.00019 |       2.77668
#       0.00057 |      -0.02776 |       0.01771 |       0.00012 |       2.77615
#      -0.00070 |      -0.02778 |       0.00277 |       0.00019 |       2.77766
#       0.00035 |      -0.02781 |       0.00614 |       0.00330 |       2.78075
# Evaluating losses...
#      -0.00450 |      -0.02783 |       0.00968 |       0.00796 |       2.78329
# -----------------------------------
# | EpThisIter      | 0             |
# | EpisodesSoFar   | 0             |
# | TimeElapsed     | 28.5          |
# | TimestepsSoFar  | 8704          |
# | ev_tdlam_before | 4.71e-05      |
# | loss_ent        | 2.78329       |
# | loss_kl         | 0.007958468   |
# | loss_pol_entpen | -0.0278329    |
# | loss_pol_surr   | -0.0044973735 |
# | loss_vf_loss    | 0.009677922   |
# -----------------------------------
# ********** Iteration 34 ************
# Reward ( 8750 )	 -0.18639081156599974
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#      -0.00064 |      -0.02785 |       0.03379 |       0.00191 |       2.78491
#      -0.01566 |      -0.02788 |       0.01107 |       0.01484 |       2.78818
#      -0.01324 |      -0.02790 |       0.00176 |       0.02563 |       2.78960
#      -0.01469 |      -0.02790 |       0.00495 |       0.02111 |       2.78994
# Evaluating losses...
#      -0.01726 |      -0.02790 |       0.00724 |       0.01445 |       2.78975
# ----------------------------------
# | EpThisIter      | 0            |
# | EpisodesSoFar   | 0            |
# | TimeElapsed     | 29.2         |
# | TimestepsSoFar  | 8960         |
# | ev_tdlam_before | 0.0379       |
# | loss_ent        | 2.7897482    |
# | loss_kl         | 0.014451708  |
# | loss_pol_entpen | -0.02789748  |
# | loss_pol_surr   | -0.017260455 |
# | loss_vf_loss    | 0.007237508  |
# ----------------------------------
# ********** Iteration 35 ************
# Reward ( 9000 )	 -0.18624893710940546
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#       0.00046 |      -0.02790 |       0.01720 |       0.00015 |       2.78959
#      -0.00650 |      -0.02788 |       0.00579 |       0.00329 |       2.78824
#      -0.01003 |      -0.02786 |       0.00103 |       0.01166 |       2.78618
#      -0.00984 |      -0.02784 |       0.00276 |       0.01446 |       2.78420
# Evaluating losses...
#      -0.01167 |      -0.02783 |       0.00392 |       0.01176 |       2.78306
# ----------------------------------
# | EpThisIter      | 0            |
# | EpisodesSoFar   | 0            |
# | TimeElapsed     | 29.9         |
# | TimestepsSoFar  | 9216         |
# | ev_tdlam_before | 0.0673       |
# | loss_ent        | 2.7830572    |
# | loss_kl         | 0.011764504  |
# | loss_pol_entpen | -0.027830571 |
# | loss_pol_surr   | -0.011667148 |
# | loss_vf_loss    | 0.003918081  |
# ----------------------------------
# ********** Iteration 36 ************
# Reward ( 9250 )	 -0.18455079853695164
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#       0.00153 |      -0.02782 |       0.00532 |       0.00030 |       2.78237
#      -0.00312 |      -0.02780 |       0.00184 |       0.00150 |       2.77978
#      -0.00661 |      -0.02777 |       0.00057 |       0.00710 |       2.77674
#      -0.00664 |      -0.02773 |       0.00116 |       0.01014 |       2.77280
# Evaluating losses...
#      -0.00847 |      -0.02770 |       0.00147 |       0.00782 |       2.77031
# ----------------------------------
# | EpThisIter      | 0            |
# | EpisodesSoFar   | 0            |
# | TimeElapsed     | 30.6         |
# | TimestepsSoFar  | 9472         |
# | ev_tdlam_before | -0.102       |
# | loss_ent        | 2.7703075    |
# | loss_kl         | 0.007817173  |
# | loss_pol_entpen | -0.027703075 |
# | loss_pol_surr   | -0.008465251 |
# | loss_vf_loss    | 0.0014745906 |
# ----------------------------------
# ********** Iteration 37 ************
# Reward ( 9500 )	 -0.18139115103121972
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#       0.00036 |      -0.02769 |       0.00059 |       0.00034 |       2.76899
#      -0.00618 |      -0.02765 |       0.00025 |       0.00554 |       2.76538
#      -0.00693 |      -0.02762 |       0.00016 |       0.01107 |       2.76216
#      -0.00828 |      -0.02760 |       0.00023 |       0.00552 |       2.75952
# Evaluating losses...
#      -0.01003 |      -0.02758 |       0.00026 |       0.00449 |       2.75791
# ----------------------------------
# | EpThisIter      | 0            |
# | EpisodesSoFar   | 0            |
# | TimeElapsed     | 31.3         |
# | TimestepsSoFar  | 9728         |
# | ev_tdlam_before | 0.0445       |
# | loss_ent        | 2.7579134    |
# | loss_kl         | 0.0044948356 |
# | loss_pol_entpen | -0.027579132 |
# | loss_pol_surr   | -0.010034148 |
# | loss_vf_loss    | 0.0002553019 |
# ----------------------------------
# ********** Iteration 38 ************
# Reward ( 9750 )	 -0.17797570749278901
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#       0.00345 |      -0.02757 |       0.01628 |       0.00140 |       2.75697
#      -0.00286 |      -0.02755 |       0.00837 |       0.00424 |       2.75512
#      -0.00621 |      -0.02754 |       0.00392 |       0.00879 |       2.75425
#      -0.00734 |      -0.02754 |       0.00491 |       0.00852 |       2.75413
# Evaluating losses...
#      -0.00920 |      -0.02754 |       0.00581 |       0.00610 |       2.75434
# ----------------------------------
# | EpThisIter      | 0            |
# | EpisodesSoFar   | 0            |
# | TimeElapsed     | 32           |
# | TimestepsSoFar  | 9984         |
# | ev_tdlam_before | -0.0364      |
# | loss_ent        | 2.7543414    |
# | loss_kl         | 0.006099542  |
# | loss_pol_entpen | -0.027543413 |
# | loss_pol_surr   | -0.009204338 |
# | loss_vf_loss    | 0.0058119306 |
# ----------------------------------
# ********** Iteration 39 ************
# Reward ( 10000 )	 -0.15674082449338228
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#       0.00090 |      -0.02754 |       0.20102 |       0.00096 |       2.75434
#      -0.00429 |      -0.02755 |       0.07433 |       0.00928 |       2.75506
#      -0.00677 |      -0.02756 |       0.01172 |       0.01239 |       2.75626
#      -0.00669 |      -0.02757 |       0.02857 |       0.00856 |       2.75735
# Evaluating losses...
#      -0.00805 |      -0.02758 |       0.04293 |       0.00670 |       2.75793
# ----------------------------------
# | EpThisIter      | 0            |
# | EpisodesSoFar   | 0            |
# | TimeElapsed     | 32.6         |
# | TimestepsSoFar  | 10240        |
# | ev_tdlam_before | 0.00509      |
# | loss_ent        | 2.757926     |
# | loss_kl         | 0.00670329   |
# | loss_pol_entpen | -0.02757926  |
# | loss_pol_surr   | -0.008053309 |
# | loss_vf_loss    | 0.042926922  |
# ----------------------------------
# ********** Iteration 40 ************
# Reward ( 10250 )	 -0.1378585155513794
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#       0.00050 |      -0.02758 |       0.27592 |       0.00049 |       2.75810
#      -0.00317 |      -0.02759 |       0.09318 |       0.00448 |       2.75876
#      -0.00577 |      -0.02760 |       0.01323 |       0.00545 |       2.76017
#      -0.00813 |      -0.02762 |       0.04066 |       0.00458 |       2.76216
# Evaluating losses...
#      -0.00858 |      -0.02763 |       0.05845 |       0.00658 |       2.76324
# ----------------------------------
# | EpThisIter      | 0            |
# | EpisodesSoFar   | 0            |
# | TimeElapsed     | 33.3         |
# | TimestepsSoFar  | 10496        |
# | ev_tdlam_before | -0.0257      |
# | loss_ent        | 2.7632408    |
# | loss_kl         | 0.0065845586 |
# | loss_pol_entpen | -0.027632408 |
# | loss_pol_surr   | -0.00857665  |
# | loss_vf_loss    | 0.058451835  |
# ----------------------------------
# ********** Iteration 41 ************
# Reward ( 10500 )	 -0.13817255978885787
# Reward ( 10750 )	 -0.13892220229932423
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#       0.00269 |      -0.02764 |       0.12288 |       0.00021 |       2.76385
#      -0.00047 |      -0.02765 |       0.03638 |       0.00038 |       2.76463
#      -0.00686 |      -0.02765 |       0.00909 |       0.00510 |       2.76489
#      -0.00507 |      -0.02765 |       0.02422 |       0.01099 |       2.76508
# Evaluating losses...
#      -0.00790 |      -0.02765 |       0.02341 |       0.01221 |       2.76487
# ----------------------------------
# | EpThisIter      | 0            |
# | EpisodesSoFar   | 0            |
# | TimeElapsed     | 34           |
# | TimestepsSoFar  | 10752        |
# | ev_tdlam_before | 0.0111       |
# | loss_ent        | 2.7648745    |
# | loss_kl         | 0.0122074    |
# | loss_pol_entpen | -0.027648743 |
# | loss_pol_surr   | -0.00790187  |
# | loss_vf_loss    | 0.023408938  |
# ----------------------------------
# ********** Iteration 42 ************
# Reward ( 11000 )	 -0.14150445014862534
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#      -0.00156 |      -0.02765 |       0.07811 |       0.00067 |       2.76515
#      -0.00575 |      -0.02766 |       0.02717 |       0.00863 |       2.76614
#      -0.00559 |      -0.02768 |       0.00624 |       0.01723 |       2.76767
#      -0.00720 |      -0.02770 |       0.01604 |       0.01232 |       2.76970
# Evaluating losses...
#      -0.01045 |      -0.02771 |       0.01516 |       0.00645 |       2.77122
# ----------------------------------
# | EpThisIter      | 0            |
# | EpisodesSoFar   | 0            |
# | TimeElapsed     | 34.7         |
# | TimestepsSoFar  | 11008        |
# | ev_tdlam_before | 0.335        |
# | loss_ent        | 2.7712247    |
# | loss_kl         | 0.0064470284 |
# | loss_pol_entpen | -0.027712246 |
# | loss_pol_surr   | -0.010454532 |
# | loss_vf_loss    | 0.015155148  |
# ----------------------------------
# ********** Iteration 43 ************
# Reward ( 11250 )	 -0.14019704617040518
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#       0.00575 |      -0.02772 |       0.04416 |       0.00272 |       2.77187
#      -0.01002 |      -0.02772 |       0.00914 |       0.00984 |       2.77208
#      -0.01076 |      -0.02772 |       0.00941 |       0.02668 |       2.77178
#      -0.01227 |      -0.02772 |       0.01093 |       0.02513 |       2.77216
# Evaluating losses...
#      -0.01769 |      -0.02773 |       0.00412 |       0.01693 |       2.77269
# ----------------------------------
# | EpThisIter      | 0            |
# | EpisodesSoFar   | 0            |
# | TimeElapsed     | 35.4         |
# | TimestepsSoFar  | 11264        |
# | ev_tdlam_before | 0.0264       |
# | loss_ent        | 2.7726908    |
# | loss_kl         | 0.016933866  |
# | loss_pol_entpen | -0.027726907 |
# | loss_pol_surr   | -0.017691359 |
# | loss_vf_loss    | 0.0041248854 |
# ----------------------------------
# ********** Iteration 44 ************
# Reward ( 11500 )	 -0.1418691148780639
# Optimizing...
# ...
#      -0.00621 |      -0.02877 |       0.01034 |       0.00244 |       2.87727
#      -0.01085 |      -0.02878 |       0.01038 |       0.01068 |       2.87759
#      -0.00934 |      -0.02878 |       0.01527 |       0.01477 |       2.87758
# Evaluating losses...
#      -0.01027 |      -0.02877 |       0.00748 |       0.01240 |       2.87740
# ----------------------------------
# | EpLenMean       | 2e+04        |
# | EpRewMean       | -2.17e+03    |
# | EpThisIter      | 0            |
# | EpisodesSoFar   | 2            |
# | TimeElapsed     | 133          |
# | TimestepsSoFar  | 43776        |
# | ev_tdlam_before | -0.000473    |
# | loss_ent        | 2.8773954    |
# | loss_kl         | 0.012396958  |
# | loss_pol_entpen | -0.028773954 |
# | loss_pol_surr   | -0.010268621 |
# | loss_vf_loss    | 0.007480493  |
# ----------------------------------
# ********** Iteration 171 ************
# Reward ( 44000 )	 -0.15446747362916596
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#       0.00074 |      -0.02877 |       0.04028 |      5.14e-05 |       2.87712
#     -7.82e-05 |      -0.02876 |       0.01298 |       0.00042 |       2.87595
#      -0.00544 |      -0.02874 |       0.00352 |       0.00416 |       2.87442
#      -0.00782 |      -0.02873 |       0.01100 |       0.01221 |       2.87257
# Evaluating losses...
#      -0.00760 |      -0.02871 |       0.00970 |       0.01539 |       2.87130
# -----------------------------------
# | EpLenMean       | 2e+04         |
# | EpRewMean       | -2.17e+03     |
# | EpThisIter      | 0             |
# | EpisodesSoFar   | 2             |
# | TimeElapsed     | 134           |
# | TimestepsSoFar  | 44032         |
# | ev_tdlam_before | -0.000223     |
# | loss_ent        | 2.871304      |
# | loss_kl         | 0.015394665   |
# | loss_pol_entpen | -0.02871304   |
# | loss_pol_surr   | -0.0075988118 |
# | loss_vf_loss    | 0.009696776   |
# -----------------------------------
# ********** Iteration 172 ************
# Reward ( 44250 )	 -0.15556912788058042
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#      -0.00013 |      -0.02871 |       0.02341 |      6.43e-05 |       2.87061
#      -0.00147 |      -0.02869 |       0.00708 |       0.00093 |       2.86914
#      -0.00060 |      -0.02868 |       0.00150 |       0.00502 |       2.86797
#      -0.00054 |      -0.02867 |       0.00531 |       0.01053 |       2.86674
# Evaluating losses...
#      -0.00110 |      -0.02866 |       0.00571 |       0.01003 |       2.86593
# -----------------------------------
# | EpLenMean       | 2e+04         |
# | EpRewMean       | -2.17e+03     |
# | EpThisIter      | 0             |
# | EpisodesSoFar   | 2             |
# | TimeElapsed     | 135           |
# | TimestepsSoFar  | 44288         |
# | ev_tdlam_before | -0.000245     |
# | loss_ent        | 2.8659303     |
# | loss_kl         | 0.010029621   |
# | loss_pol_entpen | -0.028659303  |
# | loss_pol_surr   | -0.0010967897 |
# | loss_vf_loss    | 0.0057095494  |
# -----------------------------------
# ********** Iteration 173 ************
# Reward ( 44500 )	 -0.1550849544120298
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#       0.00079 |      -0.02865 |       0.01532 |      9.94e-06 |       2.86538
#       0.00070 |      -0.02864 |       0.00495 |      7.44e-05 |       2.86445
#      -0.00091 |      -0.02864 |       0.00083 |       0.00048 |       2.86400
#      -0.00205 |      -0.02864 |       0.00294 |       0.00186 |       2.86370
# Evaluating losses...
#      -0.00269 |      -0.02864 |       0.00368 |       0.00372 |       2.86364
# -----------------------------------
# | EpLenMean       | 2e+04         |
# | EpRewMean       | -2.17e+03     |
# | EpThisIter      | 0             |
# | EpisodesSoFar   | 2             |
# | TimeElapsed     | 135           |
# | TimestepsSoFar  | 44544         |
# | ev_tdlam_before | -0.00445      |
# | loss_ent        | 2.8636422     |
# | loss_kl         | 0.0037171347  |
# | loss_pol_entpen | -0.028636422  |
# | loss_pol_surr   | -0.0026934631 |
# | loss_vf_loss    | 0.0036757719  |
# -----------------------------------
# ********** Iteration 174 ************
# Reward ( 44750 )	 -0.15351943189004766
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#       0.00158 |      -0.02864 |       0.00432 |      7.88e-05 |       2.86367
#     -8.04e-05 |      -0.02864 |       0.00136 |       0.00022 |       2.86385
#      -0.00444 |      -0.02864 |       0.00038 |       0.00417 |       2.86405
#      -0.00556 |      -0.02864 |       0.00103 |       0.01291 |       2.86388
# Evaluating losses...
#      -0.00568 |      -0.02864 |       0.00118 |       0.01390 |       2.86360
# -----------------------------------
# | EpLenMean       | 2e+04         |
# | EpRewMean       | -2.17e+03     |
# | EpThisIter      | 0             |
# | EpisodesSoFar   | 2             |
# | TimeElapsed     | 136           |
# | TimestepsSoFar  | 44800         |
# | ev_tdlam_before | 0.00965       |
# | loss_ent        | 2.863602      |
# | loss_kl         | 0.013895365   |
# | loss_pol_entpen | -0.028636018  |
# | loss_pol_surr   | -0.0056808963 |
# | loss_vf_loss    | 0.0011844137  |
# -----------------------------------
# ********** Iteration 175 ************
# Reward ( 45000 )	 -0.15486215476019852
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#       0.00040 |      -0.02864 |       0.00585 |       0.00030 |       2.86379
#      -0.00151 |      -0.02866 |       0.00182 |       0.00303 |       2.86573
#      -0.00362 |      -0.02869 |       0.00038 |       0.00569 |       2.86886
#      -0.00428 |      -0.02872 |       0.00122 |       0.00471 |       2.87231
# Evaluating losses...
#      -0.00519 |      -0.02874 |       0.00148 |       0.00301 |       2.87445
# ----------------------------------
# | EpLenMean       | 2e+04        |
# | EpRewMean       | -2.17e+03    |
# | EpThisIter      | 0            |
# | EpisodesSoFar   | 2            |
# | TimeElapsed     | 137          |
# | TimestepsSoFar  | 45056        |
# | ev_tdlam_before | -0.000374    |
# | loss_ent        | 2.874453     |
# | loss_kl         | 0.0030143785 |
# | loss_pol_entpen | -0.02874453  |
# | loss_pol_surr   | -0.005187638 |
# | loss_vf_loss    | 0.0014757797 |
# ----------------------------------
# ********** Iteration 176 ************
# Reward ( 45250 )	 -0.15483440707639373
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#     -3.88e-05 |      -0.02876 |       0.00339 |      6.11e-05 |       2.87566
#      -0.00440 |      -0.02878 |       0.00104 |       0.00145 |       2.87846
#      -0.00726 |      -0.02881 |       0.00022 |       0.00780 |       2.88051
#      -0.00384 |      -0.02881 |       0.00072 |       0.01387 |       2.88103
# Evaluating losses...
#      -0.00404 |      -0.02881 |       0.00085 |       0.01389 |       2.88105
# -----------------------------------
# | EpLenMean       | 2e+04         |
# | EpRewMean       | -2.17e+03     |
# | EpThisIter      | 0             |
# | EpisodesSoFar   | 2             |
# | TimeElapsed     | 137           |
# | TimestepsSoFar  | 45312         |
# | ev_tdlam_before | -0.000281     |
# | loss_ent        | 2.8810463     |
# | loss_kl         | 0.013890415   |
# | loss_pol_entpen | -0.028810462  |
# | loss_pol_surr   | -0.0040376578 |
# | loss_vf_loss    | 0.00085370516 |
# -----------------------------------
# ********** Iteration 177 ************
# Reward ( 45500 )	 -0.15446238758125239
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#       0.00047 |      -0.02881 |       0.00188 |       0.00032 |       2.88105
#      -0.00135 |      -0.02881 |       0.00063 |       0.00294 |       2.88077
#      -0.00336 |      -0.02880 |       0.00021 |       0.00709 |       2.88019
#      -0.00466 |      -0.02879 |       0.00046 |       0.00630 |       2.87945
# Evaluating losses...
#      -0.00518 |      -0.02879 |       0.00054 |       0.00459 |       2.87891
# -----------------------------------
# | EpLenMean       | 2e+04         |
# | EpRewMean       | -2.17e+03     |
# | EpThisIter      | 0             |
# | EpisodesSoFar   | 2             |
# | TimeElapsed     | 138           |
# | TimestepsSoFar  | 45568         |
# | ev_tdlam_before | -0.000278     |
# | loss_ent        | 2.878909      |
# | loss_kl         | 0.00459104    |
# | loss_pol_entpen | -0.02878909   |
# | loss_pol_surr   | -0.0051776282 |
# | loss_vf_loss    | 0.0005353312  |
# -----------------------------------
# ********** Iteration 178 ************
# Reward ( 45750 )	 -0.1504138752520914
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#      -0.00011 |      -0.02879 |       0.00118 |      9.26e-05 |       2.87855
#       0.00092 |      -0.02878 |       0.00076 |       0.00148 |       2.87844
#      -0.00127 |      -0.02879 |       0.00061 |       0.00421 |       2.87898
#      -0.00228 |      -0.02880 |       0.00070 |       0.00643 |       2.87963
# Evaluating losses...
#      -0.00293 |      -0.02880 |       0.00072 |       0.00603 |       2.88024
# -----------------------------------
# | EpLenMean       | 2e+04         |
# | EpRewMean       | -2.17e+03     |
# | EpThisIter      | 0             |
# | EpisodesSoFar   | 2             |
# | TimeElapsed     | 139           |
# | TimestepsSoFar  | 45824         |
# | ev_tdlam_before | 6.05e-05      |
# | loss_ent        | 2.8802392     |
# | loss_kl         | 0.006026472   |
# | loss_pol_entpen | -0.028802391  |
# | loss_pol_surr   | -0.0029319236 |
# | loss_vf_loss    | 0.0007233714  |
# -----------------------------------
# ********** Iteration 179 ************
# Reward ( 46000 )	 -0.15433079955553095
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#       0.00040 |      -0.02880 |       0.00046 |       0.00023 |       2.88035
#      -0.00079 |      -0.02880 |       0.00015 |       0.00190 |       2.87996
#      -0.00188 |      -0.02878 |      6.75e-05 |       0.00388 |       2.87774
#      -0.00143 |      -0.02874 |       0.00013 |       0.00425 |       2.87404
# Evaluating losses...
#      -0.00304 |      -0.02872 |       0.00014 |       0.00421 |       2.87157
# -----------------------------------
# | EpLenMean       | 2e+04         |
# | EpRewMean       | -2.17e+03     |
# | EpThisIter      | 0             |
# | EpisodesSoFar   | 2             |
# | TimeElapsed     | 139           |
# | TimestepsSoFar  | 46080         |
# | ev_tdlam_before | -0.000172     |
# | loss_ent        | 2.871573      |
# | loss_kl         | 0.0042077834  |
# | loss_pol_entpen | -0.02871573   |
# | loss_pol_surr   | -0.0030368045 |
# | loss_vf_loss    | 0.00014306247 |
# -----------------------------------
# ********** Iteration 180 ************
# Reward ( 46250 )	 -0.15185917316459535
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#       0.00029 |      -0.02870 |       0.00011 |      1.98e-05 |       2.87049
#       0.00017 |      -0.02869 |      7.86e-05 |       0.00025 |       2.86936
#      -0.00039 |      -0.02870 |      6.51e-05 |       0.00066 |       2.87009
#      -0.00092 |      -0.02872 |      7.10e-05 |       0.00160 |       2.87193
# Evaluating losses...
#      -0.00249 |      -0.02874 |      7.31e-05 |       0.00273 |       2.87358
# ----------------------------------
# | EpLenMean       | 2e+04        |
# | EpRewMean       | -2.17e+03    |
# | EpThisIter      | 0            |
# | EpisodesSoFar   | 2            |
# | TimeElapsed     | 140          |
# | TimestepsSoFar  | 46336        |
# | ev_tdlam_before | -0.508       |
# | loss_ent        | 2.8735788    |
# | loss_kl         | 0.0027309698 |
# | loss_pol_entpen | -0.028735787 |
# | loss_pol_surr   | -0.002486365 |
# | loss_vf_loss    | 7.305442e-05 |
# ----------------------------------
# ********** Iteration 181 ************
# Reward ( 46500 )	 -0.15700381774989947
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#       0.00079 |      -0.02874 |       0.00326 |       0.00021 |       2.87402
#      -0.00289 |      -0.02875 |       0.00123 |       0.00167 |       2.87473
#      -0.00585 |      -0.02875 |       0.00052 |       0.00594 |       2.87462
#      -0.00563 |      -0.02873 |       0.00098 |       0.00772 |       2.87349
# Evaluating losses...
#      -0.00780 |      -0.02873 |       0.00106 |       0.00607 |       2.87253
# ----------------------------------
# | EpLenMean       | 2e+04        |
# | EpRewMean       | -2.17e+03    |
# | EpThisIter      | 0            |
# | EpisodesSoFar   | 2            |
# | TimeElapsed     | 141          |
# | TimestepsSoFar  | 46592        |
# | ev_tdlam_before | 0.0053       |
# | loss_ent        | 2.8725302    |
# | loss_kl         | 0.0060743196 |
# | loss_pol_entpen | -0.028725302 |
# | loss_pol_surr   | -0.007800985 |
# | loss_vf_loss    | 0.00106348   |
# ----------------------------------
# ********** Iteration 182 ************
# Reward ( 46750 )	 -0.15646158635509538
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#       0.00030 |      -0.02872 |       0.00272 |      6.96e-05 |       2.87240
#       0.00045 |      -0.02873 |       0.00081 |       0.00042 |       2.87345
#      -0.00416 |      -0.02876 |       0.00017 |       0.00282 |       2.87557
#      -0.00191 |      -0.02879 |       0.00060 |       0.01161 |       2.87852
# Evaluating losses...
#      -0.00386 |      -0.02881 |       0.00069 |       0.01685 |       2.88052
# ----------------------------------
# | EpLenMean       | 2e+04        |
# | EpRewMean       | -2.17e+03    |
# | EpThisIter      | 0            |
# | EpisodesSoFar   | 2            |
# | TimeElapsed     | 141          |
# | TimestepsSoFar  | 46848        |
# | ev_tdlam_before | 0.0334       |
# | loss_ent        | 2.8805165    |
# | loss_kl         | 0.016851842  |
# | loss_pol_entpen | -0.028805165 |
# | loss_pol_surr   | -0.003860077 |
# | loss_vf_loss    | 0.0006852108 |
# ----------------------------------
# ********** Iteration 183 ************
# Reward ( 47000 )	 -0.1566767066310845
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#      -0.00012 |      -0.02882 |       0.00357 |       0.00043 |       2.88176
#      -0.00465 |      -0.02884 |       0.00125 |       0.00365 |       2.88374
#      -0.00315 |      -0.02885 |       0.00052 |       0.00857 |       2.88469
#      -0.00378 |      -0.02885 |       0.00103 |       0.00398 |       2.88516
# Evaluating losses...
#      -0.00568 |      -0.02886 |       0.00113 |       0.00173 |       2.88557
# ----------------------------------
# | EpLenMean       | 2e+04        |
# | EpRewMean       | -2.17e+03    |
# | EpThisIter      | 0            |
# | EpisodesSoFar   | 2            |
# | TimeElapsed     | 142          |
# | TimestepsSoFar  | 47104        |
# | ev_tdlam_before | 0.00102      |
# | loss_ent        | 2.8855696    |
# | loss_kl         | 0.001733322  |
# | loss_pol_entpen | -0.028855694 |
# | loss_pol_surr   | -0.005676184 |
# | loss_vf_loss    | 0.001125487  |
# ----------------------------------
# ********** Iteration 184 ************
# Reward ( 47250 )	 -0.16144502709220657
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#     -5.40e-05 |      -0.02886 |       0.01042 |       0.00112 |       2.88593
#      -0.00504 |      -0.02888 |       0.00307 |       0.00822 |       2.88791
#      -0.00534 |      -0.02890 |       0.00065 |       0.00751 |       2.88993
#      -0.00740 |      -0.02891 |       0.00233 |       0.00267 |       2.89149
# Evaluating losses...
#      -0.00819 |      -0.02893 |       0.00262 |       0.00201 |       2.89250
# ----------------------------------
# | EpLenMean       | 2e+04        |
# | EpRewMean       | -2.17e+03    |
# | EpThisIter      | 0            |
# | EpisodesSoFar   | 2            |
# | TimeElapsed     | 143          |
# | TimestepsSoFar  | 47360        |
# | ev_tdlam_before | -7.63e-06    |
# | loss_ent        | 2.8925047    |
# | loss_kl         | 0.0020134998 |
# | loss_pol_entpen | -0.028925046 |
# | loss_pol_surr   | -0.008186244 |
# | loss_vf_loss    | 0.0026154788 |
# ----------------------------------
# ********** Iteration 185 ************

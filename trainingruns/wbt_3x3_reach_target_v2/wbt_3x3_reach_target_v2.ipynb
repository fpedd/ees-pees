# %%
import sys
sys.path.insert(0,'../../backend')

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import gym
import stable_baselines
from stable_baselines import A2C, ACER, ACKTR, DQN, DDPG, SAC, PPO1, PPO2, TD3, TRPO
from stable_baselines.common.env_checker import check_env
from stable_baselines.common.policies import MlpPolicy
from stable_baselines.gail import ExpertDataset, generate_expert_traj

import webotsgym as wg
# Out:
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.

# %%
from webotsgym.utils import exponential_decay
from webotsgym.env.reward import step_pen_exp

class MyEval(wg.WbtReward):
    def __init__(self, env, config):
        super(MyEval, self).__init__(env, config)

    def calc_reward(self):
        target_distance = self.env.get_target_distance(False)
        if target_distance < 0.08:
            return 2000 + 10000 * (1 - abs(self.env.state.speed))
        else:
            reward = 0
            reward += -5
        
            if self.env.state.touching:
                reward += -100
        return reward

    def check_done(self):
        if self.env.total_reward < -5000:
            print("reward boundary")
            return True
        if self.env.get_target_distance(False) < 0.08:
            print("target reached")
            return True
        return False

# %%
config = wg.WbtConfig()
config.world_size = 3
config.num_obstacles = 0
config.sim_mode = wg.config.SimSpeedMode.RUN
config.sim_step_every_x = 5
config.relative_action = True
config.direction_type = wg.config.DirectionType.STEERING
# Out:
# SimSpeedMode.RUN

# %%
env = wg.WbtGym(train=True, 
                evaluate_class=MyEval,
#                 action_class = wg.WbtActDiscrete(config, dspeed=0.05, ddir=0.05),
                config=config)
# Out:
# /home/jonas/anaconda3/lib/python3.6/site-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# ../../backend/webotsgym/env/webotenv.py:112: UserWarning: Relative property of action class is overwritten by config.relative_action.
#   warnings.warn("Relative property of action class is overwritten by config.relative_action.")
# Accepting on Port:  10201

# %%
model = PPO1("MlpPolicy", env, tensorboard_log="./{}".format(model_name))
# Out:
# WARNING:tensorflow:From /home/jonas/anaconda3/lib/python3.6/site-packages/stable_baselines/common/tf_util.py:191: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /home/jonas/anaconda3/lib/python3.6/site-packages/stable_baselines/common/tf_util.py:200: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# WARNING:tensorflow:From /home/jonas/anaconda3/lib/python3.6/site-packages/stable_baselines/common/policies.py:116: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# WARNING:tensorflow:From /home/jonas/anaconda3/lib/python3.6/site-packages/stable_baselines/common/input.py:25: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /home/jonas/anaconda3/lib/python3.6/site-packages/stable_baselines/common/policies.py:561: flatten (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.flatten instead.
# WARNING:tensorflow:From /home/jonas/anaconda3/lib/python3.6/site-packages/tensorflow_core/python/layers/core.py:332: Layer.apply (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.__call__` method instead.
# WARNING:tensorflow:From /home/jonas/anaconda3/lib/python3.6/site-packages/stable_baselines/common/tf_layers.py:123: The name tf.get_variable is deprecated. Please use tf.compat.v1.get_variable instead.
#
# WARNING:tensorflow:From /home/jonas/anaconda3/lib/python3.6/site-packages/stable_baselines/common/distributions.py:418: The name tf.random_normal is deprecated. Please use tf.random.normal instead.
#
# WARNING:tensorflow:From /home/jonas/anaconda3/lib/python3.6/site-packages/stable_baselines/ppo1/pposgd_simple.py:153: The name tf.summary.scalar is deprecated. Please use tf.compat.v1.summary.scalar instead.
#
# WARNING:tensorflow:From /home/jonas/anaconda3/lib/python3.6/site-packages/stable_baselines/common/tf_util.py:449: The name tf.get_collection is deprecated. Please use tf.compat.v1.get_collection instead.
#
# WARNING:tensorflow:From /home/jonas/anaconda3/lib/python3.6/site-packages/stable_baselines/common/tf_util.py:449: The name tf.GraphKeys is deprecated. Please use tf.compat.v1.GraphKeys instead.
#
# WARNING:tensorflow:From /home/jonas/anaconda3/lib/python3.6/site-packages/stable_baselines/ppo1/pposgd_simple.py:163: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# WARNING:tensorflow:From /home/jonas/anaconda3/lib/python3.6/site-packages/stable_baselines/common/tf_util.py:241: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From /home/jonas/anaconda3/lib/python3.6/site-packages/stable_baselines/common/tf_util.py:242: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
#
# WARNING:tensorflow:From /home/jonas/anaconda3/lib/python3.6/site-packages/stable_baselines/ppo1/pposgd_simple.py:191: The name tf.summary.merge_all is deprecated. Please use tf.compat.v1.summary.merge_all instead.
#
# WARNING:tensorflow:From /home/jonas/anaconda3/lib/python3.6/site-packages/tensorflow_core/python/ops/math_grad.py:1424: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where

# %%
model.learn(total_timesteps=800000)
model.save("./{}".format(model_name))
# Out:
# WARNING:tensorflow:From /home/jonas/anaconda3/lib/python3.6/site-packages/stable_baselines/common/base_class.py:1143: The name tf.summary.FileWriter is deprecated. Please use tf.compat.v1.summary.FileWriter instead.
#
# target reached
# reward boundary
# reward boundary
# reward boundary
# WARNING:tensorflow:From /home/jonas/anaconda3/lib/python3.6/site-packages/stable_baselines/common/tf_util.py:502: The name tf.Summary is deprecated. Please use tf.compat.v1.Summary instead.
#
# reward boundary
# reward boundary
# reward boundary
# target reached
# target reached
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# target reached
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# target reached
# reward boundary
# target reached
# reward boundary
# reward boundary
# target reached
# reward boundary
# target reached
# reward boundary
# target reached
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# target reached
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# target reached
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# target reached
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# target reached
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# target reached
# reward boundary
# reward boundary
# target reached
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# target reached
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# target reached
# reward boundary
# reward boundary
# reward boundary
# target reached
# target reached
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# target reached
# reward boundary
# reward boundary
# target reached
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# target reached
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# target reached
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# target reached
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# target reached
# reward boundary
# reward boundary
# target reached
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# target reached
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# target reached
# target reached
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# target reached
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# target reached
# target reached
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# target reached
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# target reached
# target reached
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# target reached
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# target reached
# reward boundary
# reward boundary
# reward boundary
# target reached
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# target reached
# target reached
# target reached
# reward boundary
# reward boundary
# target reached
# reward boundary
# target reached
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# target reached
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# target reached
# reward boundary
# reward boundary
# reward boundary
# target reached
# target reached
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# target reached
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# target reached
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# target reached
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# target reached
# reward boundary
# reward boundary
# target reached
# reward boundary
# target reached
# reward boundary
# reward boundary
# target reached
# reward boundary
# reward boundary
# reward boundary
# target reached
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# target reached
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# target reached
# reward boundary
# reward boundary
# target reached
# reward boundary
# reward boundary
# reward boundary
# target reached
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# target reached
# reward boundary
# target reached
# reward boundary
# target reached
# reward boundary
# target reached
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# target reached
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# target reached
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# target reached
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# target reached
# target reached
# target reached
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# target reached
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# target reached
# target reached
# target reached
# reward boundary
# target reached
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# target reached
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# target reached
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# target reached
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# target reached
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# target reached
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# target reached
# reward boundary
# reward boundary
# target reached
# reward boundary
# reward boundary
# reward boundary
# target reached
# reward boundary
# target reached
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# target reached
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# target reached
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# target reached
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# target reached
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# target reached
# target reached
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# target reached
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# target reached
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# target reached
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# target reached
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# target reached
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# target reached
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# target reached
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# target reached
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# target reached
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# target reached
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# reward boundary
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-3c436df16b35> in <module>
# ----> 1 model.learn(total_timesteps=800000)
#       2 model.save("./{}".format(model_name))
#
# ~/anaconda3/lib/python3.6/site-packages/stable_baselines/ppo1/pposgd_simple.py in learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps)
#     240                     logger.log("********** Iteration %i ************" % iters_so_far)
#     241
# --> 242                     seg = seg_gen.__next__()
#     243
#     244                     # Stop training early (triggered by the callback)
#
# ~/anaconda3/lib/python3.6/site-packages/stable_baselines/common/runners.py in traj_segment_generator(policy, env, horizon, reward_giver, gail, callback)
#     157             observation, true_reward, done, info = env.step(clipped_action[0])
#     158         else:
# --> 159             observation, reward, done, info = env.step(clipped_action[0])
#     160             true_reward = reward
#     161
#
# ~/sose20/ees-pees/backend/webotsgym/env/webotenv.py in step(self, action)
#     138
#     139         action = self.action_class.map(action, self.pre_action)
# --> 140         self.send_command_and_data_request(action)
#     141         self.pre_action = action
#     142
#
# ~/sose20/ees-pees/backend/webotsgym/env/webotenv.py in send_command_and_data_request(self, action)
#     204
#     205     def send_command_and_data_request(self, action):
# --> 206         self.com.send_command_and_data_request(action)
#     207         self._update_history()
#     208
#
# ~/sose20/ees-pees/backend/webotsgym/com/communicate.py in send_command_and_data_request(self, action)
#      68                              self.config.direction_type, action)
#      69         self.send(pack_out)
# ---> 70         self.recv()
#      71
#      72     # ------------------------------- GRID MOVES ------------------------------
#
# ~/sose20/ees-pees/backend/webotsgym/com/communicate.py in recv(self)
#      26     # -------------------------------  RECV -----------------------------------
#      27     def recv(self):
# ---> 28         buffer, addr = self.sock.recvfrom(self.config.PACKET_SIZE)
#      29         self.packet = PacketIn(self.config, buffer)
#      30         if self.packet.count != self.msg_cnt:
#
# KeyboardInterrupt:

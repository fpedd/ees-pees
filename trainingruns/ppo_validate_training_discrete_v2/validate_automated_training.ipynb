# %%
import webotsgym as wg

from webotsgym.config import WebotConfig, SimSpeedMode
from webotsgym.environment import webotsgym, WebotsGrid
from webotsgym.evaluate import Evaluate, EvaluateMats, EvaluatePJ0
from webotsgym.action import DiscreteAction, ContinuousAction
from webotsgym.observation import Observation

import numpy as np

import gym
import stable_baselines
from stable_baselines import A2C, ACER, ACKTR, DQN, DDPG, SAC, PPO1, PPO2, TD3, TRPO
from stable_baselines.common.env_checker import check_env
from stable_baselines.common.policies import MlpPolicy
# Out:
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.

# %%
def exponential_decay(x, N0=1, lambda_=5):
    return N0*np.exp(-lambda_*x)

def exponential_penalty(x, step_penalty=-1, lambda_=5):
    return step_penalty * (1 - exponential_decay(x, lambda_=lambda_))

class MyEval(Evaluate):
    def __init__(self, env, config: WebotConfig = WebotConfig()):
        super(MyEval, self).__init__(env, config)

    def calc_reward(self):
        if self.env.get_target_distance(normalized=False) < 0.05:
            reward = 10000
        else:
            distance_normalized = self.env.get_target_distance(normalized=True)
            step_base_penalty = -1
            reward = exponential_penalty(x=distance_normalized, step_penalty=step_base_penalty, lambda_=3)
            if self.env.gps_visited_count > 3:
                reward -= 0.2 * (self.env.gps_visited_count - 2)**2
            if self.env.state._action_denied is True:
                reward -= 500
        return reward
        
        
    def check_done(self):
        if self.env.time_steps == 300:
            return True
        if self.env.total_reward < -10000:
            return True
        if self.env.get_target_distance(normalized=False) < 0.05:
            return True
        return False


config = WebotConfig()
config.sim_mode = SimSpeedMode.FAST
config.reset_env_after = 20000
config.num_obstacles = 12
config.world_size = 8
env = WebotsGrid(train=True, 
                 config=config,
                 evaluate_class = MyEval)
# Out:
# /home/jonas/anaconda3/lib/python3.6/site-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# Accepting on Port:  10201
# sending: start env 2

# %%
time_steps = 0
model_name = "PPO_webots_v1_jonas_no_while"

model = PPO1("MlpPolicy", env, verbose=1, tensorboard_log="./PPO_webots_v1_jonas_no_while_tensorboard/")
model.learn(total_timesteps=50000)
model.save("models/keep/{}".format(model_name))

#while time_steps < 500000:
#    model = PPO1("MlpPolicy", env, verbose=1)
#    model.load("models/keep/{}".format(model_name))
#    model.learn(total_timesteps=10000)
#    model.save("models/keep/{}".format(model_name))
#    time_steps += 10000
# Out:
# WARNING:tensorflow:From /home/jonas/anaconda3/lib/python3.6/site-packages/stable_baselines/common/tf_util.py:191: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /home/jonas/anaconda3/lib/python3.6/site-packages/stable_baselines/common/tf_util.py:200: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# WARNING:tensorflow:From /home/jonas/anaconda3/lib/python3.6/site-packages/stable_baselines/common/policies.py:116: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# WARNING:tensorflow:From /home/jonas/anaconda3/lib/python3.6/site-packages/stable_baselines/common/input.py:25: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /home/jonas/anaconda3/lib/python3.6/site-packages/stable_baselines/common/policies.py:561: flatten (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.flatten instead.
# WARNING:tensorflow:From /home/jonas/anaconda3/lib/python3.6/site-packages/tensorflow_core/python/layers/core.py:332: Layer.apply (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.__call__` method instead.
# WARNING:tensorflow:From /home/jonas/anaconda3/lib/python3.6/site-packages/stable_baselines/common/tf_layers.py:123: The name tf.get_variable is deprecated. Please use tf.compat.v1.get_variable instead.
#
# WARNING:tensorflow:From /home/jonas/anaconda3/lib/python3.6/site-packages/stable_baselines/common/distributions.py:326: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /home/jonas/anaconda3/lib/python3.6/site-packages/stable_baselines/common/distributions.py:327: The name tf.log is deprecated. Please use tf.math.log instead.
#
# WARNING:tensorflow:From /home/jonas/anaconda3/lib/python3.6/site-packages/stable_baselines/ppo1/pposgd_simple.py:153: The name tf.summary.scalar is deprecated. Please use tf.compat.v1.summary.scalar instead.
#
# WARNING:tensorflow:From /home/jonas/anaconda3/lib/python3.6/site-packages/stable_baselines/common/tf_util.py:449: The name tf.get_collection is deprecated. Please use tf.compat.v1.get_collection instead.
#
# WARNING:tensorflow:From /home/jonas/anaconda3/lib/python3.6/site-packages/stable_baselines/common/tf_util.py:449: The name tf.GraphKeys is deprecated. Please use tf.compat.v1.GraphKeys instead.
#
# WARNING:tensorflow:From /home/jonas/anaconda3/lib/python3.6/site-packages/stable_baselines/ppo1/pposgd_simple.py:163: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# WARNING:tensorflow:From /home/jonas/anaconda3/lib/python3.6/site-packages/stable_baselines/common/tf_util.py:241: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From /home/jonas/anaconda3/lib/python3.6/site-packages/stable_baselines/common/tf_util.py:242: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
#
# WARNING:tensorflow:From /home/jonas/anaconda3/lib/python3.6/site-packages/stable_baselines/ppo1/pposgd_simple.py:191: The name tf.summary.merge_all is deprecated. Please use tf.compat.v1.summary.merge_all instead.
#
# WARNING:tensorflow:From /home/jonas/anaconda3/lib/python3.6/site-packages/tensorflow_core/python/ops/math_grad.py:1424: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /home/jonas/anaconda3/lib/python3.6/site-packages/stable_baselines/common/base_class.py:1143: The name tf.summary.FileWriter is deprecated. Please use tf.compat.v1.summary.FileWriter instead.
#
# ********** Iteration 0 ************
# sending: start env 2
# sending: start env 2
# sending: start env 2
# WARNING:tensorflow:From /home/jonas/anaconda3/lib/python3.6/site-packages/stable_baselines/common/tf_util.py:502: The name tf.Summary is deprecated. Please use tf.compat.v1.Summary instead.
#
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#      -0.00141 |      -0.01386 |      3.71e+06 |       0.00066 |       1.38555
#      -0.01244 |      -0.01383 |      3.71e+06 |       0.00362 |       1.38252
#      -0.01612 |      -0.01377 |      3.71e+06 |       0.00862 |       1.37747
#      -0.01950 |      -0.01375 |      3.71e+06 |       0.01110 |       1.37506
# Evaluating losses...
#      -0.02253 |      -0.01376 |      3.71e+06 |       0.01054 |       1.37565
# ----------------------------------
# | EpLenMean       | 40           |
# | EpRewMean       | 9.64e+03     |
# | EpThisIter      | 2            |
# | EpisodesSoFar   | 2            |
# | TimeElapsed     | 38.9         |
# | TimestepsSoFar  | 256          |
# | ev_tdlam_before | -6.59e-05    |
# | loss_ent        | 1.3756464    |
# | loss_kl         | 0.010542944  |
# | loss_pol_entpen | -0.013756462 |
# | loss_pol_surr   | -0.02253063  |
# | loss_vf_loss    | 3710452.8    |
# ----------------------------------
# ********** Iteration 1 ************
# sending: start env 2
# sending: start env 2
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#      -0.00138 |      -0.01376 |      6.41e+06 |       0.00024 |       1.37594
#      -0.01069 |      -0.01373 |      6.41e+06 |       0.00266 |       1.37279
#      -0.01979 |      -0.01364 |      6.41e+06 |       0.00987 |       1.36427
#      -0.02535 |      -0.01354 |      6.41e+06 |       0.02052 |       1.35394
# Evaluating losses...
#      -0.02679 |      -0.01353 |      6.40e+06 |       0.02418 |       1.35295
# ----------------------------------
# | EpLenMean       | 94.8         |
# | EpRewMean       | 9.52e+03     |
# | EpThisIter      | 2            |
# | EpisodesSoFar   | 4            |
# | TimeElapsed     | 72           |
# | TimestepsSoFar  | 512          |
# | ev_tdlam_before | -3.86e-05    |
# | loss_ent        | 1.3529503    |
# | loss_kl         | 0.024176545  |
# | loss_pol_entpen | -0.013529504 |
# | loss_pol_surr   | -0.026790615 |
# | loss_vf_loss    | 6404641.0    |
# ----------------------------------
# ********** Iteration 2 ************
# sending: start env 2
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#       0.00054 |      -0.01366 |      3.38e+06 |      9.30e-05 |       1.36617
#      -0.00040 |      -0.01367 |      3.38e+06 |       0.00030 |       1.36703
#      -0.00359 |      -0.01369 |      3.38e+06 |       0.00048 |       1.36933
#      -0.01044 |      -0.01372 |      3.38e+06 |       0.00148 |       1.37205
# Evaluating losses...
#      -0.01374 |      -0.01373 |      3.38e+06 |       0.00272 |       1.37302
# ----------------------------------
# | EpLenMean       | 134          |
# | EpRewMean       | 8.96e+03     |
# | EpThisIter      | 1            |
# | EpisodesSoFar   | 5            |
# | TimeElapsed     | 94.9         |
# | TimestepsSoFar  | 768          |
# | ev_tdlam_before | -0.000168    |
# | loss_ent        | 1.3730172    |
# | loss_kl         | 0.0027168354 |
# | loss_pol_entpen | -0.013730172 |
# | loss_pol_surr   | -0.013735194 |
# | loss_vf_loss    | 3377750.0    |
# ----------------------------------
# ********** Iteration 3 ************
# sending: start env 2
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#       0.00051 |      -0.01375 |      1.64e+05 |       0.00013 |       1.37473
#      -0.00472 |      -0.01378 |      1.64e+05 |       0.00104 |       1.37757
#      -0.01191 |      -0.01380 |      1.64e+05 |       0.00372 |       1.37981
#      -0.01881 |      -0.01380 |      1.64e+05 |       0.00893 |       1.37975
# Evaluating losses...
#      -0.01964 |      -0.01379 |      1.64e+05 |       0.01271 |       1.37850
# ----------------------------------
# | EpLenMean       | 150          |
# | EpRewMean       | 6.61e+03     |
# | EpThisIter      | 1            |
# | EpisodesSoFar   | 6            |
# | TimeElapsed     | 120          |
# | TimestepsSoFar  | 1024         |
# | ev_tdlam_before | -0.000525    |
# | loss_ent        | 1.3785       |
# | loss_kl         | 0.012709321  |
# | loss_pol_entpen | -0.013785001 |
# | loss_pol_surr   | -0.019636909 |
# | loss_vf_loss    | 163837.36    |
# ----------------------------------
# ********** Iteration 4 ************
# sending: start env 2
# sending: start env 2
# sending: start env 2
# sending: start env 2
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#       0.00053 |      -0.01375 |      4.30e+06 |      5.00e-05 |       1.37537
#      -0.00475 |      -0.01373 |      4.30e+06 |       0.00058 |       1.37316
#      -0.01742 |      -0.01370 |      4.30e+06 |       0.00274 |       1.36991
#      -0.01956 |      -0.01364 |      4.30e+06 |       0.00815 |       1.36398
# Evaluating losses...
#      -0.01858 |      -0.01361 |      4.30e+06 |       0.01120 |       1.36122
# ----------------------------------
# | EpLenMean       | 112          |
# | EpRewMean       | 6.45e+03     |
# | EpThisIter      | 4            |
# | EpisodesSoFar   | 10           |
# | TimeElapsed     | 164          |
# | TimestepsSoFar  | 1280         |
# | ev_tdlam_before | 0.000102     |
# | loss_ent        | 1.3612224    |
# | loss_kl         | 0.011197823  |
# | loss_pol_entpen | -0.013612224 |
# | loss_pol_surr   | -0.018584304 |
# | loss_vf_loss    | 4298190.0    |
# ----------------------------------
# ********** Iteration 5 ************
# sending: start env 2
# sending: start env 2
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#      -0.00015 |      -0.01371 |      3.05e+06 |      2.53e-05 |       1.37092
#      -0.00253 |      -0.01372 |      3.04e+06 |       0.00021 |       1.37160
#      -0.00825 |      -0.01374 |      3.04e+06 |       0.00106 |       1.37364
#      -0.01654 |      -0.01375 |      3.04e+06 |       0.00325 |       1.37529
# Evaluating losses...
#      -0.01951 |      -0.01375 |      3.04e+06 |       0.00472 |       1.37537
# ----------------------------------
# | EpLenMean       | 120          |
# | EpRewMean       | 5.92e+03     |
# | EpThisIter      | 2            |
# | EpisodesSoFar   | 12           |
# | TimeElapsed     | 194          |
# | TimestepsSoFar  | 1536         |
# | ev_tdlam_before | 0.000193     |
# | loss_ent        | 1.3753653    |
# | loss_kl         | 0.0047244662 |
# | loss_pol_entpen | -0.013753652 |
# | loss_pol_surr   | -0.019510299 |
# | loss_vf_loss    | 3044489.2    |
# ----------------------------------
# ********** Iteration 6 ************
# sending: start env 2
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#      8.62e-05 |      -0.01374 |      1.32e+05 |      9.94e-05 |       1.37377
#      -0.00318 |      -0.01373 |      1.32e+05 |       0.00082 |       1.37266
#      -0.00855 |      -0.01371 |      1.32e+05 |       0.00205 |       1.37082
#      -0.01231 |      -0.01368 |      1.31e+05 |       0.00370 |       1.36836
# Evaluating losses...
#      -0.01392 |      -0.01367 |      1.31e+05 |       0.00454 |       1.36745
# ----------------------------------
# | EpLenMean       | 129          |
# | EpRewMean       | 5.06e+03     |
# | EpThisIter      | 1            |
# | EpisodesSoFar   | 13           |
# | TimeElapsed     | 219          |
# | TimestepsSoFar  | 1792         |
# | ev_tdlam_before | 0.005        |
# | loss_ent        | 1.3674505    |
# | loss_kl         | 0.004540943  |
# | loss_pol_entpen | -0.013674505 |
# | loss_pol_surr   | -0.013919574 |
# | loss_vf_loss    | 131268.27    |
# ----------------------------------
# ********** Iteration 7 ************
# sending: start env 2
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#       0.00207 |      -0.01372 |      2.11e+05 |       0.00012 |       1.37218
#      -0.00308 |      -0.01372 |      2.10e+05 |       0.00070 |       1.37203
#      -0.01207 |      -0.01372 |      2.10e+05 |       0.00224 |       1.37235
#      -0.01967 |      -0.01371 |      2.10e+05 |       0.00593 |       1.37142
# Evaluating losses...
#      -0.02504 |      -0.01370 |      2.09e+05 |       0.00929 |       1.36971
# ----------------------------------
# | EpLenMean       | 135          |
# | EpRewMean       | 4.34e+03     |
# | EpThisIter      | 1            |
# | EpisodesSoFar   | 14           |
# | TimeElapsed     | 244          |
# | TimestepsSoFar  | 2048         |
# | ev_tdlam_before | 0.00492      |
# | loss_ent        | 1.3697095    |
# | loss_kl         | 0.009293897  |
# | loss_pol_entpen | -0.013697094 |
# | loss_pol_surr   | -0.025039729 |
# | loss_vf_loss    | 209416.86    |
# ----------------------------------
# ********** Iteration 8 ************
# sending: start env 2
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#     -4.59e-05 |      -0.01367 |      2.01e+05 |       0.00027 |       1.36699
#      -0.00586 |      -0.01359 |      2.01e+05 |       0.00254 |       1.35946
#      -0.01239 |      -0.01352 |      2.01e+05 |       0.00642 |       1.35228
#      -0.01641 |      -0.01351 |      2.00e+05 |       0.00775 |       1.35126
# Evaluating losses...
#      -0.01992 |      -0.01353 |      2.00e+05 |       0.00734 |       1.35336
# ----------------------------------
# | EpLenMean       | 144          |
# | EpRewMean       | 3.71e+03     |
# | EpThisIter      | 1            |
# | EpisodesSoFar   | 15           |
# | TimeElapsed     | 267          |
# | TimestepsSoFar  | 2304         |
# | ev_tdlam_before | 0.00782      |
# | loss_ent        | 1.3533641    |
# | loss_kl         | 0.007338124  |
# | loss_pol_entpen | -0.013533641 |
# | loss_pol_surr   | -0.019921314 |
# | loss_vf_loss    | 200258.88    |
# ----------------------------------
# ********** Iteration 9 ************
# sending: start env 2
# sending: start env 2
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#       0.00035 |      -0.01362 |      6.49e+06 |      3.58e-05 |       1.36176
#      -0.00208 |      -0.01363 |      6.49e+06 |       0.00043 |       1.36287
#      -0.00927 |      -0.01364 |      6.49e+06 |       0.00156 |       1.36440
#      -0.01548 |      -0.01365 |      6.49e+06 |       0.00407 |       1.36515
# Evaluating losses...
#      -0.01895 |      -0.01364 |      6.48e+06 |       0.00593 |       1.36381
# ----------------------------------
# | EpLenMean       | 147          |
# | EpRewMean       | 4.28e+03     |
# | EpThisIter      | 2            |
# | EpisodesSoFar   | 17           |
# | TimeElapsed     | 299          |
# | TimestepsSoFar  | 2560         |
# | ev_tdlam_before | 0.00016      |
# | loss_ent        | 1.3638115    |
# | loss_kl         | 0.005930712  |
# | loss_pol_entpen | -0.013638115 |
# | loss_pol_surr   | -0.018945577 |
# | loss_vf_loss    | 6483657.0    |
# ----------------------------------
# ********** Iteration 10 ************
# sending: start env 2
# sending: start env 2
# sending: start env 2
# sending: start env 2
# sending: start env 2
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#      -0.00080 |      -0.01370 |      9.64e+06 |       0.00011 |       1.36967
#      -0.00982 |      -0.01366 |      9.64e+06 |       0.00134 |       1.36568
#      -0.01988 |      -0.01357 |      9.64e+06 |       0.00569 |       1.35732
#      -0.02130 |      -0.01346 |      9.63e+06 |       0.01363 |       1.34580
# Evaluating losses...
#      -0.02748 |      -0.01343 |      9.63e+06 |       0.01491 |       1.34327
# ----------------------------------
# | EpLenMean       | 129          |
# | EpRewMean       | 4.61e+03     |
# | EpThisIter      | 4            |
# | EpisodesSoFar   | 21           |
# | TimeElapsed     | 351          |
# | TimestepsSoFar  | 2816         |
# | ev_tdlam_before | 0.000201     |
# | loss_ent        | 1.3432746    |
# | loss_kl         | 0.014913728  |
# | loss_pol_entpen | -0.013432746 |
# | loss_pol_surr   | -0.02747802  |
# | loss_vf_loss    | 9631946.0    |
# ----------------------------------
# ********** Iteration 11 ************
# sending: start env 2
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#       0.00031 |      -0.01345 |      2.40e+05 |       0.00063 |       1.34548
#      -0.01155 |      -0.01353 |      2.40e+05 |       0.00642 |       1.35275
#      -0.01780 |      -0.01357 |      2.40e+05 |       0.01606 |       1.35685
#      -0.02449 |      -0.01360 |      2.40e+05 |       0.01477 |       1.36045
# Evaluating losses...
#      -0.02789 |      -0.01363 |      2.40e+05 |       0.01251 |       1.36269
# ----------------------------------
# | EpLenMean       | 137          |
# | EpRewMean       | 4.17e+03     |
# | EpThisIter      | 1            |
# | EpisodesSoFar   | 22           |
# | TimeElapsed     | 376          |
# | TimestepsSoFar  | 3072         |
# | ev_tdlam_before | 0.00684      |
# | loss_ent        | 1.3626854    |
# | loss_kl         | 0.012514487  |
# | loss_pol_entpen | -0.013626856 |
# | loss_pol_surr   | -0.027886644 |
# | loss_vf_loss    | 239617.25    |
# ----------------------------------
# ********** Iteration 12 ************
# sending: start env 2
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#      -0.00098 |      -0.01363 |      6.95e+04 |       0.00014 |       1.36273
#      -0.00702 |      -0.01363 |      6.94e+04 |       0.00145 |       1.36326
#      -0.01741 |      -0.01362 |      6.92e+04 |       0.00498 |       1.36198
#      -0.02615 |      -0.01358 |      6.89e+04 |       0.01042 |       1.35760
# Evaluating losses...
#      -0.02820 |      -0.01354 |      6.87e+04 |       0.01406 |       1.35437
# ----------------------------------
# | EpLenMean       | 144          |
# | EpRewMean       | 3.82e+03     |
# | EpThisIter      | 1            |
# | EpisodesSoFar   | 23           |
# | TimeElapsed     | 402          |
# | TimestepsSoFar  | 3328         |
# | ev_tdlam_before | 0.0142       |
# | loss_ent        | 1.3543742    |
# | loss_kl         | 0.014061857  |
# | loss_pol_entpen | -0.013543742 |
# | loss_pol_surr   | -0.028204221 |
# | loss_vf_loss    | 68715.984    |
# ----------------------------------
# ********** Iteration 13 ************
# sending: start env 2
# sending: start env 2
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#      -0.00117 |      -0.01342 |      3.29e+06 |      8.45e-05 |       1.34167
#      -0.01200 |      -0.01340 |      3.29e+06 |       0.00181 |       1.33980
#      -0.02708 |      -0.01331 |      3.29e+06 |       0.01065 |       1.33112
#      -0.03099 |      -0.01318 |      3.28e+06 |       0.02462 |       1.31756
# Evaluating losses...
#      -0.03469 |      -0.01312 |      3.28e+06 |       0.03090 |       1.31201
# -----------------------------------
# | EpLenMean       | 143           |
# | EpRewMean       | 3.72e+03      |
# | EpThisIter      | 2             |
# | EpisodesSoFar   | 25            |
# | TimeElapsed     | 437           |
# | TimestepsSoFar  | 3584          |
# | ev_tdlam_before | 0.000786      |
# | loss_ent        | 1.3120065     |
# | loss_kl         | 0.030902574   |
# | loss_pol_entpen | -0.0131200645 |
# | loss_pol_surr   | -0.034692492  |
# | loss_vf_loss    | 3284284.5     |
# -----------------------------------
# ********** Iteration 14 ************
# sending: start env 2
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#      -0.00134 |      -0.01351 |      3.77e+05 |       0.00021 |       1.35129
#      -0.01202 |      -0.01343 |      3.77e+05 |       0.00297 |       1.34271
#      -0.01639 |      -0.01332 |      3.76e+05 |       0.00956 |       1.33196
#      -0.01951 |      -0.01333 |      3.75e+05 |       0.01040 |       1.33324
# Evaluating losses...
#      -0.02420 |      -0.01339 |      3.75e+05 |       0.00740 |       1.33927
# ----------------------------------
# | EpLenMean       | 143          |
# | EpRewMean       | 3.37e+03     |
# | EpThisIter      | 1            |
# | EpisodesSoFar   | 26           |
# | TimeElapsed     | 462          |
# | TimestepsSoFar  | 3840         |
# | ev_tdlam_before | 0.0155       |
# | loss_ent        | 1.3392731    |
# | loss_kl         | 0.007399466  |
# | loss_pol_entpen | -0.01339273  |
# | loss_pol_surr   | -0.024199037 |
# | loss_vf_loss    | 375159.62    |
# ----------------------------------
# ********** Iteration 15 ************
# sending: start env 2
# sending: start env 2
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#      7.19e-05 |      -0.01313 |      3.63e+06 |       0.00075 |       1.31325
#      -0.01525 |      -0.01323 |      3.63e+06 |       0.00609 |       1.32305
#      -0.02018 |      -0.01325 |      3.63e+06 |       0.01364 |       1.32478
#      -0.02429 |      -0.01321 |      3.63e+06 |       0.01981 |       1.32094
# Evaluating losses...
#      -0.02650 |      -0.01318 |      3.63e+06 |       0.02040 |       1.31788
# ----------------------------------
# | EpLenMean       | 146          |
# | EpRewMean       | 3.28e+03     |
# | EpThisIter      | 2            |
# | EpisodesSoFar   | 28           |
# | TimeElapsed     | 495          |
# | TimestepsSoFar  | 4096         |
# | ev_tdlam_before | 0.00151      |
# | loss_ent        | 1.3178833    |
# | loss_kl         | 0.020403003  |
# | loss_pol_entpen | -0.013178833 |
# | loss_pol_surr   | -0.02649602  |
# | loss_vf_loss    | 3625907.2    |
# ----------------------------------
# ********** Iteration 16 ************
# sending: start env 2
# sending: start env 2
# sending: start env 2
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#       0.00166 |      -0.01352 |      9.80e+06 |       0.00019 |       1.35172
#      -0.00376 |      -0.01349 |      9.80e+06 |       0.00098 |       1.34929
#      -0.01047 |      -0.01349 |      9.79e+06 |       0.00217 |       1.34906
#      -0.01837 |      -0.01348 |      9.79e+06 |       0.00476 |       1.34831
# Evaluating losses...
#      -0.02140 |      -0.01347 |      9.79e+06 |       0.00741 |       1.34669
# ----------------------------------
# | EpLenMean       | 137          |
# | EpRewMean       | 3.93e+03     |
# | EpThisIter      | 3            |
# | EpisodesSoFar   | 31           |
# | TimeElapsed     | 536          |
# | TimestepsSoFar  | 4352         |
# | ev_tdlam_before | -0.000173    |
# | loss_ent        | 1.3466904    |
# | loss_kl         | 0.0074064326 |
# | loss_pol_entpen | -0.013466904 |
# | loss_pol_surr   | -0.021402087 |
# | loss_vf_loss    | 9788589.0    |
# ----------------------------------
# ********** Iteration 17 ************
# sending: start env 2
# sending: start env 2
# sending: start env 2
# sending: start env 2
# sending: start env 2
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#       0.00066 |      -0.01323 |      1.20e+07 |      1.00e-04 |       1.32305
#      -0.00262 |      -0.01325 |      1.20e+07 |       0.00074 |       1.32487
#      -0.01144 |      -0.01327 |      1.20e+07 |       0.00220 |       1.32707
#      -0.02019 |      -0.01327 |      1.20e+07 |       0.00439 |       1.32725
# Evaluating losses...
#      -0.02519 |      -0.01326 |      1.20e+07 |       0.00591 |       1.32557
# ----------------------------------
# | EpLenMean       | 127          |
# | EpRewMean       | 4.65e+03     |
# | EpThisIter      | 5            |
# | EpisodesSoFar   | 36           |
# | TimeElapsed     | 586          |
# | TimestepsSoFar  | 4608         |
# | ev_tdlam_before | 0.000907     |
# | loss_ent        | 1.3255668    |
# | loss_kl         | 0.005905983  |
# | loss_pol_entpen | -0.013255667 |
# | loss_pol_surr   | -0.025185034 |
# | loss_vf_loss    | 11989657.0   |
# ----------------------------------
# ********** Iteration 18 ************
# sending: start env 2
# sending: start env 2
# sending: start env 2
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#      -0.00058 |      -0.01342 |      7.10e+06 |      9.88e-05 |       1.34182
#      -0.00509 |      -0.01341 |      7.10e+06 |       0.00096 |       1.34075
#      -0.01194 |      -0.01338 |      7.10e+06 |       0.00307 |       1.33806
#      -0.01915 |      -0.01336 |      7.10e+06 |       0.00549 |       1.33572
# Evaluating losses...
#      -0.02456 |      -0.01336 |      7.10e+06 |       0.00623 |       1.33559
# -----------------------------------
# | EpLenMean       | 124           |
# | EpRewMean       | 4.67e+03      |
# | EpThisIter      | 3             |
# | EpisodesSoFar   | 39            |
# | TimeElapsed     | 627           |
# | TimestepsSoFar  | 4864          |
# | ev_tdlam_before | 0.00143       |
# | loss_ent        | 1.3355861     |
# | loss_kl         | 0.006227591   |
# | loss_pol_entpen | -0.0133558605 |
# | loss_pol_surr   | -0.024562968  |
# | loss_vf_loss    | 7097272.5     |
# -----------------------------------
# ********** Iteration 19 ************
# sending: start env 2
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#      -0.00236 |      -0.01342 |      5.58e+05 |       0.00049 |       1.34220
#      -0.01369 |      -0.01350 |      5.57e+05 |       0.00823 |       1.35049
#      -0.01394 |      -0.01355 |      5.57e+05 |       0.02004 |       1.35474
#      -0.02528 |      -0.01361 |      5.56e+05 |       0.01829 |       1.36073
# Evaluating losses...
#      -0.03112 |      -0.01364 |      5.55e+05 |       0.01500 |       1.36423
# ----------------------------------
# | EpLenMean       | 126          |
# | EpRewMean       | 4.42e+03     |
# | EpThisIter      | 1            |
# | EpisodesSoFar   | 40           |
# | TimeElapsed     | 653          |
# | TimestepsSoFar  | 5120         |
# | ev_tdlam_before | 0.014        |
# | loss_ent        | 1.3642335    |
# | loss_kl         | 0.015000706  |
# | loss_pol_entpen | -0.013642334 |
# | loss_pol_surr   | -0.031120803 |
# | loss_vf_loss    | 555213.9     |
# ----------------------------------
# ********** Iteration 20 ************
# sending: start env 2
# sending: start env 2
# sending: start env 2
# sending: start env 2
# sending: start env 2
# sending: start env 2
# sending: start env 2
# sending: start env 2
# sending: start env 2
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#      -0.00243 |      -0.01347 |      1.93e+07 |       0.00029 |       1.34677
#      -0.01473 |      -0.01346 |      1.92e+07 |       0.00394 |       1.34608
#      -0.02335 |      -0.01340 |      1.92e+07 |       0.01275 |       1.34011
#      -0.02885 |      -0.01337 |      1.92e+07 |       0.01553 |       1.33727
# Evaluating losses...
#      -0.03424 |      -0.01337 |      1.92e+07 |       0.01392 |       1.33725
# ----------------------------------
# | EpLenMean       | 108          |
# | EpRewMean       | 5.42e+03     |
# | EpThisIter      | 9            |
# | EpisodesSoFar   | 49           |
# | TimeElapsed     | 731          |
# | TimestepsSoFar  | 5376         |
# | ev_tdlam_before | 0.000116     |
# | loss_ent        | 1.337251     |
# | loss_kl         | 0.0139171835 |
# | loss_pol_entpen | -0.01337251  |
# | loss_pol_surr   | -0.03423657  |
# | loss_vf_loss    | 19241002.0   |
# ----------------------------------
# ********** Iteration 21 ************
# sending: start env 2
# sending: start env 2
# sending: start env 2
# sending: start env 2
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#       0.00130 |      -0.01349 |      1.05e+07 |       0.00020 |       1.34922
#      -0.00603 |      -0.01347 |      1.05e+07 |       0.00121 |       1.34670
#      -0.01885 |      -0.01340 |      1.05e+07 |       0.00388 |       1.34034
#      -0.02596 |      -0.01330 |      1.05e+07 |       0.00989 |       1.32951
# Evaluating losses...
#      -0.02791 |      -0.01323 |      1.05e+07 |       0.01386 |       1.32311
# ----------------------------------
# | EpLenMean       | 105          |
# | EpRewMean       | 5.44e+03     |
# | EpThisIter      | 4            |
# | EpisodesSoFar   | 53           |
# | TimeElapsed     | 774          |
# | TimestepsSoFar  | 5632         |
# | ev_tdlam_before | 0.0036       |
# | loss_ent        | 1.3231063    |
# | loss_kl         | 0.01386      |
# | loss_pol_entpen | -0.013231063 |
# | loss_pol_surr   | -0.027910763 |
# | loss_vf_loss    | 10461563.0   |
# ----------------------------------
# ********** Iteration 22 ************
# sending: start env 2
# sending: start env 2
# sending: start env 2
# sending: start env 2
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#      -0.00063 |      -0.01346 |      1.32e+07 |      7.90e-05 |       1.34606
#      -0.00732 |      -0.01342 |      1.32e+07 |       0.00098 |       1.34156
#      -0.01851 |      -0.01337 |      1.32e+07 |       0.00469 |       1.33706
#      -0.02380 |      -0.01332 |      1.32e+07 |       0.01164 |       1.33225
# Evaluating losses...
#      -0.02662 |      -0.01331 |      1.32e+07 |       0.01474 |       1.33077
# ----------------------------------
# | EpLenMean       | 103          |
# | EpRewMean       | 5.73e+03     |
# | EpThisIter      | 4            |
# | EpisodesSoFar   | 57           |
# | TimeElapsed     | 822          |
# | TimestepsSoFar  | 5888         |
# | ev_tdlam_before | 0.000241     |
# | loss_ent        | 1.3307741    |
# | loss_kl         | 0.014740629  |
# | loss_pol_entpen | -0.013307741 |
# | loss_pol_surr   | -0.026615098 |
# | loss_vf_loss    | 13165926.0   |
# ----------------------------------
# ********** Iteration 23 ************
# sending: start env 2
# sending: start env 2
# sending: start env 2
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#       0.00119 |      -0.01330 |      9.79e+06 |      8.88e-05 |       1.33023
#      -0.00159 |      -0.01327 |      9.79e+06 |       0.00080 |       1.32707
#      -0.00695 |      -0.01321 |      9.79e+06 |       0.00271 |       1.32081
#      -0.01578 |      -0.01312 |      9.79e+06 |       0.00641 |       1.31218
# Evaluating losses...
#      -0.01827 |      -0.01306 |      9.79e+06 |       0.00980 |       1.30552
# -----------------------------------
# | EpLenMean       | 101           |
# | EpRewMean       | 5.94e+03      |
# | EpThisIter      | 3             |
# | EpisodesSoFar   | 60            |
# | TimeElapsed     | 866           |
# | TimestepsSoFar  | 6144          |
# | ev_tdlam_before | 3.13e-05      |
# | loss_ent        | 1.305515      |
# | loss_kl         | 0.009799049   |
# | loss_pol_entpen | -0.0130551495 |
# | loss_pol_surr   | -0.018271912  |
# | loss_vf_loss    | 9788222.0     |
# -----------------------------------
# ********** Iteration 24 ************
# sending: start env 2
# sending: start env 2
# sending: start env 2
# sending: start env 2
# sending: start env 2
# sending: start env 2
# sending: start env 2
# sending: start env 2
# sending: start env 2
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#      -0.00235 |      -0.01305 |      2.45e+07 |       0.00038 |       1.30455
#      -0.01060 |      -0.01289 |      2.45e+07 |       0.00502 |       1.28948
#      -0.01421 |      -0.01279 |      2.45e+07 |       0.01075 |       1.27899
#      -0.02538 |      -0.01286 |      2.45e+07 |       0.00948 |       1.28595
# Evaluating losses...
#      -0.03153 |      -0.01293 |      2.45e+07 |       0.00805 |       1.29269
# ----------------------------------
# | EpLenMean       | 92.4         |
# | EpRewMean       | 6.46e+03     |
# | EpThisIter      | 9            |
# | EpisodesSoFar   | 69           |
# | TimeElapsed     | 944          |
# | TimestepsSoFar  | 6400         |
# | ev_tdlam_before | 0.000113     |
# | loss_ent        | 1.2926877    |
# | loss_kl         | 0.008047205  |
# | loss_pol_entpen | -0.012926878 |
# | loss_pol_surr   | -0.03152914  |
# | loss_vf_loss    | 24526966.0   |
# ----------------------------------
# ********** Iteration 25 ************
# sending: start env 2
# sending: start env 2
# sending: start env 2
# sending: start env 2
# sending: start env 2
# sending: start env 2
# sending: start env 2
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#      -0.00111 |      -0.01306 |      1.50e+07 |       0.00033 |       1.30564
#      -0.00813 |      -0.01313 |      1.50e+07 |       0.00280 |       1.31333
#      -0.01816 |      -0.01318 |      1.50e+07 |       0.00795 |       1.31848
#      -0.02428 |      -0.01317 |      1.50e+07 |       0.01007 |       1.31735
# Evaluating losses...
#      -0.03216 |      -0.01313 |      1.50e+07 |       0.00905 |       1.31295
# ----------------------------------
# | EpLenMean       | 86.2         |
# | EpRewMean       | 6.58e+03     |
# | EpThisIter      | 7            |
# | EpisodesSoFar   | 76           |
# | TimeElapsed     | 1.01e+03     |
# | TimestepsSoFar  | 6656         |
# | ev_tdlam_before | 0.0033       |
# | loss_ent        | 1.3129547    |
# | loss_kl         | 0.009047285  |
# | loss_pol_entpen | -0.013129546 |
# | loss_pol_surr   | -0.032155495 |
# | loss_vf_loss    | 14956310.0   |
# ----------------------------------
# ********** Iteration 26 ************
# sending: start env 2
# sending: start env 2
# sending: start env 2
# sending: start env 2
# sending: start env 2
# sending: start env 2
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#      -0.00042 |      -0.01317 |      1.26e+07 |       0.00021 |       1.31683
#      -0.01105 |      -0.01312 |      1.26e+07 |       0.00275 |       1.31214
#      -0.01369 |      -0.01304 |      1.26e+07 |       0.01078 |       1.30374
#      -0.01572 |      -0.01295 |      1.26e+07 |       0.01563 |       1.29534
# Evaluating losses...
#      -0.01933 |      -0.01293 |      1.26e+07 |       0.01499 |       1.29276
# ----------------------------------
# | EpLenMean       | 84.2         |
# | EpRewMean       | 6.64e+03     |
# | EpThisIter      | 6            |
# | EpisodesSoFar   | 82           |
# | TimeElapsed     | 1.07e+03     |
# | TimestepsSoFar  | 6912         |
# | ev_tdlam_before | 0.00328      |
# | loss_ent        | 1.292763     |
# | loss_kl         | 0.014992656  |
# | loss_pol_entpen | -0.012927629 |
# | loss_pol_surr   | -0.019331962 |
# | loss_vf_loss    | 12637542.0   |
# ----------------------------------
# ********** Iteration 27 ************
# sending: start env 2
# sending: start env 2
# sending: start env 2
# sending: start env 2
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#       0.00035 |      -0.01283 |      1.31e+07 |      3.75e-05 |       1.28336
#      -0.00743 |      -0.01279 |      1.31e+07 |       0.00064 |       1.27923
#      -0.01846 |      -0.01272 |      1.31e+07 |       0.00429 |       1.27163
#      -0.02327 |      -0.01266 |      1.31e+07 |       0.00870 |       1.26636
# Evaluating losses...
#      -0.02605 |      -0.01266 |      1.31e+07 |       0.00960 |       1.26640
# ----------------------------------
# | EpLenMean       | 83.2         |
# | EpRewMean       | 6.79e+03     |
# | EpThisIter      | 4            |
# | EpisodesSoFar   | 86           |
# | TimeElapsed     | 1.12e+03     |
# | TimestepsSoFar  | 7168         |
# | ev_tdlam_before | -5.56e-05    |
# | loss_ent        | 1.2663956    |
# | loss_kl         | 0.009598469  |
# | loss_pol_entpen | -0.012663955 |
# | loss_pol_surr   | -0.026052859 |
# | loss_vf_loss    | 13112116.0   |
# ----------------------------------
# ********** Iteration 28 ************
# sending: start env 2
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#       0.00013 |      -0.01306 |      3.42e+06 |      5.31e-05 |       1.30572
#      -0.00802 |      -0.01308 |      3.42e+06 |       0.00073 |       1.30785
#      -0.01740 |      -0.01308 |      3.42e+06 |       0.00422 |       1.30845
#      -0.02165 |      -0.01303 |      3.42e+06 |       0.01065 |       1.30306
# Evaluating losses...
#      -0.02612 |      -0.01300 |      3.42e+06 |       0.01286 |       1.29987
# ----------------------------------
# | EpLenMean       | 82.7         |
# | EpRewMean       | 6.83e+03     |
# | EpThisIter      | 1            |
# | EpisodesSoFar   | 87           |
# | TimeElapsed     | 1.14e+03     |
# | TimestepsSoFar  | 7424         |
# | ev_tdlam_before | 0.00274      |
# | loss_ent        | 1.2998707    |
# | loss_kl         | 0.012864712  |
# | loss_pol_entpen | -0.012998708 |
# | loss_pol_surr   | -0.026123334 |
# | loss_vf_loss    | 3415177.0    |
# ----------------------------------
# ********** Iteration 29 ************
# sending: start env 2
# sending: start env 2
# sending: start env 2
# sending: start env 2
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#       0.00110 |      -0.01288 |      1.29e+07 |       0.00016 |       1.28816
#      -0.00467 |      -0.01292 |      1.29e+07 |       0.00062 |       1.29208
#      -0.01494 |      -0.01295 |      1.29e+07 |       0.00248 |       1.29530
#      -0.01978 |      -0.01293 |      1.29e+07 |       0.00571 |       1.29338
# Evaluating losses...
#      -0.02255 |      -0.01289 |      1.29e+07 |       0.00793 |       1.28861
# ----------------------------------
# | EpLenMean       | 84.2         |
# | EpRewMean       | 6.91e+03     |
# | EpThisIter      | 4            |
# | EpisodesSoFar   | 91           |
# | TimeElapsed     | 1.19e+03     |
# | TimestepsSoFar  | 7680         |
# | ev_tdlam_before | -0.000471    |
# | loss_ent        | 1.2886066    |
# | loss_kl         | 0.007926454  |
# | loss_pol_entpen | -0.012886066 |
# | loss_pol_surr   | -0.022553986 |
# | loss_vf_loss    | 12930776.0   |
# ----------------------------------
# ********** Iteration 30 ************
# sending: start env 2
# sending: start env 2
# sending: start env 2
# sending: start env 2
# sending: start env 2
# sending: start env 2
# sending: start env 2
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#       0.00047 |      -0.01294 |      2.20e+07 |      9.31e-05 |       1.29413
#      -0.00961 |      -0.01293 |      2.20e+07 |       0.00145 |       1.29349
#      -0.01789 |      -0.01291 |      2.20e+07 |       0.00723 |       1.29135
#      -0.02099 |      -0.01288 |      2.20e+07 |       0.00984 |       1.28803
# Evaluating losses...
#      -0.02598 |      -0.01287 |      2.20e+07 |       0.00800 |       1.28661
# ----------------------------------
# | EpLenMean       | 80.4         |
# | EpRewMean       | 7.13e+03     |
# | EpThisIter      | 7            |
# | EpisodesSoFar   | 98           |
# | TimeElapsed     | 1.26e+03     |
# | TimestepsSoFar  | 7936         |
# | ev_tdlam_before | 2.38e-06     |
# | loss_ent        | 1.2866108    |
# | loss_kl         | 0.007999109  |
# | loss_pol_entpen | -0.012866108 |
# | loss_pol_surr   | -0.025976602 |
# | loss_vf_loss    | 21953320.0   |
# ----------------------------------
# ********** Iteration 31 ************
# sending: start env 2
# sending: start env 2
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#       0.00015 |      -0.01312 |      3.24e+06 |      4.81e-05 |       1.31156
#      -0.00635 |      -0.01310 |      3.24e+06 |       0.00050 |       1.30977
#      -0.01750 |      -0.01306 |      3.24e+06 |       0.00459 |       1.30556
#      -0.01840 |      -0.01296 |      3.24e+06 |       0.01601 |       1.29622
# Evaluating losses...
#      -0.01872 |      -0.01292 |      3.23e+06 |       0.02107 |       1.29154
# ----------------------------------
# | EpLenMean       | 81.7         |
# | EpRewMean       | 7.03e+03     |
# | EpThisIter      | 2            |
# | EpisodesSoFar   | 100          |
# | TimeElapsed     | 1.3e+03      |
# | TimestepsSoFar  | 8192         |
# | ev_tdlam_before | 0.00231      |
# | loss_ent        | 1.29154      |
# | loss_kl         | 0.021072257  |
# | loss_pol_entpen | -0.0129154   |
# | loss_pol_surr   | -0.018721143 |
# | loss_vf_loss    | 3232842.0    |
# ----------------------------------
# ********** Iteration 32 ************
# sending: start env 2
# sending: start env 2
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#       0.00059 |      -0.01306 |      3.47e+06 |      5.95e-05 |       1.30626
#      -0.00535 |      -0.01301 |      3.47e+06 |       0.00110 |       1.30131
#      -0.01152 |      -0.01290 |      3.47e+06 |       0.00691 |       1.28988
#      -0.01720 |      -0.01279 |      3.46e+06 |       0.01483 |       1.27870
# Evaluating losses...
#      -0.01887 |      -0.01279 |      3.46e+06 |       0.01528 |       1.27925
# ----------------------------------
# | EpLenMean       | 83.3         |
# | EpRewMean       | 6.89e+03     |
# | EpThisIter      | 2            |
# | EpisodesSoFar   | 102          |
# | TimeElapsed     | 1.33e+03     |
# | TimestepsSoFar  | 8448         |
# | ev_tdlam_before | 0.00836      |
# | loss_ent        | 1.2792487    |
# | loss_kl         | 0.015284603  |
# | loss_pol_entpen | -0.012792487 |
# | loss_pol_surr   | -0.018871175 |
# | loss_vf_loss    | 3463729.5    |
# ----------------------------------
# ********** Iteration 33 ************
# sending: start env 2
# sending: start env 2
# sending: start env 2
# sending: start env 2
# sending: start env 2
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#       0.00253 |      -0.01272 |      1.05e+07 |       0.00028 |       1.27171
#      -0.00161 |      -0.01277 |      1.05e+07 |       0.00118 |       1.27673
#      -0.00733 |      -0.01280 |      1.05e+07 |       0.00310 |       1.27958
#      -0.01266 |      -0.01280 |      1.05e+07 |       0.00391 |       1.27951
# Evaluating losses...
#      -0.01987 |      -0.01278 |      1.05e+07 |       0.00385 |       1.27821
# ----------------------------------
# | EpLenMean       | 76           |
# | EpRewMean       | 6.93e+03     |
# | EpThisIter      | 5            |
# | EpisodesSoFar   | 107          |
# | TimeElapsed     | 1.38e+03     |
# | TimestepsSoFar  | 8704         |
# | ev_tdlam_before | 0.0104       |
# | loss_ent        | 1.2782112    |
# | loss_kl         | 0.0038501553 |
# | loss_pol_entpen | -0.012782112 |
# | loss_pol_surr   | -0.019871803 |
# | loss_vf_loss    | 10467201.0   |
# ----------------------------------
# ********** Iteration 34 ************
# sending: start env 2
# sending: start env 2
# sending: start env 2
# sending: start env 2
# sending: start env 2
# sending: start env 2
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#     -6.67e-05 |      -0.01262 |      1.86e+07 |       0.00017 |       1.26220
#      -0.00739 |      -0.01262 |      1.86e+07 |       0.00195 |       1.26171
#      -0.01386 |      -0.01260 |      1.86e+07 |       0.00835 |       1.26029
#      -0.01728 |      -0.01256 |      1.86e+07 |       0.01272 |       1.25633
# Evaluating losses...
#      -0.02304 |      -0.01254 |      1.86e+07 |       0.01079 |       1.25395
# ----------------------------------
# | EpLenMean       | 72.2         |
# | EpRewMean       | 7.21e+03     |
# | EpThisIter      | 6            |
# | EpisodesSoFar   | 113          |
# | TimeElapsed     | 1.43e+03     |
# | TimestepsSoFar  | 8960         |
# | ev_tdlam_before | -0.00132     |
# | loss_ent        | 1.2539482    |
# | loss_kl         | 0.010791126  |
# | loss_pol_entpen | -0.012539482 |
# | loss_pol_surr   | -0.023044271 |
# | loss_vf_loss    | 18565850.0   |
# ----------------------------------
# ********** Iteration 35 ************
# sending: start env 2
# sending: start env 2
# sending: start env 2
# sending: start env 2
# sending: start env 2
# sending: start env 2
# sending: start env 2
# sending: start env 2
# sending: start env 2
# sending: start env 2
# sending: start env 2
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#      -0.00075 |      -0.01243 |      2.33e+07 |       0.00027 |       1.24312
#      -0.01081 |      -0.01239 |      2.33e+07 |       0.00219 |       1.23909
#      -0.01955 |      -0.01238 |      2.33e+07 |       0.00789 |       1.23843
#      -0.02530 |      -0.01235 |      2.33e+07 |       0.01130 |       1.23465
# Evaluating losses...
#      -0.03191 |      -0.01232 |      2.33e+07 |       0.01083 |       1.23176
# ----------------------------------
# | EpLenMean       | 56           |
# | EpRewMean       | 7.98e+03     |
# | EpThisIter      | 11           |
# | EpisodesSoFar   | 124          |
# | TimeElapsed     | 1.52e+03     |
# | TimestepsSoFar  | 9216         |
# | ev_tdlam_before | 0.00494      |
# | loss_ent        | 1.2317605    |
# | loss_kl         | 0.01082956   |
# | loss_pol_entpen | -0.012317603 |
# | loss_pol_surr   | -0.031911165 |
# | loss_vf_loss    | 23256562.0   |
# ----------------------------------
# ********** Iteration 36 ************
# sending: start env 2
# sending: start env 2
# sending: start env 2
# sending: start env 2
# sending: start env 2
# sending: start env 2
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#      2.58e-05 |      -0.01259 |      1.66e+07 |       0.00026 |       1.25918
#      -0.00664 |      -0.01258 |      1.66e+07 |       0.00250 |       1.25824
#      -0.01161 |      -0.01256 |      1.66e+07 |       0.00825 |       1.25630
#      -0.01188 |      -0.01253 |      1.66e+07 |       0.01226 |       1.25346
# Evaluating losses...
#      -0.01685 |      -0.01250 |      1.66e+07 |       0.01157 |       1.25041
# ----------------------------------
# | EpLenMean       | 52.3         |
# | EpRewMean       | 8.14e+03     |
# | EpThisIter      | 6            |
# | EpisodesSoFar   | 130          |
# | TimeElapsed     | 1.58e+03     |
# | TimestepsSoFar  | 9472         |
# | ev_tdlam_before | 0.00569      |
# | loss_ent        | 1.2504134    |
# | loss_kl         | 0.011568432  |
# | loss_pol_entpen | -0.012504134 |
# | loss_pol_surr   | -0.01684834  |
# | loss_vf_loss    | 16561948.0   |
# ----------------------------------
# ********** Iteration 37 ************
# sending: start env 2
# sending: start env 2
# sending: start env 2
# sending: start env 2
# sending: start env 2
# sending: start env 2
# sending: start env 2
# sending: start env 2
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#       0.00105 |      -0.01254 |      2.25e+07 |      5.63e-05 |       1.25388
#      -0.00755 |      -0.01256 |      2.25e+07 |       0.00058 |       1.25603
#      -0.01796 |      -0.01261 |      2.25e+07 |       0.00348 |       1.26100
#      -0.02621 |      -0.01263 |      2.25e+07 |       0.00818 |       1.26288
# Evaluating losses...
#      -0.02850 |      -0.01263 |      2.25e+07 |       0.01089 |       1.26310
# ----------------------------------
# | EpLenMean       | 49.4         |
# | EpRewMean       | 8.18e+03     |
# | EpThisIter      | 8            |
# | EpisodesSoFar   | 138          |
# | TimeElapsed     | 1.65e+03     |
# | TimestepsSoFar  | 9728         |
# | ev_tdlam_before | 0.000621     |
# | loss_ent        | 1.2631036    |
# | loss_kl         | 0.010885829  |
# | loss_pol_entpen | -0.012631035 |
# | loss_pol_surr   | -0.028496945 |
# | loss_vf_loss    | 22526614.0   |
# ----------------------------------
# ********** Iteration 38 ************
# sending: start env 2
# sending: start env 2
# sending: start env 2
# sending: start env 2
# sending: start env 2
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#       0.00059 |      -0.01231 |      1.19e+07 |       0.00015 |       1.23093
#      -0.01126 |      -0.01235 |      1.19e+07 |       0.00181 |       1.23512
#      -0.02160 |      -0.01239 |      1.19e+07 |       0.00688 |       1.23850
#      -0.02795 |      -0.01236 |      1.19e+07 |       0.01107 |       1.23649
# Evaluating losses...
#      -0.03430 |      -0.01234 |      1.19e+07 |       0.01065 |       1.23429
# ----------------------------------
# | EpLenMean       | 47.7         |
# | EpRewMean       | 8.32e+03     |
# | EpThisIter      | 5            |
# | EpisodesSoFar   | 143          |
# | TimeElapsed     | 1.7e+03      |
# | TimestepsSoFar  | 9984         |
# | ev_tdlam_before | 0.0042       |
# | loss_ent        | 1.2342892    |
# | loss_kl         | 0.010650458  |
# | loss_pol_entpen | -0.012342892 |
# | loss_pol_surr   | -0.034302104 |
# | loss_vf_loss    | 11894512.0   |
# ----------------------------------
# ********** Iteration 39 ************
# sending: start env 2
# sending: start env 2
# sending: start env 2
# sending: start env 2
# sending: start env 2
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#      -0.00397 |      -0.01289 |      1.43e+07 |       0.00048 |       1.28852
#      -0.01091 |      -0.01284 |      1.43e+07 |       0.00746 |       1.28436
#      -0.01382 |      -0.01280 |      1.43e+07 |       0.01268 |       1.28008
#      -0.02405 |      -0.01285 |      1.43e+07 |       0.00862 |       1.28476
# Evaluating losses...
# ...
# | loss_pol_entpen | -0.010996701  |
# | loss_pol_surr   | -0.0017026719 |
# | loss_vf_loss    | 8652203.0     |
# -----------------------------------
# ********** Iteration 184 ************
# sending: start env 2
# sending: start env 2
# sending: start env 2
# sending: start env 2
# sending: start env 2
# sending: start env 2
# sending: start env 2
# sending: start env 2
# sending: start env 2
# sending: start env 2
# sending: start env 2
# sending: start env 2
# sending: start env 2
# sending: start env 2
# sending: start env 2
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#      9.40e-05 |      -0.00982 |      2.24e+07 |      1.00e-06 |       0.98215
#      -0.00068 |      -0.00981 |      2.24e+07 |      1.37e-05 |       0.98148
#      -0.00101 |      -0.00981 |      2.24e+07 |      2.68e-05 |       0.98106
#      -0.00109 |      -0.00981 |      2.24e+07 |      3.01e-05 |       0.98139
# Evaluating losses...
#      -0.00142 |      -0.00982 |      2.24e+07 |      3.16e-05 |       0.98163
# -----------------------------------
# | EpLenMean       | 17.8          |
# | EpRewMean       | 8.88e+03      |
# | EpThisIter      | 13            |
# | EpisodesSoFar   | 1914          |
# | TimeElapsed     | 2.46e+04      |
# | TimestepsSoFar  | 47360         |
# | ev_tdlam_before | 0.0118        |
# | loss_ent        | 0.98162603    |
# | loss_kl         | 3.161929e-05  |
# | loss_pol_entpen | -0.00981626   |
# | loss_pol_surr   | -0.0014221072 |
# | loss_vf_loss    | 22360820.0    |
# -----------------------------------
# ********** Iteration 185 ************
# sending: start env 2
# sending: start env 2
# sending: start env 2
# sending: start env 2
# sending: start env 2
# sending: start env 2
# sending: start env 2
# sending: start env 2
# sending: start env 2
# sending: start env 2
# sending: start env 2
# sending: start env 2
# sending: start env 2
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#      1.85e-05 |      -0.00875 |      2.69e+07 |      4.13e-07 |       0.87466
#      -0.00049 |      -0.00875 |      2.69e+07 |      3.52e-06 |       0.87458
#      -0.00104 |      -0.00875 |      2.69e+07 |      1.65e-05 |       0.87473
#      -0.00130 |      -0.00875 |      2.69e+07 |      3.48e-05 |       0.87450
# Evaluating losses...
#      -0.00152 |      -0.00874 |      2.69e+07 |      4.49e-05 |       0.87438
# -----------------------------------
# | EpLenMean       | 17.5          |
# | EpRewMean       | 8.9e+03       |
# | EpThisIter      | 13            |
# | EpisodesSoFar   | 1927          |
# | TimeElapsed     | 2.47e+04      |
# | TimestepsSoFar  | 47616         |
# | ev_tdlam_before | 0.00918       |
# | loss_ent        | 0.8743781     |
# | loss_kl         | 4.4923265e-05 |
# | loss_pol_entpen | -0.00874378   |
# | loss_pol_surr   | -0.0015247762 |
# | loss_vf_loss    | 26888778.0    |
# -----------------------------------
# ********** Iteration 186 ************
# sending: start env 2
# sending: start env 2
# sending: start env 2
# sending: start env 2
# sending: start env 2
# sending: start env 2
# sending: start env 2
# sending: start env 2
# sending: start env 2
# sending: start env 2
# sending: start env 2
# sending: start env 2
# sending: start env 2
# sending: start env 2
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#      4.74e-05 |      -0.00906 |      2.82e+07 |      1.63e-06 |       0.90585
#      -0.00056 |      -0.00906 |      2.82e+07 |      1.12e-05 |       0.90630
#      -0.00078 |      -0.00907 |      2.82e+07 |      2.42e-05 |       0.90658
#      -0.00113 |      -0.00907 |      2.82e+07 |      2.55e-05 |       0.90658
# Evaluating losses...
#      -0.00140 |      -0.00906 |      2.82e+07 |      2.41e-05 |       0.90649
# -----------------------------------
# | EpLenMean       | 19            |
# | EpRewMean       | 8.75e+03      |
# | EpThisIter      | 14            |
# | EpisodesSoFar   | 1941          |
# | TimeElapsed     | 2.48e+04      |
# | TimestepsSoFar  | 47872         |
# | ev_tdlam_before | 0.0176        |
# | loss_ent        | 0.9064915     |
# | loss_kl         | 2.4128041e-05 |
# | loss_pol_entpen | -0.009064915  |
# | loss_pol_surr   | -0.0014005974 |
# | loss_vf_loss    | 28186024.0    |
# -----------------------------------
# ********** Iteration 187 ************
# sending: start env 2
# sending: start env 2
# sending: start env 2
# sending: start env 2
# sending: start env 2
# sending: start env 2
# sending: start env 2
# sending: start env 2
# sending: start env 2
# sending: start env 2
# sending: start env 2
# sending: start env 2
# sending: start env 2
# sending: start env 2
# sending: start env 2
# sending: start env 2
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#     -1.60e-05 |      -0.00837 |      3.04e+07 |      6.90e-07 |       0.83729
#      -0.00083 |      -0.00838 |      3.04e+07 |      8.24e-06 |       0.83784
#      -0.00091 |      -0.00839 |      3.04e+07 |      2.93e-05 |       0.83861
#      -0.00107 |      -0.00839 |      3.04e+07 |      3.30e-05 |       0.83859
# Evaluating losses...
#      -0.00143 |      -0.00838 |      3.04e+07 |      2.53e-05 |       0.83820
# -----------------------------------
# | EpLenMean       | 19.6          |
# | EpRewMean       | 8.9e+03       |
# | EpThisIter      | 16            |
# | EpisodesSoFar   | 1957          |
# | TimeElapsed     | 2.49e+04      |
# | TimestepsSoFar  | 48128         |
# | ev_tdlam_before | 0.0106        |
# | loss_ent        | 0.8382048     |
# | loss_kl         | 2.5304378e-05 |
# | loss_pol_entpen | -0.008382048  |
# | loss_pol_surr   | -0.0014266642 |
# | loss_vf_loss    | 30370960.0    |
# -----------------------------------
# ********** Iteration 188 ************
# sending: start env 2
# sending: start env 2
# sending: start env 2
# sending: start env 2
# sending: start env 2
# sending: start env 2
# sending: start env 2
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#      5.51e-05 |      -0.01044 |      1.30e+07 |      6.90e-07 |       1.04435
#      -0.00045 |      -0.01044 |      1.30e+07 |      6.30e-06 |       1.04436
#      -0.00062 |      -0.01044 |      1.30e+07 |      2.46e-05 |       1.04420
#      -0.00089 |      -0.01044 |      1.30e+07 |      2.49e-05 |       1.04401
# Evaluating losses...
#      -0.00115 |      -0.01044 |      1.30e+07 |      1.71e-05 |       1.04380
# -----------------------------------
# | EpLenMean       | 21.1          |
# | EpRewMean       | 8.74e+03      |
# | EpThisIter      | 7             |
# | EpisodesSoFar   | 1964          |
# | TimeElapsed     | 2.5e+04       |
# | TimestepsSoFar  | 48384         |
# | ev_tdlam_before | 0.0177        |
# | loss_ent        | 1.0438018     |
# | loss_kl         | 1.7075607e-05 |
# | loss_pol_entpen | -0.010438018  |
# | loss_pol_surr   | -0.0011461545 |
# | loss_vf_loss    | 13033821.0    |
# -----------------------------------
# ********** Iteration 189 ************
# sending: start env 2
# sending: start env 2
# sending: start env 2
# sending: start env 2
# sending: start env 2
# sending: start env 2
# sending: start env 2
# sending: start env 2
# sending: start env 2
# sending: start env 2
# sending: start env 2
# sending: start env 2
# sending: start env 2
# sending: start env 2
# sending: start env 2
# sending: start env 2
# sending: start env 2
# sending: start env 2
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#     -4.50e-05 |      -0.00836 |      3.25e+07 |      6.70e-07 |       0.83645
#      -0.00032 |      -0.00836 |      3.25e+07 |      4.56e-06 |       0.83645
#      -0.00067 |      -0.00837 |      3.25e+07 |      1.12e-05 |       0.83683
#      -0.00097 |      -0.00837 |      3.25e+07 |      1.59e-05 |       0.83701
# Evaluating losses...
#      -0.00113 |      -0.00837 |      3.25e+07 |      1.69e-05 |       0.83696
# -----------------------------------
# | EpLenMean       | 21.5          |
# | EpRewMean       | 8.74e+03      |
# | EpThisIter      | 17            |
# | EpisodesSoFar   | 1981          |
# | TimeElapsed     | 2.51e+04      |
# | TimestepsSoFar  | 48640         |
# | ev_tdlam_before | 0.0064        |
# | loss_ent        | 0.8369602     |
# | loss_kl         | 1.6875796e-05 |
# | loss_pol_entpen | -0.008369602  |
# | loss_pol_surr   | -0.0011270791 |
# | loss_vf_loss    | 32471586.0    |
# -----------------------------------
# ********** Iteration 190 ************
# sending: start env 2
# sending: start env 2
# sending: start env 2
# sending: start env 2
# sending: start env 2
# sending: start env 2
# sending: start env 2
# sending: start env 2
# sending: start env 2
# sending: start env 2
# sending: start env 2
# sending: start env 2
# sending: start env 2
# sending: start env 2
# sending: start env 2
# sending: start env 2
# sending: start env 2
# sending: start env 2
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#     -1.65e-05 |      -0.00839 |      3.51e+07 |      3.39e-07 |       0.83935
#      -0.00019 |      -0.00839 |      3.51e+07 |      2.73e-06 |       0.83938
#      -0.00052 |      -0.00840 |      3.51e+07 |      5.69e-06 |       0.83966
#      -0.00074 |      -0.00840 |      3.51e+07 |      8.49e-06 |       0.84005
# Evaluating losses...
#      -0.00083 |      -0.00840 |      3.51e+07 |      1.01e-05 |       0.84016
# ------------------------------------
# | EpLenMean       | 19.2           |
# | EpRewMean       | 9.04e+03       |
# | EpThisIter      | 18             |
# | EpisodesSoFar   | 1999           |
# | TimeElapsed     | 2.53e+04       |
# | TimestepsSoFar  | 48896          |
# | ev_tdlam_before | 0.0139         |
# | loss_ent        | 0.8401605      |
# | loss_kl         | 1.013267e-05   |
# | loss_pol_entpen | -0.008401604   |
# | loss_pol_surr   | -0.00083367527 |
# | loss_vf_loss    | 35066144.0     |
# ------------------------------------
# ********** Iteration 191 ************
# sending: start env 2
# sending: start env 2
# sending: start env 2
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#      1.48e-05 |      -0.01095 |      2.21e+06 |      1.29e-07 |       1.09504
#      -0.00015 |      -0.01095 |      2.21e+06 |      8.27e-07 |       1.09497
#      -0.00030 |      -0.01095 |      2.21e+06 |      2.50e-06 |       1.09493
#      -0.00046 |      -0.01095 |      2.21e+06 |      5.12e-06 |       1.09488
# Evaluating losses...
#      -0.00049 |      -0.01095 |      2.21e+06 |      6.58e-06 |       1.09485
# ------------------------------------
# | EpLenMean       | 19.4           |
# | EpRewMean       | 9.05e+03       |
# | EpThisIter      | 3              |
# | EpisodesSoFar   | 2002           |
# | TimeElapsed     | 2.53e+04       |
# | TimestepsSoFar  | 49152          |
# | ev_tdlam_before | 0.033          |
# | loss_ent        | 1.0948465      |
# | loss_kl         | 6.57688e-06    |
# | loss_pol_entpen | -0.010948466   |
# | loss_pol_surr   | -0.00049103424 |
# | loss_vf_loss    | 2214476.0      |
# ------------------------------------
# ********** Iteration 192 ************
# sending: start env 2
# sending: start env 2
# sending: start env 2
# sending: start env 2
# sending: start env 2
# sending: start env 2
# sending: start env 2
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#      8.61e-06 |      -0.01014 |      1.35e+07 |      2.66e-08 |       1.01378
#      -0.00014 |      -0.01014 |      1.35e+07 |      4.37e-07 |       1.01387
#      -0.00029 |      -0.01014 |      1.35e+07 |      1.37e-06 |       1.01391
#      -0.00035 |      -0.01014 |      1.35e+07 |      2.70e-06 |       1.01390
# Evaluating losses...
#      -0.00044 |      -0.01014 |      1.35e+07 |      3.85e-06 |       1.01392
# ------------------------------------
# | EpLenMean       | 20.8           |
# | EpRewMean       | 9.01e+03       |
# | EpThisIter      | 7              |
# | EpisodesSoFar   | 2009           |
# | TimeElapsed     | 2.54e+04       |
# | TimestepsSoFar  | 49408          |
# | ev_tdlam_before | 0.00947        |
# | loss_ent        | 1.0139213      |
# | loss_kl         | 3.851037e-06   |
# | loss_pol_entpen | -0.010139212   |
# | loss_pol_surr   | -0.00044342503 |
# | loss_vf_loss    | 13509106.0     |
# ------------------------------------
# ********** Iteration 193 ************
# sending: start env 2
# sending: start env 2
# sending: start env 2
# sending: start env 2
# sending: start env 2
# sending: start env 2
# sending: start env 2
# sending: start env 2
# sending: start env 2
# sending: start env 2
# sending: start env 2
# sending: start env 2
# sending: start env 2
# sending: start env 2
# sending: start env 2
# sending: start env 2
# sending: start env 2
# sending: start env 2
# sending: start env 2
# sending: start env 2
# sending: start env 2
# sending: start env 2
# sending: start env 2
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#      4.94e-05 |      -0.00722 |      4.51e+07 |      8.39e-08 |       0.72217
#     -7.29e-05 |      -0.00722 |      4.51e+07 |      1.97e-07 |       0.72214
#      -0.00023 |      -0.00722 |      4.51e+07 |      5.84e-07 |       0.72204
#      -0.00031 |      -0.00722 |      4.51e+07 |      1.32e-06 |       0.72200
# Evaluating losses...
#      -0.00039 |      -0.00722 |      4.51e+07 |      2.05e-06 |       0.72194
# -----------------------------------
# | EpLenMean       | 19.9          |
# | EpRewMean       | 9.16e+03      |
# | EpThisIter      | 23            |
# | EpisodesSoFar   | 2032          |
# | TimeElapsed     | 2.56e+04      |
# | TimestepsSoFar  | 49664         |
# | ev_tdlam_before | 5.45e-05      |
# | loss_ent        | 0.72194326    |
# | loss_kl         | 2.0452435e-06 |
# | loss_pol_entpen | -0.0072194324 |
# | loss_pol_surr   | -0.000392342  |
# | loss_vf_loss    | 45127110.0    |
# -----------------------------------
# ********** Iteration 194 ************
# sending: start env 2
# sending: start env 2
# sending: start env 2
# sending: start env 2
# sending: start env 2
# sending: start env 2
# sending: start env 2
# sending: start env 2
# sending: start env 2
# sending: start env 2
# sending: start env 2
# sending: start env 2
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#      3.50e-05 |      -0.00986 |      1.98e+07 |      2.96e-08 |       0.98589
#     -4.44e-05 |      -0.00986 |      1.98e+07 |      1.41e-07 |       0.98586
#      -0.00011 |      -0.00986 |      1.98e+07 |      5.15e-07 |       0.98588
#      -0.00015 |      -0.00986 |      1.98e+07 |      5.68e-07 |       0.98590
# Evaluating losses...
#      -0.00018 |      -0.00986 |      1.98e+07 |      5.17e-07 |       0.98589
# ------------------------------------
# | EpLenMean       | 19.1           |
# | EpRewMean       | 9.01e+03       |
# | EpThisIter      | 12             |
# | EpisodesSoFar   | 2044           |
# | TimeElapsed     | 2.57e+04       |
# | TimestepsSoFar  | 49920          |
# | ev_tdlam_before | 0.0238         |
# | loss_ent        | 0.9858932      |
# | loss_kl         | 5.16711e-07    |
# | loss_pol_entpen | -0.009858931   |
# | loss_pol_surr   | -0.00017561764 |
# | loss_vf_loss    | 19807694.0     |
# ------------------------------------
# ********** Iteration 195 ************
# sending: start env 2
# sending: start env 2
# sending: start env 2
# sending: start env 2
# sending: start env 2
# sending: start env 2
# sending: start env 2
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#      4.64e-07 |      -0.01115 |      4.61e+06 |     -2.28e-09 |       1.11545
#     -1.47e-05 |      -0.01115 |      4.61e+06 |     -1.06e-09 |       1.11545
#     -1.99e-05 |      -0.01115 |      4.61e+06 |      8.98e-10 |       1.11545
#     -2.33e-05 |      -0.01115 |      4.61e+06 |      8.07e-09 |       1.11545
# Evaluating losses...
#     -2.70e-05 |      -0.01115 |      4.61e+06 |      8.49e-09 |       1.11545
# ------------------------------------
# | EpLenMean       | 21.1           |
# | EpRewMean       | 8.7e+03        |
# | EpThisIter      | 7              |
# | EpisodesSoFar   | 2051           |
# | TimeElapsed     | 2.57e+04       |
# | TimestepsSoFar  | 50176          |
# | ev_tdlam_before | 0.021          |
# | loss_ent        | 1.1154544      |
# | loss_kl         | 8.486339e-09   |
# | loss_pol_entpen | -0.011154545   |
# | loss_pol_surr   | -2.6950613e-05 |
# | loss_vf_loss    | 4610472.5      |
# ------------------------------------

# %%
int(config.fast_simulation)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-4-e0bf3aacd197> in <module>
# ----> 1 int(config.fast_simulation)
#
# AttributeError: 'WebotConfig' object has no attribute 'fast_simulation'
